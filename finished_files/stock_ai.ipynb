# %%
# Import Modules

import numpy as np
import pandas as pd
import os
import random
import copy
import matplotlib.pyplot as plt
import pandas
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score, TimeSeriesSplit 
from sklearn.metrics import accuracy_score, confusion_matrix
import joblib
from sklearn import tree

os.chdir('./input/Data/Stocks')
list = os.listdir()
number_files = len(list)

#filenames = [x for x in os.listdir("./Stocks/") if x.endswith('.txt') and os.path.getsize(x) > 0]
filenames = random.sample([x for x in os.listdir() if x.endswith('.txt') 
                           and os.path.getsize(os.path.join('',x)) > 0], 8)

data = []
for filename in filenames:
    df = pd.read_csv(os.path.join('',filename), sep=',')
    label, _, _ = filename.split(sep='.')
    df['Label'] = label
    df['Date'] = pd.to_datetime(df['Date'])

    data.append(df)

TechIndicator = copy.deepcopy(data)


# Relative Strength Index
# Avg(PriceUp)/(Avg(PriceUP)+Avg(PriceDown)*100
# Where: PriceUp(t)=1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)>0};
#        PriceDown(t)=-1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)<0};

def rsi(values):
    up = values[values>0].mean()
    down = -1*values[values<0].mean()
    return 100 * up / (up + down)

# Add Momentum_1D column for all 15 stocks.
# Momentum_1D = P(t) - P(t-1)
for stock in range(len(TechIndicator)):
    TechIndicator[stock]['Momentum_1D'] = (TechIndicator[stock]['Close']-TechIndicator[stock]['Close'].shift(1)).fillna(0)
    TechIndicator[stock]['RSI_14D'] = TechIndicator[stock]['Momentum_1D'].rolling(center=False, window=14).apply(rsi).fillna(0)

### Calculation of Volume (Plain)m
for stock in range(len(TechIndicator)):
    TechIndicator[stock]['Volume_plain'] = TechIndicator[stock]['Volume'].fillna(0)
TechIndicator[0].tail()

def bbands(price, length=30, numsd=2):
    """ returns average, upper band, and lower band"""
    #ave = pd.stats.moments.rolling_mean(price,length)
    ave = price.rolling(window = length, center = False).mean()
    #sd = pd.stats.moments.rolling_std(price,length)
    sd = price.rolling(window = length, center = False).std()
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['BB_Middle_Band'], TechIndicator[stock]['BB_Upper_Band'], TechIndicator[stock]['BB_Lower_Band'] = bbands(TechIndicator[stock]['Close'], length=20, numsd=1)
    TechIndicator[stock]['BB_Middle_Band'] = TechIndicator[stock]['BB_Middle_Band'].fillna(0)
    TechIndicator[stock]['BB_Upper_Band'] = TechIndicator[stock]['BB_Upper_Band'].fillna(0)
    TechIndicator[stock]['BB_Lower_Band'] = TechIndicator[stock]['BB_Lower_Band'].fillna(0)

def aroon(df, tf=25):
    aroonup = []
    aroondown = []
    x = tf
    while x< len(df['Date']):
        aroon_up = ((df['High'][x-tf:x].tolist().index(max(df['High'][x-tf:x])))/float(tf))*100
        aroon_down = ((df['Low'][x-tf:x].tolist().index(min(df['Low'][x-tf:x])))/float(tf))*100
        aroonup.append(aroon_up)
        aroondown.append(aroon_down)
        x+=1
    return aroonup, aroondown

for stock in range(len(TechIndicator)):
    listofzeros = [0] * 25
    up, down = aroon(TechIndicator[stock])
    aroon_list = [x - y for x, y in zip(up,down)]
    if len(aroon_list)==0:
        aroon_list = [0] * TechIndicator[stock].shape[0]
        TechIndicator[stock]['Aroon_Oscillator'] = aroon_list
    else:
        TechIndicator[stock]['Aroon_Oscillator'] = listofzeros+aroon_list

for stock in range(len(TechIndicator)):
    TechIndicator[stock]["PVT"] = (TechIndicator[stock]['Momentum_1D']/ TechIndicator[stock]['Close'].shift(1))*TechIndicator[stock]['Volume']
    TechIndicator[stock]["PVT"] = TechIndicator[stock]["PVT"]-TechIndicator[stock]["PVT"].shift(1)
    TechIndicator[stock]["PVT"] = TechIndicator[stock]["PVT"].fillna(0)

def abands(df):
    #df['AB_Middle_Band'] = pd.rolling_mean(df['Close'], 20)
    df['AB_Middle_Band'] = df['Close'].rolling(window = 20, center=False).mean()
    # High * ( 1 + 4 * (High - Low) / (High + Low))
    df['aupband'] = df['High'] * (1 + 4 * (df['High']-df['Low'])/(df['High']+df['Low']))
    df['AB_Upper_Band'] = df['aupband'].rolling(window=20, center=False).mean()
    # Low *(1 - 4 * (High - Low)/ (High + Low))
    df['adownband'] = df['Low'] * (1 - 4 * (df['High']-df['Low'])/(df['High']+df['Low']))
    df['AB_Lower_Band'] = df['adownband'].rolling(window=20, center=False).mean()

for stock in range(len(TechIndicator)):
    abands(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)
TechIndicator[0].tail()

columns2Drop = ['Momentum_1D', 'aupband', 'adownband']
for stock in range(len(TechIndicator)):
    TechIndicator[stock] = TechIndicator[stock].drop(labels = columns2Drop, axis=1)
TechIndicator[0].head()

def STOK(df, n):
    df['STOK'] = ((df['Close'] - df['Low'].rolling(window=n, center=False).mean()) / (df['High'].rolling(window=n, center=False).max() - df['Low'].rolling(window=n, center=False).min())) * 100
    df['STOD'] = df['STOK'].rolling(window = 3, center=False).mean()

for stock in range(len(TechIndicator)):
    STOK(TechIndicator[stock], 4)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def CMFlow(df, tf):
    CHMF = []
    MFMs = []
    MFVs = []
    x = tf
    
    while x < len(df['Date']):
        PeriodVolume = 0
        volRange = df['Volume'][x-tf:x]
        for eachVol in volRange:
            PeriodVolume += eachVol
        
        MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
        MFV = MFM*PeriodVolume
        
        MFMs.append(MFM)
        MFVs.append(MFV)
        x+=1
    
    y = tf
    while y < len(MFVs):
        PeriodVolume = 0
        volRange = df['Volume'][x-tf:x]
        for eachVol in volRange:
            PeriodVolume += eachVol
        consider = MFVs[y-tf:y]
        tfsMFV = 0
        
        for eachMFV in consider:
            tfsMFV += eachMFV
        
        tfsCMF = tfsMFV/PeriodVolume
        CHMF.append(tfsCMF)
        y+=1
    return CHMF

for stock in range(len(TechIndicator)):
    listofzeros = [0] * 40
    CHMF = CMFlow(TechIndicator[stock], 20)
    if len(CHMF)==0:
        CHMF = [0] * TechIndicator[stock].shape[0]
        TechIndicator[stock]['Chaikin_MF'] = CHMF
    else:
        TechIndicator[stock]['Chaikin_MF'] = listofzeros+CHMF

def psar(df, iaf = 0.02, maxaf = 0.2):
    length = len(df)
    dates = (df['Date'])
    high = (df['High'])
    low = (df['Low'])
    close = (df['Close'])
    psar = df['Close'][0:len(df['Close'])]
    psarbull = [None] * length
    psarbear = [None] * length
    bull = True
    af = iaf
    ep = df['Low'][0]
    hp = df['High'][0]
    lp = df['Low'][0]
    for i in range(2,length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if df['Low'][i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = df['Low'][i]
                af = iaf
        else:
            if df['High'][i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = df['High'][i]
                af = iaf
        if not reverse:
            if bull:
                if df['High'][i] > hp:
                    hp = df['High'][i]
                    af = min(af + iaf, maxaf)
                if df['Low'][i - 1] < psar[i]:
                    psar[i] = df['Low'][i - 1]
                if df['Low'][i - 2] < psar[i]:
                    psar[i] = df['Low'][i - 2]
            else:
                if df['Low'][i] < lp:
                    lp = df['Low'][i]
                    af = min(af + iaf, maxaf)
                if df['High'][i - 1] > psar[i]:
                    psar[i] = df['High'][i - 1]
                if df['High'][i - 2] > psar[i]:
                    psar[i] = df['High'][i - 2]
        if bull:
            psarbull[i] = psar[i]
        else:
            psarbear[i] = psar[i]
    #return {"dates":dates, "high":high, "low":low, "close":close, "psar":psar, "psarbear":psarbear, "psarbull":psarbull}
    #return psar, psarbear, psarbull
    df['psar'] = psar
    #df['psarbear'] = psarbear
    #df['psarbull'] = psarbull

for stock in range(len(TechIndicator)):
    psar(TechIndicator[stock])

# ROC = [(Close - Close n periods ago) / (Close n periods ago)] * 100
for stock in range(len(TechIndicator)):
    TechIndicator[stock]['ROC'] = ((TechIndicator[stock]['Close'] - TechIndicator[stock]['Close'].shift(12))/(TechIndicator[stock]['Close'].shift(12)))*100
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['VWAP'] = np.cumsum(TechIndicator[stock]['Volume'] * (TechIndicator[stock]['High'] + TechIndicator[stock]['Low'])/2) / np.cumsum(TechIndicator[stock]['Volume'])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['Momentum'] = TechIndicator[stock]['Close'] - TechIndicator[stock]['Close'].shift(4)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def CCI(df, n, constant):
    TP = (df['High'] + df['Low'] + df['Close']) / 3
    CCI = pd.Series((TP - TP.rolling(window=n, center=False).mean()) / (constant * TP.rolling(window=n, center=False).std())) #, name = 'CCI_' + str(n))
    return CCI

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['CCI'] = CCI(TechIndicator[stock], 20, 0.015)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    new = (TechIndicator[stock]['Volume'] * (~TechIndicator[stock]['Close'].diff().le(0) * 2 -1)).cumsum()
    TechIndicator[stock]['OBV'] = new

#Keltner Channel  
def KELCH(df, n):  
    KelChM = pd.Series(((df['High'] + df['Low'] + df['Close']) / 3).rolling(window =n, center=False).mean(), name = 'KelChM_' + str(n))  
    KelChU = pd.Series(((4 * df['High'] - 2 * df['Low'] + df['Close']) / 3).rolling(window =n, center=False).mean(), name = 'KelChU_' + str(n))  
    KelChD = pd.Series(((-2 * df['High'] + 4 * df['Low'] + df['Close']) / 3).rolling(window =n, center=False).mean(), name = 'KelChD_' + str(n))    
    return KelChM, KelChD, KelChU

for stock in range(len(TechIndicator)):
    KelchM, KelchD, KelchU = KELCH(TechIndicator[stock], 14)
    TechIndicator[stock]['Kelch_Upper'] = KelchU
    TechIndicator[stock]['Kelch_Middle'] = KelchM
    TechIndicator[stock]['Kelch_Down'] = KelchD
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['EMA'] = TechIndicator[stock]['Close'].ewm(span=3,min_periods=0,adjust=True,ignore_na=False).mean()
    
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['TEMA'] = (3 * TechIndicator[stock]['EMA'] - 3 * TechIndicator[stock]['EMA'] * TechIndicator[stock]['EMA']) + (TechIndicator[stock]['EMA']*TechIndicator[stock]['EMA']*TechIndicator[stock]['EMA'])

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['HL'] = TechIndicator[stock]['High'] - TechIndicator[stock]['Low']
    TechIndicator[stock]['absHC'] = abs(TechIndicator[stock]['High'] - TechIndicator[stock]['Close'].shift(1))
    TechIndicator[stock]['absLC'] = abs(TechIndicator[stock]['Low'] - TechIndicator[stock]['Close'].shift(1))
    TechIndicator[stock]['TR'] = TechIndicator[stock][['HL','absHC','absLC']].max(axis=1)
    TechIndicator[stock]['ATR'] = TechIndicator[stock]['TR'].rolling(window=14).mean()
    TechIndicator[stock]['NATR'] = (TechIndicator[stock]['ATR'] / TechIndicator[stock]['Close']) *100
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def DMI(df, period):
    df['UpMove'] = df['High'] - df['High'].shift(1)
    df['DownMove'] = df['Low'].shift(1) - df['Low']
    df['Zero'] = 0

    df['PlusDM'] = np.where((df['UpMove'] > df['DownMove']) & (df['UpMove'] > df['Zero']), df['UpMove'], 0)
    df['MinusDM'] = np.where((df['UpMove'] < df['DownMove']) & (df['DownMove'] > df['Zero']), df['DownMove'], 0)

    df['plusDI'] = 100 * (df['PlusDM']/df['ATR']).ewm(span=period,min_periods=0,adjust=True,ignore_na=False).mean()
    df['minusDI'] = 100 * (df['MinusDM']/df['ATR']).ewm(span=period,min_periods=0,adjust=True,ignore_na=False).mean()

    df['ADX'] = 100 * (abs((df['plusDI'] - df['minusDI'])/(df['plusDI'] + df['minusDI']))).ewm(span=period,min_periods=0,adjust=True,ignore_na=False).mean()

for stock in range(len(TechIndicator)):
    DMI(TechIndicator[stock], 14)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

columns2Drop = ['UpMove', 'DownMove', 'ATR', 'PlusDM', 'MinusDM', 'Zero', 'EMA', 'HL', 'absHC', 'absLC', 'TR']
for stock in range(len(TechIndicator)):
    TechIndicator[stock] = TechIndicator[stock].drop(labels = columns2Drop, axis=1)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['26_ema'] = TechIndicator[stock]['Close'].ewm(span=26,min_periods=0,adjust=True,ignore_na=False).mean()
    TechIndicator[stock]['12_ema'] = TechIndicator[stock]['Close'].ewm(span=12,min_periods=0,adjust=True,ignore_na=False).mean()
    TechIndicator[stock]['MACD'] = TechIndicator[stock]['12_ema'] - TechIndicator[stock]['26_ema']
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def MFI(df):
    # typical price
    df['tp'] = (df['High']+df['Low']+df['Close'])/3
    #raw money flow
    df['rmf'] = df['tp'] * df['Volume']
    
    # positive and negative money flow
    df['pmf'] = np.where(df['tp'] > df['tp'].shift(1), df['tp'], 0)
    df['nmf'] = np.where(df['tp'] < df['tp'].shift(1), df['tp'], 0)

    # money flow ratio
    df['mfr'] = df['pmf'].rolling(window=14,center=False).sum()/df['nmf'].rolling(window=14,center=False).sum()
    df['Money_Flow_Index'] = 100 - 100 / (1 + df['mfr'])

for stock in range(len(TechIndicator)):
    MFI(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def ichimoku(df):
    # Turning Line
    period9_high = df['High'].rolling(window=9,center=False).max()
    period9_low = df['Low'].rolling(window=9,center=False).min()
    df['turning_line'] = (period9_high + period9_low) / 2
    
    # Standard Line
    period26_high = df['High'].rolling(window=26,center=False).max()
    period26_low = df['Low'].rolling(window=26,center=False).min()
    df['standard_line'] = (period26_high + period26_low) / 2
    
    # Leading Span 1
    df['ichimoku_span1'] = ((df['turning_line'] + df['standard_line']) / 2).shift(26)
    
    # Leading Span 2
    period52_high = df['High'].rolling(window=52,center=False).max()
    period52_low = df['Low'].rolling(window=52,center=False).min()
    df['ichimoku_span2'] = ((period52_high + period52_low) / 2).shift(26)
    
    # The most current closing price plotted 22 time periods behind (optional)
    df['chikou_span'] = df['Close'].shift(-22) # 22 according to investopedia

for stock in range(len(TechIndicator)):
    ichimoku(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def WillR(df):
    highest_high = df['High'].rolling(window=14,center=False).max()
    lowest_low = df['Low'].rolling(window=14,center=False).min()
    df['WillR'] = (-100) * ((highest_high - df['Close']) / (highest_high - lowest_low))

for stock in range(len(TechIndicator)):
    WillR(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def MINMAX(df):
    df['MIN_Volume'] = df['Volume'].rolling(window=14,center=False).min()
    df['MAX_Volume'] = df['Volume'].rolling(window=14,center=False).max()

for stock in range(len(TechIndicator)):
    MINMAX(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def KAMA(price, n=10, pow1=2, pow2=30):
    ''' kama indicator '''    
    ''' accepts pandas dataframe of prices '''

    absDiffx = abs(price - price.shift(1) )  

    ER_num = abs( price - price.shift(n) )
    ER_den = absDiffx.rolling(window=n,center=False).sum()
    ER = ER_num / ER_den

    sc = ( ER*(2.0/(pow1+1)-2.0/(pow2+1.0))+2/(pow2+1.0) ) ** 2.0


    answer = np.zeros(sc.size)
    N = len(answer)
    first_value = True

    for i in range(N):
        if sc[i] != sc[i]:
            answer[i] = np.nan
        else:
            if first_value:
                answer[i] = price[i]
                first_value = False
            else:
                answer[i] = answer[i-1] + sc[i] * (price[i] - answer[i-1])
    return answer

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['KAMA'] = KAMA(TechIndicator[stock]['Close'])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

columns2Drop = ['26_ema', '12_ema','tp','rmf','pmf','nmf','mfr']
for stock in range(len(TechIndicator)):
    TechIndicator[stock] = TechIndicator[stock].drop(labels = columns2Drop, axis=1)

def get_data(stock):
    y = []
    stock['ANSWER'] = pd.Series(index=stock.index)
    extra_columns = ['KAMA', 'OpenInt', 'RSI_14D', 'Volume_plain', 'BB_Middle_Band', 'BB_Upper_Band', 'BB_Lower_Band', 'Aroon_Oscillator', 'PVT', 'AB_Middle_Band', 'AB_Upper_Band', 'AB_Lower_Band', 'STOK', 'STOD', 'Chaikin_MF', 'psar', 'ROC', 'VWAP', 'Momentum', 'CCI', 'OBV', 'Kelch_Upper', 'Kelch_Middle', 'Kelch_Down', 'TEMA', 'NATR', 'plusDI', 'minusDI', 'ADX', 'MACD', 'Money_Flow_Index', 'turning_line', 'standard_line', 'ichimoku_span1', 'ichimoku_span2', 'chikou_span', 'WillR', 'MIN_Volume', 'MAX_Volume']
    x = stock.drop(columns=['Date', 'Label', 'ANSWER']).iloc[:-10]
    # x = stock['Close'].iloc[:-10]
    for row in range(len(stock) - 10):
        condition = 0
        if stock['Close'][row] < stock['Close'][row + 1]:
            condition = 1
            stock.at[row, 'ANSWER'] = 1
        elif stock['Close'][row] > stock['Close'][row + 1]:
            condition = 2
            stock.at[row, 'ANSWER'] = 2

        y.append(condition)
    y = pd.Series(y, name='Label')
    return x, y

def train_ai(lst):
    all_x = []
    all_y = []
    for stock in range(len(lst)):
        x, y = get_data(lst[stock])
        all_x.append(x)
        all_y.append(y)
        lst[stock] = lst[stock].fillna(0, inplace=True)

    
    all_x = pd.concat(all_x, ignore_index=True)
    all_y = pd.concat(all_y, ignore_index=True)
    columns = [column for column in all_x.columns]
    
    

    tscv = TimeSeriesSplit(n_splits=5)
    model = DecisionTreeClassifier()

    # Use cross-validation to check for overfitting
    cv_scores = cross_val_score(model, all_x, all_y, cv=tscv)
    print(f"Cross-validation scores: {cv_scores}")
    print(f"Mean CV score: {cv_scores.mean()}")

    for train_index, test_index in tscv.split(all_x):
        # print('test', train_index, test_index)
        x_train, x_test = all_x.iloc[train_index], all_x.iloc[test_index]
        y_train, y_test = all_y.iloc[train_index], all_y.iloc[test_index]
        model.fit(x_train, y_train)
        predictions = model.predict(x_test)
        score = accuracy_score(y_test, predictions)
        cm = confusion_matrix(y_test, predictions)
        print(f"Test accuracy score: {score}")
        print(f"Confusion Matrix:\n{cm}")
    
        for i in range(len(x_test) - 1):
            pred = model.predict(x_test.iloc[i:i+1])
            actual = y_test.iloc[i]
            # if pred != actual:
            print(f'Price: {x_test["Close"].iloc[i]:.2f}, Prediction: {pred[0]}, Actual: {actual} --- Next Price: {x_test["Close"].iloc[i+1]:.2f}')

    return model
    

trading_bot= train_ai(TechIndicator)
joblib.dump(trading_bot, 'trading_bot.joblib')


# trading_bot = joblib.load('trading_bot.joblib')
# Out:
# C:\Users\trygv\AppData\Local\Temp\ipykernel_22376\3906690086.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_22376\3906690086.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_22376\3906690086.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_22376\3906690086.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_22376\3906690086.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_22376\3906690086.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# Cross-validation scores: [0.90601185 0.88865368 0.89034716 0.9081287  0.81837426]
# Mean CV score: 0.8823031329381881
# Test accuracy score: 0.8839966130397968
# Confusion Matrix:
# [[   8   29   30]
#  [ 112 1076   25]
#  [  65   13 1004]]
# Price: 11.68, Prediction: 0, Actual: 2 --- Next Price: 11.62
# Price: 11.62, Prediction: 2, Actual: 2 --- Next Price: 11.56
# Price: 11.56, Prediction: 2, Actual: 2 --- Next Price: 11.51
# Price: 11.51, Prediction: 2, Actual: 2 --- Next Price: 11.46
# Price: 11.46, Prediction: 2, Actual: 2 --- Next Price: 11.41
# Price: 11.41, Prediction: 0, Actual: 2 --- Next Price: 11.37
# Price: 11.37, Prediction: 2, Actual: 2 --- Next Price: 11.32
# Price: 11.32, Prediction: 2, Actual: 2 --- Next Price: 10.67
# Price: 10.67, Prediction: 1, Actual: 1 --- Next Price: 10.69
# Price: 10.69, Prediction: 1, Actual: 1 --- Next Price: 10.72
# Price: 10.72, Prediction: 1, Actual: 1 --- Next Price: 10.76
# Price: 10.76, Prediction: 1, Actual: 1 --- Next Price: 10.81
# Price: 10.81, Prediction: 1, Actual: 1 --- Next Price: 10.85
# Price: 10.85, Prediction: 1, Actual: 1 --- Next Price: 10.91
# Price: 10.91, Prediction: 1, Actual: 1 --- Next Price: 10.96
# Price: 10.96, Prediction: 1, Actual: 1 --- Next Price: 11.01
# Price: 11.01, Prediction: 1, Actual: 1 --- Next Price: 11.06
# Price: 11.06, Prediction: 1, Actual: 1 --- Next Price: 11.16
# Price: 11.16, Prediction: 1, Actual: 1 --- Next Price: 11.25
# Price: 11.25, Prediction: 1, Actual: 1 --- Next Price: 11.37
# Price: 11.37, Prediction: 1, Actual: 1 --- Next Price: 11.47
# Price: 11.47, Prediction: 1, Actual: 1 --- Next Price: 11.56
# Price: 11.56, Prediction: 1, Actual: 1 --- Next Price: 11.66
# Price: 11.66, Prediction: 1, Actual: 1 --- Next Price: 11.74
# Price: 11.74, Prediction: 1, Actual: 1 --- Next Price: 11.84
# Price: 11.84, Prediction: 1, Actual: 1 --- Next Price: 11.92
# Price: 11.92, Prediction: 1, Actual: 1 --- Next Price: 12.05
# Price: 12.05, Prediction: 1, Actual: 1 --- Next Price: 12.15
# Price: 12.15, Prediction: 1, Actual: 1 --- Next Price: 12.24
# Price: 12.24, Prediction: 1, Actual: 1 --- Next Price: 12.24
# Price: 12.24, Prediction: 1, Actual: 0 --- Next Price: 12.24
# Price: 12.24, Prediction: 1, Actual: 1 --- Next Price: 12.35
# Price: 12.35, Prediction: 1, Actual: 1 --- Next Price: 12.80
# Price: 12.80, Prediction: 2, Actual: 2 --- Next Price: 12.79
# Price: 12.79, Prediction: 2, Actual: 2 --- Next Price: 12.79
# Price: 12.79, Prediction: 2, Actual: 2 --- Next Price: 12.44
# Price: 12.44, Prediction: 1, Actual: 2 --- Next Price: 12.43
# Price: 12.43, Prediction: 1, Actual: 0 --- Next Price: 12.43
# Price: 12.43, Prediction: 1, Actual: 1 --- Next Price: 12.45
# Price: 12.45, Prediction: 1, Actual: 1 --- Next Price: 12.47
# Price: 12.47, Prediction: 0, Actual: 1 --- Next Price: 12.97
# Price: 12.97, Prediction: 2, Actual: 2 --- Next Price: 12.36
# Price: 12.36, Prediction: 0, Actual: 1 --- Next Price: 13.17
# Price: 13.17, Prediction: 2, Actual: 0 --- Next Price: 13.17
# Price: 13.17, Prediction: 2, Actual: 2 --- Next Price: 13.15
# Price: 13.15, Prediction: 2, Actual: 2 --- Next Price: 13.13
# Price: 13.13, Prediction: 0, Actual: 2 --- Next Price: 13.11
# Price: 13.11, Prediction: 2, Actual: 2 --- Next Price: 12.23
# Price: 12.23, Prediction: 1, Actual: 1 --- Next Price: 12.25
# Price: 12.25, Prediction: 1, Actual: 1 --- Next Price: 12.27
# Price: 12.27, Prediction: 1, Actual: 1 --- Next Price: 12.29
# Price: 12.29, Prediction: 1, Actual: 1 --- Next Price: 13.23
# Price: 13.23, Prediction: 0, Actual: 2 --- Next Price: 13.21
# Price: 13.21, Prediction: 2, Actual: 2 --- Next Price: 13.19
# Price: 13.19, Prediction: 2, Actual: 2 --- Next Price: 13.17
# Price: 13.17, Prediction: 2, Actual: 2 --- Next Price: 13.15
# Price: 13.15, Prediction: 2, Actual: 2 --- Next Price: 13.13
# Price: 13.13, Prediction: 2, Actual: 2 --- Next Price: 12.22
# Price: 12.22, Prediction: 1, Actual: 1 --- Next Price: 12.24
# Price: 12.24, Prediction: 1, Actual: 1 --- Next Price: 12.26
# Price: 12.26, Prediction: 1, Actual: 1 --- Next Price: 12.27
# Price: 12.27, Prediction: 1, Actual: 1 --- Next Price: 12.29
# Price: 12.29, Prediction: 1, Actual: 1 --- Next Price: 12.31
# Price: 12.31, Prediction: 1, Actual: 1 --- Next Price: 12.32
# Price: 12.32, Prediction: 1, Actual: 1 --- Next Price: 12.34
# Price: 12.34, Prediction: 1, Actual: 1 --- Next Price: 12.36
# Price: 12.36, Prediction: 1, Actual: 1 --- Next Price: 12.39
# Price: 12.39, Prediction: 1, Actual: 1 --- Next Price: 12.42
# Price: 12.42, Prediction: 1, Actual: 1 --- Next Price: 12.48
# Price: 12.48, Prediction: 1, Actual: 1 --- Next Price: 12.54
# Price: 12.54, Prediction: 1, Actual: 1 --- Next Price: 12.59
# Price: 12.59, Prediction: 1, Actual: 1 --- Next Price: 13.43
# Price: 13.43, Prediction: 2, Actual: 2 --- Next Price: 13.41
# Price: 13.41, Prediction: 2, Actual: 2 --- Next Price: 13.38
# Price: 13.38, Prediction: 2, Actual: 2 --- Next Price: 13.31
# Price: 13.31, Prediction: 2, Actual: 2 --- Next Price: 13.21
# Price: 13.21, Prediction: 2, Actual: 2 --- Next Price: 13.05
# Price: 13.05, Prediction: 2, Actual: 2 --- Next Price: 12.87
# Price: 12.87, Prediction: 2, Actual: 2 --- Next Price: 12.68
# Price: 12.68, Prediction: 2, Actual: 2 --- Next Price: 12.56
# Price: 12.56, Prediction: 2, Actual: 2 --- Next Price: 11.38
# Price: 11.38, Prediction: 1, Actual: 2 --- Next Price: 11.05
# Price: 11.05, Prediction: 1, Actual: 0 --- Next Price: 11.05
# Price: 11.05, Prediction: 1, Actual: 1 --- Next Price: 11.16
# Price: 11.16, Prediction: 1, Actual: 1 --- Next Price: 11.27
# Price: 11.27, Prediction: 1, Actual: 1 --- Next Price: 11.38
# Price: 11.38, Prediction: 1, Actual: 1 --- Next Price: 11.48
# Price: 11.48, Prediction: 1, Actual: 1 --- Next Price: 11.59
# Price: 11.59, Prediction: 1, Actual: 1 --- Next Price: 11.69
# Price: 11.69, Prediction: 1, Actual: 1 --- Next Price: 11.79
# Price: 11.79, Prediction: 1, Actual: 1 --- Next Price: 11.88
# Price: 11.88, Prediction: 1, Actual: 1 --- Next Price: 11.98
# Price: 11.98, Prediction: 1, Actual: 1 --- Next Price: 12.07
# Price: 12.07, Prediction: 1, Actual: 1 --- Next Price: 12.16
# Price: 12.16, Prediction: 1, Actual: 1 --- Next Price: 12.25
# Price: 12.25, Prediction: 1, Actual: 1 --- Next Price: 12.34
# Price: 12.34, Prediction: 1, Actual: 1 --- Next Price: 12.43
# Price: 12.43, Prediction: 1, Actual: 1 --- Next Price: 12.51
# Price: 12.51, Prediction: 1, Actual: 1 --- Next Price: 12.60
# Price: 12.60, Prediction: 1, Actual: 1 --- Next Price: 12.68
# Price: 12.68, Prediction: 1, Actual: 1 --- Next Price: 12.76
# Price: 12.76, Prediction: 1, Actual: 1 --- Next Price: 12.83
# Price: 12.83, Prediction: 1, Actual: 1 --- Next Price: 12.91
# Price: 12.91, Prediction: 1, Actual: 1 --- Next Price: 12.99
# Price: 12.99, Prediction: 1, Actual: 1 --- Next Price: 13.06
# Price: 13.06, Prediction: 1, Actual: 1 --- Next Price: 16.65
# Price: 16.65, Prediction: 2, Actual: 2 --- Next Price: 16.58
# Price: 16.58, Prediction: 2, Actual: 2 --- Next Price: 16.41
# Price: 16.41, Prediction: 2, Actual: 2 --- Next Price: 16.25
# Price: 16.25, Prediction: 0, Actual: 2 --- Next Price: 16.10
# Price: 16.10, Prediction: 2, Actual: 2 --- Next Price: 15.87
# Price: 15.87, Prediction: 2, Actual: 2 --- Next Price: 15.57
# Price: 15.57, Prediction: 2, Actual: 2 --- Next Price: 15.29
# Price: 15.29, Prediction: 2, Actual: 2 --- Next Price: 15.04
# Price: 15.04, Prediction: 0, Actual: 2 --- Next Price: 14.80
# Price: 14.80, Prediction: 2, Actual: 2 --- Next Price: 14.59
# Price: 14.59, Prediction: 0, Actual: 2 --- Next Price: 14.39
# Price: 14.39, Prediction: 2, Actual: 2 --- Next Price: 14.20
# Price: 14.20, Prediction: 0, Actual: 2 --- Next Price: 14.05
# Price: 14.05, Prediction: 2, Actual: 2 --- Next Price: 13.89
# Price: 13.89, Prediction: 0, Actual: 2 --- Next Price: 13.75
# Price: 13.75, Prediction: 2, Actual: 2 --- Next Price: 13.62
# Price: 13.62, Prediction: 2, Actual: 2 --- Next Price: 13.50
# Price: 13.50, Prediction: 2, Actual: 2 --- Next Price: 13.39
# Price: 13.39, Prediction: 2, Actual: 2 --- Next Price: 12.10
# Price: 12.10, Prediction: 1, Actual: 1 --- Next Price: 12.13
# Price: 12.13, Prediction: 1, Actual: 1 --- Next Price: 12.19
# Price: 12.19, Prediction: 1, Actual: 1 --- Next Price: 12.26
# Price: 12.26, Prediction: 1, Actual: 1 --- Next Price: 12.35
# Price: 12.35, Prediction: 1, Actual: 1 --- Next Price: 12.49
# Price: 12.49, Prediction: 1, Actual: 1 --- Next Price: 12.62
# Price: 12.62, Prediction: 1, Actual: 1 --- Next Price: 12.77
# Price: 12.77, Prediction: 1, Actual: 1 --- Next Price: 12.91
# Price: 12.91, Prediction: 1, Actual: 1 --- Next Price: 13.03
# Price: 13.03, Prediction: 1, Actual: 1 --- Next Price: 13.14
# Price: 13.14, Prediction: 1, Actual: 1 --- Next Price: 14.14
# Price: 14.14, Prediction: 2, Actual: 2 --- Next Price: 14.12
# Price: 14.12, Prediction: 2, Actual: 2 --- Next Price: 14.06
# Price: 14.06, Prediction: 2, Actual: 2 --- Next Price: 14.01
# Price: 14.01, Prediction: 2, Actual: 2 --- Next Price: 13.96
# Price: 13.96, Prediction: 2, Actual: 2 --- Next Price: 13.91
# Price: 13.91, Prediction: 2, Actual: 2 --- Next Price: 13.86
# Price: 13.86, Prediction: 2, Actual: 2 --- Next Price: 13.82
# Price: 13.82, Prediction: 2, Actual: 2 --- Next Price: 13.77
# Price: 13.77, Prediction: 2, Actual: 2 --- Next Price: 13.73
# Price: 13.73, Prediction: 2, Actual: 2 --- Next Price: 13.65
# Price: 13.65, Prediction: 2, Actual: 2 --- Next Price: 13.51
# Price: 13.51, Prediction: 2, Actual: 2 --- Next Price: 13.34
# Price: 13.34, Prediction: 2, Actual: 2 --- Next Price: 13.18
# Price: 13.18, Prediction: 2, Actual: 2 --- Next Price: 13.04
# Price: 13.04, Prediction: 2, Actual: 2 --- Next Price: 12.92
# Price: 12.92, Prediction: 2, Actual: 2 --- Next Price: 12.77
# Price: 12.77, Prediction: 2, Actual: 2 --- Next Price: 12.58
# Price: 12.58, Prediction: 2, Actual: 2 --- Next Price: 12.40
# Price: 12.40, Prediction: 2, Actual: 2 --- Next Price: 12.24
# Price: 12.24, Prediction: 2, Actual: 2 --- Next Price: 12.11
# Price: 12.11, Prediction: 2, Actual: 2 --- Next Price: 11.14
# Price: 11.14, Prediction: 0, Actual: 1 --- Next Price: 11.96
# Price: 11.96, Prediction: 2, Actual: 0 --- Next Price: 11.96
# Price: 11.96, Prediction: 2, Actual: 2 --- Next Price: 11.91
# Price: 11.91, Prediction: 2, Actual: 2 --- Next Price: 11.87
# Price: 11.87, Prediction: 2, Actual: 2 --- Next Price: 11.83
# Price: 11.83, Prediction: 2, Actual: 2 --- Next Price: 11.76
# Price: 11.76, Prediction: 2, Actual: 2 --- Next Price: 11.67
# Price: 11.67, Prediction: 2, Actual: 2 --- Next Price: 11.59
# Price: 11.59, Prediction: 2, Actual: 2 --- Next Price: 11.52
# Price: 11.52, Prediction: 2, Actual: 2 --- Next Price: 11.39
# Price: 11.39, Prediction: 2, Actual: 2 --- Next Price: 11.21
# Price: 11.21, Prediction: 2, Actual: 2 --- Next Price: 11.06
# Price: 11.06, Prediction: 2, Actual: 2 --- Next Price: 9.92
# Price: 9.92, Prediction: 1, Actual: 1 --- Next Price: 9.94
# Price: 9.94, Prediction: 1, Actual: 1 --- Next Price: 9.99
# Price: 9.99, Prediction: 1, Actual: 1 --- Next Price: 10.06
# Price: 10.06, Prediction: 1, Actual: 1 --- Next Price: 10.13
# Price: 10.13, Prediction: 1, Actual: 1 --- Next Price: 10.19
# Price: 10.19, Prediction: 1, Actual: 1 --- Next Price: 11.18
# Price: 11.18, Prediction: 2, Actual: 2 --- Next Price: 11.16
# Price: 11.16, Prediction: 2, Actual: 2 --- Next Price: 11.14
# Price: 11.14, Prediction: 2, Actual: 2 --- Next Price: 10.19
# Price: 10.19, Prediction: 1, Actual: 1 --- Next Price: 10.22
# Price: 10.22, Prediction: 1, Actual: 1 --- Next Price: 10.29
# Price: 10.29, Prediction: 1, Actual: 1 --- Next Price: 10.40
# Price: 10.40, Prediction: 1, Actual: 1 --- Next Price: 10.50
# Price: 10.50, Prediction: 1, Actual: 1 --- Next Price: 10.63
# Price: 10.63, Prediction: 1, Actual: 1 --- Next Price: 10.76
# Price: 10.76, Prediction: 1, Actual: 1 --- Next Price: 10.87
# Price: 10.87, Prediction: 1, Actual: 1 --- Next Price: 12.18
# Price: 12.18, Prediction: 0, Actual: 2 --- Next Price: 12.16
# Price: 12.16, Prediction: 2, Actual: 2 --- Next Price: 12.09
# Price: 12.09, Prediction: 2, Actual: 2 --- Next Price: 11.98
# Price: 11.98, Prediction: 2, Actual: 2 --- Next Price: 11.82
# Price: 11.82, Prediction: 2, Actual: 2 --- Next Price: 11.62
# Price: 11.62, Prediction: 2, Actual: 2 --- Next Price: 11.45
# Price: 11.45, Prediction: 2, Actual: 2 --- Next Price: 11.29
# Price: 11.29, Prediction: 2, Actual: 2 --- Next Price: 11.14
# Price: 11.14, Prediction: 2, Actual: 2 --- Next Price: 10.98
# Price: 10.98, Prediction: 2, Actual: 2 --- Next Price: 10.78
# Price: 10.78, Prediction: 2, Actual: 2 --- Next Price: 10.52
# Price: 10.52, Prediction: 2, Actual: 2 --- Next Price: 10.18
# Price: 10.18, Prediction: 2, Actual: 2 --- Next Price: 9.85
# Price: 9.85, Prediction: 2, Actual: 2 --- Next Price: 8.50
# Price: 8.50, Prediction: 0, Actual: 1 --- Next Price: 8.53
# Price: 8.53, Prediction: 0, Actual: 1 --- Next Price: 8.59
# Price: 8.59, Prediction: 1, Actual: 1 --- Next Price: 8.71
# Price: 8.71, Prediction: 1, Actual: 1 --- Next Price: 8.88
# Price: 8.88, Prediction: 1, Actual: 1 --- Next Price: 9.11
# Price: 9.11, Prediction: 1, Actual: 1 --- Next Price: 9.36
# Price: 9.36, Prediction: 1, Actual: 1 --- Next Price: 9.58
# Price: 9.58, Prediction: 1, Actual: 1 --- Next Price: 9.77
# Price: 9.77, Prediction: 1, Actual: 1 --- Next Price: 9.94
# Price: 9.94, Prediction: 1, Actual: 1 --- Next Price: 11.19
# Price: 11.19, Prediction: 2, Actual: 2 --- Next Price: 11.17
# Price: 11.17, Prediction: 2, Actual: 2 --- Next Price: 11.11
# Price: 11.11, Prediction: 2, Actual: 2 --- Next Price: 11.06
# Price: 11.06, Prediction: 2, Actual: 2 --- Next Price: 11.00
# Price: 11.00, Prediction: 2, Actual: 2 --- Next Price: 10.95
# Price: 10.95, Prediction: 2, Actual: 2 --- Next Price: 10.90
# Price: 10.90, Prediction: 2, Actual: 2 --- Next Price: 10.86
# Price: 10.86, Prediction: 2, Actual: 2 --- Next Price: 10.81
# Price: 10.81, Prediction: 2, Actual: 2 --- Next Price: 10.77
# Price: 10.77, Prediction: 2, Actual: 2 --- Next Price: 10.73
# Price: 10.73, Prediction: 2, Actual: 2 --- Next Price: 10.67
# Price: 10.67, Prediction: 2, Actual: 2 --- Next Price: 9.71
# Price: 9.71, Prediction: 1, Actual: 1 --- Next Price: 9.73
# Price: 9.73, Prediction: 1, Actual: 1 --- Next Price: 9.79
# Price: 9.79, Prediction: 1, Actual: 1 --- Next Price: 9.84
# Price: 9.84, Prediction: 1, Actual: 1 --- Next Price: 9.93
# Price: 9.93, Prediction: 1, Actual: 1 --- Next Price: 10.08
# Price: 10.08, Prediction: 1, Actual: 1 --- Next Price: 10.28
# Price: 10.28, Prediction: 1, Actual: 1 --- Next Price: 10.47
# Price: 10.47, Prediction: 1, Actual: 1 --- Next Price: 10.63
# Price: 10.63, Prediction: 1, Actual: 1 --- Next Price: 10.79
# Price: 10.79, Prediction: 1, Actual: 1 --- Next Price: 12.14
# Price: 12.14, Prediction: 2, Actual: 2 --- Next Price: 12.12
# Price: 12.12, Prediction: 2, Actual: 2 --- Next Price: 12.09
# Price: 12.09, Prediction: 2, Actual: 0 --- Next Price: 12.09
# Price: 12.09, Prediction: 2, Actual: 2 --- Next Price: 12.07
# Price: 12.07, Prediction: 2, Actual: 2 --- Next Price: 12.05
# Price: 12.05, Prediction: 2, Actual: 2 --- Next Price: 12.00
# Price: 12.00, Prediction: 2, Actual: 2 --- Next Price: 11.95
# Price: 11.95, Prediction: 2, Actual: 2 --- Next Price: 10.78
# Price: 10.78, Prediction: 1, Actual: 0 --- Next Price: 10.78
# Price: 10.78, Prediction: 1, Actual: 1 --- Next Price: 10.81
# Price: 10.81, Prediction: 1, Actual: 1 --- Next Price: 10.86
# Price: 10.86, Prediction: 1, Actual: 1 --- Next Price: 10.94
# Price: 10.94, Prediction: 1, Actual: 1 --- Next Price: 11.01
# Price: 11.01, Prediction: 1, Actual: 1 --- Next Price: 11.11
# Price: 11.11, Prediction: 1, Actual: 1 --- Next Price: 11.25
# Price: 11.25, Prediction: 1, Actual: 1 --- Next Price: 11.43
# Price: 11.43, Prediction: 1, Actual: 1 --- Next Price: 11.59
# Price: 11.59, Prediction: 1, Actual: 1 --- Next Price: 11.72
# Price: 11.72, Prediction: 1, Actual: 1 --- Next Price: 11.85
# Price: 11.85, Prediction: 1, Actual: 1 --- Next Price: 11.95
# Price: 11.95, Prediction: 2, Actual: 1 --- Next Price: 12.00
# Price: 12.00, Prediction: 1, Actual: 1 --- Next Price: 12.74
# Price: 12.74, Prediction: 2, Actual: 2 --- Next Price: 12.72
# Price: 12.72, Prediction: 2, Actual: 2 --- Next Price: 12.68
# Price: 12.68, Prediction: 2, Actual: 2 --- Next Price: 12.65
# Price: 12.65, Prediction: 2, Actual: 2 --- Next Price: 11.74
# Price: 11.74, Prediction: 1, Actual: 1 --- Next Price: 11.76
# Price: 11.76, Prediction: 0, Actual: 1 --- Next Price: 11.80
# Price: 11.80, Prediction: 1, Actual: 1 --- Next Price: 12.80
# Price: 12.80, Prediction: 2, Actual: 2 --- Next Price: 12.78
# Price: 12.78, Prediction: 2, Actual: 2 --- Next Price: 12.75
# Price: 12.75, Prediction: 2, Actual: 2 --- Next Price: 12.73
# Price: 12.73, Prediction: 2, Actual: 2 --- Next Price: 11.59
# Price: 11.59, Prediction: 1, Actual: 1 --- Next Price: 11.62
# Price: 11.62, Prediction: 1, Actual: 1 --- Next Price: 11.65
# Price: 11.65, Prediction: 1, Actual: 1 --- Next Price: 11.67
# Price: 11.67, Prediction: 1, Actual: 1 --- Next Price: 11.70
# Price: 11.70, Prediction: 1, Actual: 1 --- Next Price: 11.76
# Price: 11.76, Prediction: 1, Actual: 1 --- Next Price: 11.80
# Price: 11.80, Prediction: 1, Actual: 0 --- Next Price: 11.80
# Price: 11.80, Prediction: 1, Actual: 1 --- Next Price: 11.85
# Price: 11.85, Prediction: 1, Actual: 1 --- Next Price: 11.91
# Price: 11.91, Prediction: 1, Actual: 1 --- Next Price: 11.96
# Price: 11.96, Prediction: 1, Actual: 1 --- Next Price: 12.01
# Price: 12.01, Prediction: 1, Actual: 1 --- Next Price: 12.07
# Price: 12.07, Prediction: 1, Actual: 1 --- Next Price: 12.12
# Price: 12.12, Prediction: 1, Actual: 1 --- Next Price: 12.16
# Price: 12.16, Prediction: 1, Actual: 1 --- Next Price: 12.21
# Price: 12.21, Prediction: 1, Actual: 1 --- Next Price: 12.22
# Price: 12.22, Prediction: 1, Actual: 0 --- Next Price: 12.22
# Price: 12.22, Prediction: 1, Actual: 1 --- Next Price: 12.26
# Price: 12.26, Prediction: 1, Actual: 1 --- Next Price: 13.30
# Price: 13.30, Prediction: 0, Actual: 2 --- Next Price: 13.28
# Price: 13.28, Prediction: 2, Actual: 2 --- Next Price: 13.25
# Price: 13.25, Prediction: 2, Actual: 2 --- Next Price: 13.22
# Price: 13.22, Prediction: 2, Actual: 2 --- Next Price: 13.20
# Price: 13.20, Prediction: 2, Actual: 2 --- Next Price: 13.17
# Price: 13.17, Prediction: 0, Actual: 2 --- Next Price: 13.12
# Price: 13.12, Prediction: 2, Actual: 2 --- Next Price: 13.07
# Price: 13.07, Prediction: 2, Actual: 2 --- Next Price: 13.02
# Price: 13.02, Prediction: 2, Actual: 2 --- Next Price: 12.97
# Price: 12.97, Prediction: 2, Actual: 2 --- Next Price: 12.93
# Price: 12.93, Prediction: 2, Actual: 2 --- Next Price: 12.88
# Price: 12.88, Prediction: 2, Actual: 2 --- Next Price: 12.84
# Price: 12.84, Prediction: 2, Actual: 2 --- Next Price: 12.80
# Price: 12.80, Prediction: 2, Actual: 2 --- Next Price: 12.76
# Price: 12.76, Prediction: 2, Actual: 2 --- Next Price: 12.72
# Price: 12.72, Prediction: 2, Actual: 2 --- Next Price: 12.69
# Price: 12.69, Prediction: 2, Actual: 2 --- Next Price: 12.65
# Price: 12.65, Prediction: 2, Actual: 2 --- Next Price: 12.60
# Price: 12.60, Prediction: 2, Actual: 2 --- Next Price: 12.55
# Price: 12.55, Prediction: 2, Actual: 2 --- Next Price: 12.45
# Price: 12.45, Prediction: 2, Actual: 2 --- Next Price: 12.36
# Price: 12.36, Prediction: 0, Actual: 2 --- Next Price: 12.28
# Price: 12.28, Prediction: 2, Actual: 2 --- Next Price: 11.34
# Price: 11.34, Prediction: 1, Actual: 1 --- Next Price: 11.36
# Price: 11.36, Prediction: 1, Actual: 1 --- Next Price: 11.37
# Price: 11.37, Prediction: 1, Actual: 1 --- Next Price: 11.41
# Price: 11.41, Prediction: 1, Actual: 1 --- Next Price: 11.45
# Price: 11.45, Prediction: 1, Actual: 1 --- Next Price: 12.38
# Price: 12.38, Prediction: 2, Actual: 2 --- Next Price: 12.35
# Price: 12.35, Prediction: 2, Actual: 2 --- Next Price: 12.33
# Price: 12.33, Prediction: 2, Actual: 2 --- Next Price: 12.30
# Price: 12.30, Prediction: 2, Actual: 2 --- Next Price: 12.28
# Price: 12.28, Prediction: 2, Actual: 2 --- Next Price: 12.26
# Price: 12.26, Prediction: 2, Actual: 2 --- Next Price: 12.19
# Price: 12.19, Prediction: 2, Actual: 2 --- Next Price: 12.13
# Price: 12.13, Prediction: 2, Actual: 2 --- Next Price: 12.07
# Price: 12.07, Prediction: 2, Actual: 2 --- Next Price: 12.01
# Price: 12.01, Prediction: 2, Actual: 2 --- Next Price: 11.96
# Price: 11.96, Prediction: 2, Actual: 2 --- Next Price: 11.91
# Price: 11.91, Prediction: 2, Actual: 2 --- Next Price: 11.86
# Price: 11.86, Prediction: 2, Actual: 2 --- Next Price: 10.64
# Price: 10.64, Prediction: 1, Actual: 1 --- Next Price: 10.66
# Price: 10.66, Prediction: 1, Actual: 1 --- Next Price: 10.71
# Price: 10.71, Prediction: 1, Actual: 1 --- Next Price: 10.80
# Price: 10.80, Prediction: 1, Actual: 1 --- Next Price: 10.88
# Price: 10.88, Prediction: 1, Actual: 1 --- Next Price: 10.99
# Price: 10.99, Prediction: 1, Actual: 1 --- Next Price: 11.15
# Price: 11.15, Prediction: 1, Actual: 1 --- Next Price: 11.29
# Price: 11.29, Prediction: 1, Actual: 1 --- Next Price: 13.29
# Price: 13.29, Prediction: 2, Actual: 0 --- Next Price: 13.29
# Price: 13.29, Prediction: 2, Actual: 2 --- Next Price: 13.25
# Price: 13.25, Prediction: 2, Actual: 2 --- Next Price: 13.22
# Price: 13.22, Prediction: 2, Actual: 2 --- Next Price: 13.18
# Price: 13.18, Prediction: 2, Actual: 2 --- Next Price: 13.15
# Price: 13.15, Prediction: 2, Actual: 2 --- Next Price: 13.11
# Price: 13.11, Prediction: 2, Actual: 2 --- Next Price: 13.08
# Price: 13.08, Prediction: 0, Actual: 2 --- Next Price: 11.39
# Price: 11.39, Prediction: 1, Actual: 1 --- Next Price: 11.43
# Price: 11.43, Prediction: 1, Actual: 1 --- Next Price: 11.46
# Price: 11.46, Prediction: 1, Actual: 1 --- Next Price: 11.49
# Price: 11.49, Prediction: 1, Actual: 1 --- Next Price: 11.52
# Price: 11.52, Prediction: 1, Actual: 1 --- Next Price: 11.58
# Price: 11.58, Prediction: 1, Actual: 1 --- Next Price: 11.68
# Price: 11.68, Prediction: 1, Actual: 1 --- Next Price: 11.83
# Price: 11.83, Prediction: 1, Actual: 1 --- Next Price: 11.97
# Price: 11.97, Prediction: 1, Actual: 1 --- Next Price: 12.09
# Price: 12.09, Prediction: 1, Actual: 1 --- Next Price: 12.28
# Price: 12.28, Prediction: 1, Actual: 1 --- Next Price: 12.49
# Price: 12.49, Prediction: 1, Actual: 1 --- Next Price: 12.71
# Price: 12.71, Prediction: 1, Actual: 1 --- Next Price: 12.98
# Price: 12.98, Prediction: 2, Actual: 1 --- Next Price: 14.40
# Price: 14.40, Prediction: 2, Actual: 2 --- Next Price: 14.37
# Price: 14.37, Prediction: 2, Actual: 2 --- Next Price: 14.31
# Price: 14.31, Prediction: 2, Actual: 2 --- Next Price: 14.26
# Price: 14.26, Prediction: 2, Actual: 2 --- Next Price: 14.21
# Price: 14.21, Prediction: 2, Actual: 2 --- Next Price: 14.13
# Price: 14.13, Prediction: 2, Actual: 2 --- Next Price: 14.06
# Price: 14.06, Prediction: 2, Actual: 2 --- Next Price: 13.99
# Price: 13.99, Prediction: 2, Actual: 2 --- Next Price: 13.93
# Price: 13.93, Prediction: 2, Actual: 2 --- Next Price: 12.28
# Price: 12.28, Prediction: 1, Actual: 1 --- Next Price: 14.00
# Price: 14.00, Prediction: 2, Actual: 2 --- Next Price: 11.62
# Price: 11.62, Prediction: 1, Actual: 0 --- Next Price: 11.62
# Price: 11.62, Prediction: 1, Actual: 1 --- Next Price: 11.67
# Price: 11.67, Prediction: 1, Actual: 1 --- Next Price: 11.72
# Price: 11.72, Prediction: 1, Actual: 1 --- Next Price: 11.77
# Price: 11.77, Prediction: 1, Actual: 1 --- Next Price: 11.81
# Price: 11.81, Prediction: 1, Actual: 1 --- Next Price: 14.09
# Price: 14.09, Prediction: 2, Actual: 2 --- Next Price: 14.04
# Price: 14.04, Prediction: 2, Actual: 2 --- Next Price: 13.95
# Price: 13.95, Prediction: 2, Actual: 2 --- Next Price: 13.81
# Price: 13.81, Prediction: 2, Actual: 2 --- Next Price: 13.61
# Price: 13.61, Prediction: 2, Actual: 2 --- Next Price: 13.32
# Price: 13.32, Prediction: 2, Actual: 2 --- Next Price: 12.94
# Price: 12.94, Prediction: 2, Actual: 2 --- Next Price: 12.61
# Price: 12.61, Prediction: 2, Actual: 2 --- Next Price: 12.23
# Price: 12.23, Prediction: 2, Actual: 2 --- Next Price: 11.81
# Price: 11.81, Prediction: 2, Actual: 2 --- Next Price: 11.33
# Price: 11.33, Prediction: 2, Actual: 2 --- Next Price: 10.94
# Price: 10.94, Prediction: 2, Actual: 2 --- Next Price: 9.15
# Price: 9.15, Prediction: 2, Actual: 1 --- Next Price: 9.19
# Price: 9.19, Prediction: 2, Actual: 1 --- Next Price: 9.22
# Price: 9.22, Prediction: 2, Actual: 1 --- Next Price: 9.25
# Price: 9.25, Prediction: 2, Actual: 1 --- Next Price: 9.27
# Price: 9.27, Prediction: 2, Actual: 1 --- Next Price: 9.30
# Price: 9.30, Prediction: 2, Actual: 1 --- Next Price: 10.70
# Price: 10.70, Prediction: 2, Actual: 2 --- Next Price: 10.67
# Price: 10.67, Prediction: 2, Actual: 2 --- Next Price: 10.58
# Price: 10.58, Prediction: 2, Actual: 2 --- Next Price: 10.42
# Price: 10.42, Prediction: 2, Actual: 2 --- Next Price: 10.21
# Price: 10.21, Prediction: 2, Actual: 2 --- Next Price: 10.01
# Price: 10.01, Prediction: 2, Actual: 2 --- Next Price: 9.75
# Price: 9.75, Prediction: 2, Actual: 2 --- Next Price: 9.37
# Price: 9.37, Prediction: 2, Actual: 2 --- Next Price: 9.02
# Price: 9.02, Prediction: 2, Actual: 2 --- Next Price: 8.72
# Price: 8.72, Prediction: 2, Actual: 2 --- Next Price: 8.46
# Price: 8.46, Prediction: 2, Actual: 2 --- Next Price: 8.22
# Price: 8.22, Prediction: 2, Actual: 2 --- Next Price: 8.02
# Price: 8.02, Prediction: 2, Actual: 2 --- Next Price: 7.84
# Price: 7.84, Prediction: 0, Actual: 2 --- Next Price: 7.83
# Price: 7.83, Prediction: 2, Actual: 2 --- Next Price: 7.72
# Price: 7.72, Prediction: 2, Actual: 2 --- Next Price: 7.54
# Price: 7.54, Prediction: 2, Actual: 2 --- Next Price: 7.37
# Price: 7.37, Prediction: 2, Actual: 2 --- Next Price: 7.18
# Price: 7.18, Prediction: 2, Actual: 2 --- Next Price: 7.08
# Price: 7.08, Prediction: 2, Actual: 0 --- Next Price: 7.08
# Price: 7.08, Prediction: 2, Actual: 2 --- Next Price: 7.00
# Price: 7.00, Prediction: 2, Actual: 2 --- Next Price: 5.61
# Price: 5.61, Prediction: 0, Actual: 0 --- Next Price: 5.61
# Price: 5.61, Prediction: 0, Actual: 1 --- Next Price: 5.65
# Price: 5.65, Prediction: 1, Actual: 1 --- Next Price: 5.73
# Price: 5.73, Prediction: 1, Actual: 1 --- Next Price: 5.84
# Price: 5.84, Prediction: 1, Actual: 1 --- Next Price: 5.95
# Price: 5.95, Prediction: 1, Actual: 1 --- Next Price: 6.06
# Price: 6.06, Prediction: 1, Actual: 1 --- Next Price: 6.20
# Price: 6.20, Prediction: 1, Actual: 1 --- Next Price: 6.38
# Price: 6.38, Prediction: 1, Actual: 1 --- Next Price: 6.58
# Price: 6.58, Prediction: 1, Actual: 1 --- Next Price: 6.92
# Price: 6.92, Prediction: 1, Actual: 1 --- Next Price: 7.28
# Price: 7.28, Prediction: 1, Actual: 1 --- Next Price: 7.58
# Price: 7.58, Prediction: 1, Actual: 1 --- Next Price: 7.84
# Price: 7.84, Prediction: 1, Actual: 1 --- Next Price: 8.05
# Price: 8.05, Prediction: 2, Actual: 1 --- Next Price: 8.09
# Price: 8.09, Prediction: 1, Actual: 1 --- Next Price: 8.36
# Price: 8.36, Prediction: 0, Actual: 1 --- Next Price: 8.58
# Price: 8.58, Prediction: 2, Actual: 1 --- Next Price: 8.69
# Price: 8.69, Prediction: 0, Actual: 1 --- Next Price: 9.59
# Price: 9.59, Prediction: 0, Actual: 0 --- Next Price: 9.59
# Price: 9.59, Prediction: 0, Actual: 2 --- Next Price: 9.57
# Price: 9.57, Prediction: 0, Actual: 2 --- Next Price: 9.55
# Price: 9.55, Prediction: 2, Actual: 2 --- Next Price: 9.53
# Price: 9.53, Prediction: 2, Actual: 2 --- Next Price: 9.48
# Price: 9.48, Prediction: 2, Actual: 2 --- Next Price: 8.27
# Price: 8.27, Prediction: 0, Actual: 1 --- Next Price: 8.30
# Price: 8.30, Prediction: 1, Actual: 1 --- Next Price: 8.37
# Price: 8.37, Prediction: 1, Actual: 1 --- Next Price: 8.49
# Price: 8.49, Prediction: 1, Actual: 1 --- Next Price: 8.65
# Price: 8.65, Prediction: 1, Actual: 1 --- Next Price: 8.80
# Price: 8.80, Prediction: 1, Actual: 1 --- Next Price: 8.93
# Price: 8.93, Prediction: 1, Actual: 1 --- Next Price: 9.06
# Price: 9.06, Prediction: 1, Actual: 1 --- Next Price: 10.51
# Price: 10.51, Prediction: 2, Actual: 2 --- Next Price: 10.48
# Price: 10.48, Prediction: 2, Actual: 2 --- Next Price: 10.46
# Price: 10.46, Prediction: 2, Actual: 2 --- Next Price: 10.39
# Price: 10.39, Prediction: 2, Actual: 2 --- Next Price: 10.33
# Price: 10.33, Prediction: 2, Actual: 2 --- Next Price: 10.27
# Price: 10.27, Prediction: 2, Actual: 2 --- Next Price: 10.19
# Price: 10.19, Prediction: 2, Actual: 2 --- Next Price: 10.11
# Price: 10.11, Prediction: 2, Actual: 2 --- Next Price: 10.03
# Price: 10.03, Prediction: 0, Actual: 2 --- Next Price: 9.96
# Price: 9.96, Prediction: 0, Actual: 2 --- Next Price: 8.84
# Price: 8.84, Prediction: 1, Actual: 1 --- Next Price: 8.87
# Price: 8.87, Prediction: 1, Actual: 1 --- Next Price: 8.89
# Price: 8.89, Prediction: 1, Actual: 1 --- Next Price: 8.92
# Price: 8.92, Prediction: 1, Actual: 1 --- Next Price: 8.94
# Price: 8.94, Prediction: 1, Actual: 1 --- Next Price: 8.96
# Price: 8.96, Prediction: 1, Actual: 1 --- Next Price: 8.98
# Price: 8.98, Prediction: 1, Actual: 1 --- Next Price: 9.01
# Price: 9.01, Prediction: 1, Actual: 1 --- Next Price: 9.03
# Price: 9.03, Prediction: 1, Actual: 1 --- Next Price: 9.07
# Price: 9.07, Prediction: 1, Actual: 1 --- Next Price: 9.15
# Price: 9.15, Prediction: 1, Actual: 1 --- Next Price: 9.22
# Price: 9.22, Prediction: 1, Actual: 1 --- Next Price: 9.29
# Price: 9.29, Prediction: 1, Actual: 1 --- Next Price: 10.36
# Price: 10.36, Prediction: 2, Actual: 2 --- Next Price: 10.33
# Price: 10.33, Prediction: 2, Actual: 2 --- Next Price: 10.27
# Price: 10.27, Prediction: 2, Actual: 2 --- Next Price: 10.21
# Price: 10.21, Prediction: 2, Actual: 2 --- Next Price: 10.10
# Price: 10.10, Prediction: 2, Actual: 2 --- Next Price: 9.95
# Price: 9.95, Prediction: 2, Actual: 2 --- Next Price: 9.81
# Price: 9.81, Prediction: 2, Actual: 2 --- Next Price: 9.62
# Price: 9.62, Prediction: 2, Actual: 2 --- Next Price: 9.40
# Price: 9.40, Prediction: 2, Actual: 2 --- Next Price: 9.20
# Price: 9.20, Prediction: 2, Actual: 2 --- Next Price: 9.15
# Price: 9.15, Prediction: 2, Actual: 2 --- Next Price: 8.98
# Price: 8.98, Prediction: 2, Actual: 2 --- Next Price: 8.83
# Price: 8.83, Prediction: 2, Actual: 2 --- Next Price: 8.70
# Price: 8.70, Prediction: 2, Actual: 2 --- Next Price: 8.63
# Price: 8.63, Prediction: 2, Actual: 2 --- Next Price: 8.47
# Price: 8.47, Prediction: 2, Actual: 2 --- Next Price: 7.32
# Price: 7.32, Prediction: 0, Actual: 1 --- Next Price: 7.34
# Price: 7.34, Prediction: 1, Actual: 1 --- Next Price: 7.39
# Price: 7.39, Prediction: 1, Actual: 1 --- Next Price: 7.48
# Price: 7.48, Prediction: 1, Actual: 1 --- Next Price: 7.60
# Price: 7.60, Prediction: 1, Actual: 1 --- Next Price: 7.75
# Price: 7.75, Prediction: 1, Actual: 1 --- Next Price: 7.97
# Price: 7.97, Prediction: 1, Actual: 1 --- Next Price: 8.19
# Price: 8.19, Prediction: 1, Actual: 1 --- Next Price: 8.38
# Price: 8.38, Prediction: 1, Actual: 1 --- Next Price: 8.55
# Price: 8.55, Prediction: 1, Actual: 1 --- Next Price: 8.72
# Price: 8.72, Prediction: 1, Actual: 1 --- Next Price: 8.91
# Price: 8.91, Prediction: 1, Actual: 1 --- Next Price: 9.04
# Price: 9.04, Prediction: 1, Actual: 1 --- Next Price: 10.26
# Price: 10.26, Prediction: 2, Actual: 2 --- Next Price: 10.23
# Price: 10.23, Prediction: 2, Actual: 2 --- Next Price: 10.21
# Price: 10.21, Prediction: 2, Actual: 2 --- Next Price: 9.10
# Price: 9.10, Prediction: 1, Actual: 1 --- Next Price: 9.12
# Price: 9.12, Prediction: 1, Actual: 1 --- Next Price: 9.18
# Price: 9.18, Prediction: 1, Actual: 1 --- Next Price: 9.23
# Price: 9.23, Prediction: 1, Actual: 1 --- Next Price: 9.27
# Price: 9.27, Prediction: 1, Actual: 1 --- Next Price: 9.32
# Price: 9.32, Prediction: 1, Actual: 1 --- Next Price: 9.37
# Price: 9.37, Prediction: 1, Actual: 1 --- Next Price: 10.44
# Price: 10.44, Prediction: 2, Actual: 2 --- Next Price: 10.40
# Price: 10.40, Prediction: 2, Actual: 2 --- Next Price: 10.37
# Price: 10.37, Prediction: 2, Actual: 2 --- Next Price: 10.35
# Price: 10.35, Prediction: 2, Actual: 2 --- Next Price: 10.32
# Price: 10.32, Prediction: 2, Actual: 2 --- Next Price: 10.29
# Price: 10.29, Prediction: 2, Actual: 2 --- Next Price: 10.26
# Price: 10.26, Prediction: 2, Actual: 2 --- Next Price: 10.23
# Price: 10.23, Prediction: 2, Actual: 2 --- Next Price: 10.23
# Price: 10.23, Prediction: 2, Actual: 2 --- Next Price: 10.20
# Price: 10.20, Prediction: 2, Actual: 2 --- Next Price: 10.18
# Price: 10.18, Prediction: 2, Actual: 2 --- Next Price: 8.92
# Price: 8.92, Prediction: 1, Actual: 1 --- Next Price: 8.95
# Price: 8.95, Prediction: 1, Actual: 1 --- Next Price: 10.56
# Price: 10.56, Prediction: 2, Actual: 2 --- Next Price: 10.52
# Price: 10.52, Prediction: 2, Actual: 2 --- Next Price: 10.48
# Price: 10.48, Prediction: 2, Actual: 2 --- Next Price: 10.44
# Price: 10.44, Prediction: 2, Actual: 2 --- Next Price: 10.41
# Price: 10.41, Prediction: 2, Actual: 2 --- Next Price: 10.37
# Price: 10.37, Prediction: 2, Actual: 2 --- Next Price: 10.34
# Price: 10.34, Prediction: 2, Actual: 2 --- Next Price: 10.31
# Price: 10.31, Prediction: 2, Actual: 2 --- Next Price: 10.23
# Price: 10.23, Prediction: 2, Actual: 2 --- Next Price: 10.09
# Price: 10.09, Prediction: 2, Actual: 2 --- Next Price: 9.96
# Price: 9.96, Prediction: 2, Actual: 2 --- Next Price: 9.84
# Price: 9.84, Prediction: 2, Actual: 2 --- Next Price: 9.72
# Price: 9.72, Prediction: 2, Actual: 2 --- Next Price: 9.61
# Price: 9.61, Prediction: 2, Actual: 2 --- Next Price: 9.51
# Price: 9.51, Prediction: 2, Actual: 2 --- Next Price: 9.41
# Price: 9.41, Prediction: 2, Actual: 2 --- Next Price: 9.32
# Price: 9.32, Prediction: 2, Actual: 2 --- Next Price: 9.24
# Price: 9.24, Prediction: 2, Actual: 2 --- Next Price: 9.16
# Price: 9.16, Prediction: 2, Actual: 2 --- Next Price: 9.05
# Price: 9.05, Prediction: 2, Actual: 2 --- Next Price: 8.95
# Price: 8.95, Prediction: 2, Actual: 2 --- Next Price: 7.84
# Price: 7.84, Prediction: 1, Actual: 1 --- Next Price: 7.87
# Price: 7.87, Prediction: 1, Actual: 1 --- Next Price: 7.90
# Price: 7.90, Prediction: 1, Actual: 1 --- Next Price: 7.96
# Price: 7.96, Prediction: 1, Actual: 1 --- Next Price: 8.01
# Price: 8.01, Prediction: 1, Actual: 1 --- Next Price: 8.09
# Price: 8.09, Prediction: 1, Actual: 1 --- Next Price: 8.20
# Price: 8.20, Prediction: 1, Actual: 1 --- Next Price: 8.32
# Price: 8.32, Prediction: 1, Actual: 1 --- Next Price: 8.48
# Price: 8.48, Prediction: 1, Actual: 1 --- Next Price: 8.63
# Price: 8.63, Prediction: 1, Actual: 1 --- Next Price: 8.75
# Price: 8.75, Prediction: 1, Actual: 1 --- Next Price: 8.86
# Price: 8.86, Prediction: 1, Actual: 1 --- Next Price: 8.96
# Price: 8.96, Prediction: 1, Actual: 1 --- Next Price: 9.05
# Price: 9.05, Prediction: 1, Actual: 1 --- Next Price: 9.68
# Price: 9.68, Prediction: 2, Actual: 2 --- Next Price: 9.66
# Price: 9.66, Prediction: 2, Actual: 2 --- Next Price: 9.63
# Price: 9.63, Prediction: 2, Actual: 2 --- Next Price: 9.59
# Price: 9.59, Prediction: 2, Actual: 2 --- Next Price: 9.56
# Price: 9.56, Prediction: 2, Actual: 2 --- Next Price: 9.54
# Price: 9.54, Prediction: 2, Actual: 0 --- Next Price: 9.54
# Price: 9.54, Prediction: 2, Actual: 2 --- Next Price: 8.74
# Price: 8.74, Prediction: 1, Actual: 1 --- Next Price: 8.76
# Price: 8.76, Prediction: 1, Actual: 1 --- Next Price: 8.78
# Price: 8.78, Prediction: 1, Actual: 1 --- Next Price: 8.79
# Price: 8.79, Prediction: 1, Actual: 1 --- Next Price: 9.60
# Price: 9.60, Prediction: 2, Actual: 2 --- Next Price: 9.58
# Price: 9.58, Prediction: 2, Actual: 2 --- Next Price: 9.55
# Price: 9.55, Prediction: 2, Actual: 2 --- Next Price: 9.50
# Price: 9.50, Prediction: 2, Actual: 2 --- Next Price: 9.42
# Price: 9.42, Prediction: 2, Actual: 2 --- Next Price: 8.60
# Price: 8.60, Prediction: 1, Actual: 1 --- Next Price: 8.63
# Price: 8.63, Prediction: 1, Actual: 1 --- Next Price: 8.65
# Price: 8.65, Prediction: 1, Actual: 1 --- Next Price: 8.68
# Price: 8.68, Prediction: 1, Actual: 1 --- Next Price: 8.73
# Price: 8.73, Prediction: 1, Actual: 1 --- Next Price: 8.78
# Price: 8.78, Prediction: 1, Actual: 1 --- Next Price: 8.85
# Price: 8.85, Prediction: 1, Actual: 1 --- Next Price: 8.97
# Price: 8.97, Prediction: 1, Actual: 1 --- Next Price: 9.08
# Price: 9.08, Prediction: 1, Actual: 1 --- Next Price: 9.18
# Price: 9.18, Prediction: 1, Actual: 1 --- Next Price: 9.30
# Price: 9.30, Prediction: 1, Actual: 1 --- Next Price: 9.41
# Price: 9.41, Prediction: 1, Actual: 1 --- Next Price: 9.57
# Price: 9.57, Prediction: 1, Actual: 1 --- Next Price: 10.85
# Price: 10.85, Prediction: 2, Actual: 0 --- Next Price: 10.85
# Price: 10.85, Prediction: 0, Actual: 2 --- Next Price: 10.82
# Price: 10.82, Prediction: 0, Actual: 2 --- Next Price: 10.80
# Price: 10.80, Prediction: 0, Actual: 2 --- Next Price: 9.70
# Price: 9.70, Prediction: 1, Actual: 1 --- Next Price: 9.73
# Price: 9.73, Prediction: 1, Actual: 1 --- Next Price: 9.75
# Price: 9.75, Prediction: 1, Actual: 1 --- Next Price: 9.82
# Price: 9.82, Prediction: 1, Actual: 1 --- Next Price: 9.92
# Price: 9.92, Prediction: 1, Actual: 1 --- Next Price: 10.02
# Price: 10.02, Prediction: 1, Actual: 1 --- Next Price: 10.12
# Price: 10.12, Prediction: 1, Actual: 1 --- Next Price: 10.20
# Price: 10.20, Prediction: 1, Actual: 1 --- Next Price: 10.33
# Price: 10.33, Prediction: 1, Actual: 1 --- Next Price: 10.44
# Price: 10.44, Prediction: 1, Actual: 1 --- Next Price: 10.54
# Price: 10.54, Prediction: 1, Actual: 1 --- Next Price: 10.68
# Price: 10.68, Prediction: 1, Actual: 1 --- Next Price: 10.81
# Price: 10.81, Prediction: 1, Actual: 1 --- Next Price: 10.92
# Price: 10.92, Prediction: 1, Actual: 1 --- Next Price: 11.94
# Price: 11.94, Prediction: 2, Actual: 2 --- Next Price: 11.92
# Price: 11.92, Prediction: 2, Actual: 2 --- Next Price: 11.87
# Price: 11.87, Prediction: 2, Actual: 2 --- Next Price: 11.80
# Price: 11.80, Prediction: 2, Actual: 2 --- Next Price: 11.64
# Price: 11.64, Prediction: 2, Actual: 2 --- Next Price: 11.42
# Price: 11.42, Prediction: 2, Actual: 2 --- Next Price: 11.23
# Price: 11.23, Prediction: 2, Actual: 2 --- Next Price: 11.05
# Price: 11.05, Prediction: 2, Actual: 2 --- Next Price: 10.89
# Price: 10.89, Prediction: 2, Actual: 2 --- Next Price: 10.75
# Price: 10.75, Prediction: 2, Actual: 2 --- Next Price: 10.62
# Price: 10.62, Prediction: 2, Actual: 2 --- Next Price: 10.50
# Price: 10.50, Prediction: 2, Actual: 2 --- Next Price: 10.40
# Price: 10.40, Prediction: 2, Actual: 2 --- Next Price: 9.46
# Price: 9.46, Prediction: 1, Actual: 1 --- Next Price: 9.49
# Price: 9.49, Prediction: 1, Actual: 1 --- Next Price: 9.54
# Price: 9.54, Prediction: 1, Actual: 1 --- Next Price: 9.62
# Price: 9.62, Prediction: 1, Actual: 1 --- Next Price: 9.73
# Price: 9.73, Prediction: 1, Actual: 1 --- Next Price: 9.82
# Price: 9.82, Prediction: 1, Actual: 1 --- Next Price: 9.99
# Price: 9.99, Prediction: 1, Actual: 1 --- Next Price: 10.13
# Price: 10.13, Prediction: 1, Actual: 1 --- Next Price: 10.30
# Price: 10.30, Prediction: 1, Actual: 1 --- Next Price: 10.44
# Price: 10.44, Prediction: 1, Actual: 1 --- Next Price: 11.55
# Price: 11.55, Prediction: 2, Actual: 0 --- Next Price: 11.55
# Price: 11.55, Prediction: 2, Actual: 2 --- Next Price: 11.50
# Price: 11.50, Prediction: 2, Actual: 2 --- Next Price: 11.42
# Price: 11.42, Prediction: 2, Actual: 2 --- Next Price: 11.32
# Price: 11.32, Prediction: 2, Actual: 2 --- Next Price: 11.22
# Price: 11.22, Prediction: 0, Actual: 2 --- Next Price: 11.13
# Price: 11.13, Prediction: 2, Actual: 2 --- Next Price: 11.05
# Price: 11.05, Prediction: 2, Actual: 2 --- Next Price: 10.95
# Price: 10.95, Prediction: 2, Actual: 2 --- Next Price: 10.85
# Price: 10.85, Prediction: 2, Actual: 2 --- Next Price: 10.72
# Price: 10.72, Prediction: 2, Actual: 2 --- Next Price: 10.61
# Price: 10.61, Prediction: 2, Actual: 2 --- Next Price: 10.52
# Price: 10.52, Prediction: 1, Actual: 2 --- Next Price: 9.96
# Price: 9.96, Prediction: 1, Actual: 1 --- Next Price: 9.97
# Price: 9.97, Prediction: 1, Actual: 1 --- Next Price: 9.98
# Price: 9.98, Prediction: 1, Actual: 1 --- Next Price: 10.00
# Price: 10.00, Prediction: 1, Actual: 1 --- Next Price: 10.03
# Price: 10.03, Prediction: 1, Actual: 1 --- Next Price: 10.61
# Price: 10.61, Prediction: 2, Actual: 0 --- Next Price: 10.61
# Price: 10.61, Prediction: 2, Actual: 2 --- Next Price: 10.58
# Price: 10.58, Prediction: 2, Actual: 2 --- Next Price: 10.54
# Price: 10.54, Prediction: 2, Actual: 2 --- Next Price: 10.50
# Price: 10.50, Prediction: 2, Actual: 2 --- Next Price: 10.44
# Price: 10.44, Prediction: 2, Actual: 2 --- Next Price: 10.36
# Price: 10.36, Prediction: 2, Actual: 2 --- Next Price: 9.71
# Price: 9.71, Prediction: 1, Actual: 1 --- Next Price: 9.72
# Price: 9.72, Prediction: 1, Actual: 0 --- Next Price: 9.72
# Price: 9.72, Prediction: 1, Actual: 1 --- Next Price: 9.75
# Price: 9.75, Prediction: 1, Actual: 1 --- Next Price: 9.78
# Price: 9.78, Prediction: 1, Actual: 1 --- Next Price: 9.84
# Price: 9.84, Prediction: 1, Actual: 1 --- Next Price: 9.91
# Price: 9.91, Prediction: 1, Actual: 1 --- Next Price: 9.97
# Price: 9.97, Prediction: 1, Actual: 1 --- Next Price: 10.02
# Price: 10.02, Prediction: 1, Actual: 0 --- Next Price: 10.02
# Price: 10.02, Prediction: 1, Actual: 1 --- Next Price: 10.07
# Price: 10.07, Prediction: 1, Actual: 1 --- Next Price: 10.91
# Price: 10.91, Prediction: 2, Actual: 2 --- Next Price: 10.89
# Price: 10.89, Prediction: 2, Actual: 2 --- Next Price: 10.87
# Price: 10.87, Prediction: 2, Actual: 2 --- Next Price: 10.85
# Price: 10.85, Prediction: 2, Actual: 2 --- Next Price: 10.83
# Price: 10.83, Prediction: 2, Actual: 2 --- Next Price: 10.81
# Price: 10.81, Prediction: 2, Actual: 2 --- Next Price: 10.80
# Price: 10.80, Prediction: 2, Actual: 2 --- Next Price: 10.78
# Price: 10.78, Prediction: 2, Actual: 2 --- Next Price: 9.93
# Price: 9.93, Prediction: 1, Actual: 1 --- Next Price: 9.95
# Price: 9.95, Prediction: 1, Actual: 1 --- Next Price: 9.96
# Price: 9.96, Prediction: 1, Actual: 1 --- Next Price: 10.00
# Price: 10.00, Prediction: 1, Actual: 1 --- Next Price: 10.03
# Price: 10.03, Prediction: 1, Actual: 1 --- Next Price: 10.07
# Price: 10.07, Prediction: 1, Actual: 1 --- Next Price: 10.10
# Price: 10.10, Prediction: 1, Actual: 1 --- Next Price: 10.15
# Price: 10.15, Prediction: 1, Actual: 1 --- Next Price: 10.21
# Price: 10.21, Prediction: 1, Actual: 1 --- Next Price: 10.33
# Price: 10.33, Prediction: 1, Actual: 1 --- Next Price: 10.45
# Price: 10.45, Prediction: 1, Actual: 1 --- Next Price: 10.59
# Price: 10.59, Prediction: 1, Actual: 1 --- Next Price: 10.72
# Price: 10.72, Prediction: 1, Actual: 1 --- Next Price: 10.82
# Price: 10.82, Prediction: 1, Actual: 1 --- Next Price: 10.94
# Price: 10.94, Prediction: 1, Actual: 1 --- Next Price: 11.05
# Price: 11.05, Prediction: 1, Actual: 1 --- Next Price: 11.14
# Price: 11.14, Prediction: 1, Actual: 1 --- Next Price: 11.24
# Price: 11.24, Prediction: 1, Actual: 1 --- Next Price: 11.32
# Price: 11.32, Prediction: 1, Actual: 1 --- Next Price: 11.63
# Price: 11.63, Prediction: 2, Actual: 2 --- Next Price: 11.62
# Price: 11.62, Prediction: 2, Actual: 2 --- Next Price: 11.61
# Price: 11.61, Prediction: 2, Actual: 2 --- Next Price: 11.22
# Price: 11.22, Prediction: 1, Actual: 1 --- Next Price: 11.23
# Price: 11.23, Prediction: 1, Actual: 1 --- Next Price: 11.25
# Price: 11.25, Prediction: 1, Actual: 1 --- Next Price: 11.29
# Price: 11.29, Prediction: 1, Actual: 1 --- Next Price: 11.36
# Price: 11.36, Prediction: 1, Actual: 1 --- Next Price: 11.42
# Price: 11.42, Prediction: 1, Actual: 1 --- Next Price: 11.48
# Price: 11.48, Prediction: 1, Actual: 1 --- Next Price: 11.53
# Price: 11.53, Prediction: 1, Actual: 1 --- Next Price: 12.14
# Price: 12.14, Prediction: 2, Actual: 2 --- Next Price: 12.13
# Price: 12.13, Prediction: 2, Actual: 2 --- Next Price: 12.12
# Price: 12.12, Prediction: 2, Actual: 2 --- Next Price: 12.09
# Price: 12.09, Prediction: 2, Actual: 2 --- Next Price: 12.03
# Price: 12.03, Prediction: 2, Actual: 2 --- Next Price: 11.94
# Price: 11.94, Prediction: 2, Actual: 2 --- Next Price: 11.85
# Price: 11.85, Prediction: 2, Actual: 2 --- Next Price: 11.77
# Price: 11.77, Prediction: 2, Actual: 2 --- Next Price: 11.68
# Price: 11.68, Prediction: 2, Actual: 2 --- Next Price: 11.56
# Price: 11.56, Prediction: 2, Actual: 2 --- Next Price: 11.45
# Price: 11.45, Prediction: 2, Actual: 2 --- Next Price: 11.31
# Price: 11.31, Prediction: 2, Actual: 2 --- Next Price: 11.19
# Price: 11.19, Prediction: 2, Actual: 2 --- Next Price: 11.08
# Price: 11.08, Prediction: 0, Actual: 2 --- Next Price: 10.97
# Price: 10.97, Prediction: 2, Actual: 2 --- Next Price: 10.83
# Price: 10.83, Prediction: 2, Actual: 2 --- Next Price: 10.71
# Price: 10.71, Prediction: 2, Actual: 2 --- Next Price: 10.61
# Price: 10.61, Prediction: 2, Actual: 2 --- Next Price: 10.52
# Price: 10.52, Prediction: 2, Actual: 2 --- Next Price: 10.45
# Price: 10.45, Prediction: 2, Actual: 2 --- Next Price: 10.16
# Price: 10.16, Prediction: 0, Actual: 1 --- Next Price: 10.17
# Price: 10.17, Prediction: 1, Actual: 1 --- Next Price: 10.19
# Price: 10.19, Prediction: 1, Actual: 1 --- Next Price: 10.22
# Price: 10.22, Prediction: 0, Actual: 1 --- Next Price: 10.27
# Price: 10.27, Prediction: 1, Actual: 1 --- Next Price: 10.33
# Price: 10.33, Prediction: 0, Actual: 1 --- Next Price: 10.39
# Price: 10.39, Prediction: 1, Actual: 1 --- Next Price: 10.92
# Price: 10.92, Prediction: 2, Actual: 2 --- Next Price: 10.91
# Price: 10.91, Prediction: 2, Actual: 2 --- Next Price: 10.40
# Price: 10.40, Prediction: 1, Actual: 1 --- Next Price: 10.41
# Price: 10.41, Prediction: 1, Actual: 1 --- Next Price: 10.45
# Price: 10.45, Prediction: 1, Actual: 1 --- Next Price: 10.48
# Price: 10.48, Prediction: 1, Actual: 1 --- Next Price: 10.51
# Price: 10.51, Prediction: 1, Actual: 1 --- Next Price: 10.54
# Price: 10.54, Prediction: 1, Actual: 1 --- Next Price: 10.57
# Price: 10.57, Prediction: 1, Actual: 1 --- Next Price: 10.60
# Price: 10.60, Prediction: 1, Actual: 1 --- Next Price: 11.28
# Price: 11.28, Prediction: 2, Actual: 2 --- Next Price: 10.61
# Price: 10.61, Prediction: 1, Actual: 0 --- Next Price: 10.61
# Price: 10.61, Prediction: 1, Actual: 1 --- Next Price: 10.63
# Price: 10.63, Prediction: 1, Actual: 1 --- Next Price: 10.64
# Price: 10.64, Prediction: 1, Actual: 1 --- Next Price: 10.65
# Price: 10.65, Prediction: 1, Actual: 1 --- Next Price: 10.68
# Price: 10.68, Prediction: 1, Actual: 1 --- Next Price: 10.73
# Price: 10.73, Prediction: 1, Actual: 1 --- Next Price: 10.82
# Price: 10.82, Prediction: 1, Actual: 1 --- Next Price: 10.94
# Price: 10.94, Prediction: 1, Actual: 1 --- Next Price: 11.05
# Price: 11.05, Prediction: 1, Actual: 1 --- Next Price: 11.15
# Price: 11.15, Prediction: 1, Actual: 1 --- Next Price: 12.05
# Price: 12.05, Prediction: 2, Actual: 2 --- Next Price: 12.03
# Price: 12.03, Prediction: 2, Actual: 2 --- Next Price: 12.01
# Price: 12.01, Prediction: 2, Actual: 2 --- Next Price: 11.99
# Price: 11.99, Prediction: 2, Actual: 2 --- Next Price: 11.98
# Price: 11.98, Prediction: 2, Actual: 2 --- Next Price: 11.96
# Price: 11.96, Prediction: 2, Actual: 2 --- Next Price: 11.95
# Price: 11.95, Prediction: 2, Actual: 2 --- Next Price: 11.93
# Price: 11.93, Prediction: 2, Actual: 2 --- Next Price: 11.91
# Price: 11.91, Prediction: 2, Actual: 2 --- Next Price: 11.90
# Price: 11.90, Prediction: 2, Actual: 2 --- Next Price: 11.89
# Price: 11.89, Prediction: 2, Actual: 2 --- Next Price: 11.88
# Price: 11.88, Prediction: 2, Actual: 2 --- Next Price: 11.17
# Price: 11.17, Prediction: 1, Actual: 1 --- Next Price: 11.18
# Price: 11.18, Prediction: 1, Actual: 1 --- Next Price: 11.21
# Price: 11.21, Prediction: 1, Actual: 1 --- Next Price: 11.24
# Price: 11.24, Prediction: 1, Actual: 1 --- Next Price: 11.30
# Price: 11.30, Prediction: 1, Actual: 1 --- Next Price: 11.34
# ...
# Price: 1.68, Prediction: 1, Actual: 1 --- Next Price: 1.69
# Price: 1.69, Prediction: 1, Actual: 1 --- Next Price: 1.71
# Price: 1.71, Prediction: 1, Actual: 1 --- Next Price: 1.73
# Price: 1.73, Prediction: 1, Actual: 1 --- Next Price: 1.75
# Price: 1.75, Prediction: 1, Actual: 1 --- Next Price: 1.77
# Price: 1.77, Prediction: 1, Actual: 1 --- Next Price: 1.79
# Price: 1.79, Prediction: 1, Actual: 1 --- Next Price: 1.81
# Price: 1.81, Prediction: 1, Actual: 1 --- Next Price: 1.97
# Price: 1.97, Prediction: 2, Actual: 2 --- Next Price: 1.97
# Price: 1.97, Prediction: 2, Actual: 2 --- Next Price: 1.96
# Price: 1.96, Prediction: 2, Actual: 2 --- Next Price: 1.95
# Price: 1.95, Prediction: 2, Actual: 2 --- Next Price: 1.94
# Price: 1.94, Prediction: 2, Actual: 2 --- Next Price: 1.93
# Price: 1.93, Prediction: 2, Actual: 2 --- Next Price: 1.91
# Price: 1.91, Prediction: 2, Actual: 2 --- Next Price: 1.90
# Price: 1.90, Prediction: 2, Actual: 2 --- Next Price: 1.89
# Price: 1.89, Prediction: 2, Actual: 2 --- Next Price: 1.87
# Price: 1.87, Prediction: 2, Actual: 2 --- Next Price: 1.83
# Price: 1.83, Prediction: 2, Actual: 2 --- Next Price: 1.81
# Price: 1.81, Prediction: 2, Actual: 2 --- Next Price: 1.78
# Price: 1.78, Prediction: 2, Actual: 2 --- Next Price: 1.75
# Price: 1.75, Prediction: 2, Actual: 2 --- Next Price: 1.72
# Price: 1.72, Prediction: 2, Actual: 2 --- Next Price: 1.68
# Price: 1.68, Prediction: 2, Actual: 2 --- Next Price: 1.64
# Price: 1.64, Prediction: 2, Actual: 2 --- Next Price: 1.62
# Price: 1.62, Prediction: 1, Actual: 2 --- Next Price: 1.49
# Price: 1.49, Prediction: 1, Actual: 1 --- Next Price: 1.49
# Price: 1.49, Prediction: 1, Actual: 1 --- Next Price: 1.50
# Price: 1.50, Prediction: 1, Actual: 1 --- Next Price: 1.66
# Price: 1.66, Prediction: 2, Actual: 2 --- Next Price: 1.66
# Price: 1.66, Prediction: 2, Actual: 2 --- Next Price: 1.49
# Price: 1.49, Prediction: 1, Actual: 1 --- Next Price: 1.49
# Price: 1.49, Prediction: 1, Actual: 1 --- Next Price: 1.50
# Price: 1.50, Prediction: 1, Actual: 1 --- Next Price: 1.50
# Price: 1.50, Prediction: 1, Actual: 1 --- Next Price: 1.51
# Price: 1.51, Prediction: 1, Actual: 1 --- Next Price: 1.51
# Price: 1.51, Prediction: 1, Actual: 1 --- Next Price: 1.53
# Price: 1.53, Prediction: 1, Actual: 1 --- Next Price: 1.54
# Price: 1.54, Prediction: 1, Actual: 1 --- Next Price: 1.55
# Price: 1.55, Prediction: 1, Actual: 1 --- Next Price: 1.72
# Price: 1.72, Prediction: 2, Actual: 2 --- Next Price: 1.52
# Price: 1.52, Prediction: 1, Actual: 0 --- Next Price: 1.52
# Price: 1.52, Prediction: 1, Actual: 1 --- Next Price: 1.53
# Price: 1.53, Prediction: 1, Actual: 1 --- Next Price: 1.55
# Price: 1.55, Prediction: 1, Actual: 1 --- Next Price: 1.56
# Price: 1.56, Prediction: 0, Actual: 1 --- Next Price: 1.57
# Price: 1.57, Prediction: 1, Actual: 1 --- Next Price: 1.58
# Price: 1.58, Prediction: 1, Actual: 1 --- Next Price: 1.60
# Price: 1.60, Prediction: 0, Actual: 1 --- Next Price: 1.61
# Price: 1.61, Prediction: 1, Actual: 1 --- Next Price: 1.63
# Price: 1.63, Prediction: 1, Actual: 1 --- Next Price: 1.65
# Price: 1.65, Prediction: 1, Actual: 1 --- Next Price: 1.66
# Price: 1.66, Prediction: 1, Actual: 1 --- Next Price: 1.94
# Price: 1.94, Prediction: 2, Actual: 2 --- Next Price: 1.93
# Price: 1.93, Prediction: 2, Actual: 2 --- Next Price: 1.93
# Price: 1.93, Prediction: 2, Actual: 2 --- Next Price: 1.92
# Price: 1.92, Prediction: 2, Actual: 2 --- Next Price: 1.92
# Price: 1.92, Prediction: 2, Actual: 2 --- Next Price: 1.92
# Price: 1.92, Prediction: 2, Actual: 2 --- Next Price: 1.91
# Price: 1.91, Prediction: 2, Actual: 2 --- Next Price: 1.91
# Price: 1.91, Prediction: 2, Actual: 2 --- Next Price: 1.90
# Price: 1.90, Prediction: 2, Actual: 2 --- Next Price: 1.90
# Price: 1.90, Prediction: 2, Actual: 2 --- Next Price: 1.89
# Price: 1.89, Prediction: 2, Actual: 2 --- Next Price: 1.89
# Price: 1.89, Prediction: 2, Actual: 2 --- Next Price: 1.68
# Price: 1.68, Prediction: 1, Actual: 1 --- Next Price: 1.68
# Price: 1.68, Prediction: 1, Actual: 1 --- Next Price: 1.70
# Price: 1.70, Prediction: 1, Actual: 1 --- Next Price: 1.71
# Price: 1.71, Prediction: 1, Actual: 1 --- Next Price: 1.73
# Price: 1.73, Prediction: 1, Actual: 1 --- Next Price: 1.74
# Price: 1.74, Prediction: 1, Actual: 1 --- Next Price: 1.75
# Price: 1.75, Prediction: 1, Actual: 1 --- Next Price: 1.76
# Price: 1.76, Prediction: 1, Actual: 1 --- Next Price: 1.78
# Price: 1.78, Prediction: 1, Actual: 1 --- Next Price: 1.79
# Price: 1.79, Prediction: 1, Actual: 1 --- Next Price: 1.80
# Price: 1.80, Prediction: 1, Actual: 1 --- Next Price: 1.81
# Price: 1.81, Prediction: 1, Actual: 1 --- Next Price: 2.05
# Price: 2.05, Prediction: 2, Actual: 2 --- Next Price: 2.05
# Price: 2.05, Prediction: 2, Actual: 2 --- Next Price: 2.04
# Price: 2.04, Prediction: 2, Actual: 2 --- Next Price: 2.04
# Price: 2.04, Prediction: 2, Actual: 2 --- Next Price: 2.03
# Price: 2.03, Prediction: 2, Actual: 2 --- Next Price: 2.01
# Price: 2.01, Prediction: 2, Actual: 2 --- Next Price: 1.99
# Price: 1.99, Prediction: 2, Actual: 2 --- Next Price: 1.97
# Price: 1.97, Prediction: 2, Actual: 2 --- Next Price: 1.95
# Price: 1.95, Prediction: 2, Actual: 2 --- Next Price: 1.93
# Price: 1.93, Prediction: 2, Actual: 2 --- Next Price: 1.91
# Price: 1.91, Prediction: 2, Actual: 2 --- Next Price: 1.88
# Price: 1.88, Prediction: 2, Actual: 2 --- Next Price: 1.84
# Price: 1.84, Prediction: 2, Actual: 2 --- Next Price: 1.81
# Price: 1.81, Prediction: 2, Actual: 2 --- Next Price: 1.78
# Price: 1.78, Prediction: 2, Actual: 2 --- Next Price: 1.76
# Price: 1.76, Prediction: 2, Actual: 2 --- Next Price: 1.73
# Price: 1.73, Prediction: 2, Actual: 2 --- Next Price: 1.57
# Price: 1.57, Prediction: 1, Actual: 1 --- Next Price: 1.57
# Price: 1.57, Prediction: 1, Actual: 1 --- Next Price: 1.58
# Price: 1.58, Prediction: 1, Actual: 1 --- Next Price: 1.59
# Price: 1.59, Prediction: 1, Actual: 1 --- Next Price: 1.61
# Price: 1.61, Prediction: 1, Actual: 1 --- Next Price: 1.62
# Price: 1.62, Prediction: 1, Actual: 1 --- Next Price: 1.80
# Price: 1.80, Prediction: 2, Actual: 2 --- Next Price: 1.80
# Price: 1.80, Prediction: 2, Actual: 2 --- Next Price: 1.79
# Price: 1.79, Prediction: 2, Actual: 2 --- Next Price: 1.78
# Price: 1.78, Prediction: 2, Actual: 2 --- Next Price: 1.77
# Price: 1.77, Prediction: 2, Actual: 2 --- Next Price: 1.77
# Price: 1.77, Prediction: 2, Actual: 2 --- Next Price: 1.76
# Price: 1.76, Prediction: 2, Actual: 2 --- Next Price: 1.75
# Price: 1.75, Prediction: 2, Actual: 2 --- Next Price: 1.74
# Price: 1.74, Prediction: 2, Actual: 2 --- Next Price: 1.72
# Price: 1.72, Prediction: 2, Actual: 2 --- Next Price: 1.70
# Price: 1.70, Prediction: 2, Actual: 2 --- Next Price: 1.68
# Price: 1.68, Prediction: 2, Actual: 2 --- Next Price: 1.42
# Price: 1.42, Prediction: 1, Actual: 0 --- Next Price: 1.42
# Price: 1.42, Prediction: 0, Actual: 1 --- Next Price: 1.43
# Price: 1.43, Prediction: 1, Actual: 1 --- Next Price: 1.44
# Price: 1.44, Prediction: 0, Actual: 1 --- Next Price: 1.45
# Price: 1.45, Prediction: 1, Actual: 1 --- Next Price: 1.46
# Price: 1.46, Prediction: 0, Actual: 1 --- Next Price: 1.47
# Price: 1.47, Prediction: 1, Actual: 1 --- Next Price: 1.48
# Price: 1.48, Prediction: 0, Actual: 1 --- Next Price: 1.49
# Price: 1.49, Prediction: 0, Actual: 1 --- Next Price: 1.50
# Price: 1.50, Prediction: 1, Actual: 1 --- Next Price: 1.51
# Price: 1.51, Prediction: 1, Actual: 1 --- Next Price: 1.52
# Price: 1.52, Prediction: 1, Actual: 1 --- Next Price: 1.53
# Price: 1.53, Prediction: 1, Actual: 1 --- Next Price: 1.55
# Price: 1.55, Prediction: 1, Actual: 1 --- Next Price: 1.56
# Price: 1.56, Prediction: 1, Actual: 1 --- Next Price: 1.57
# Price: 1.57, Prediction: 1, Actual: 1 --- Next Price: 1.58
# Price: 1.58, Prediction: 1, Actual: 1 --- Next Price: 1.60
# Price: 1.60, Prediction: 1, Actual: 1 --- Next Price: 1.61
# Price: 1.61, Prediction: 1, Actual: 1 --- Next Price: 1.76
# Price: 1.76, Prediction: 1, Actual: 2 --- Next Price: 1.76
# Price: 1.76, Prediction: 2, Actual: 2 --- Next Price: 1.75
# Price: 1.75, Prediction: 2, Actual: 2 --- Next Price: 1.74
# Price: 1.74, Prediction: 2, Actual: 2 --- Next Price: 1.72
# Price: 1.72, Prediction: 2, Actual: 2 --- Next Price: 1.71
# Price: 1.71, Prediction: 2, Actual: 2 --- Next Price: 1.68
# Price: 1.68, Prediction: 2, Actual: 2 --- Next Price: 1.66
# Price: 1.66, Prediction: 2, Actual: 2 --- Next Price: 1.65
# Price: 1.65, Prediction: 2, Actual: 2 --- Next Price: 1.63
# Price: 1.63, Prediction: 1, Actual: 2 --- Next Price: 1.61
# Price: 1.61, Prediction: 2, Actual: 2 --- Next Price: 1.60
# Price: 1.60, Prediction: 2, Actual: 2 --- Next Price: 1.58
# Price: 1.58, Prediction: 2, Actual: 2 --- Next Price: 1.56
# Price: 1.56, Prediction: 1, Actual: 2 --- Next Price: 1.55
# Price: 1.55, Prediction: 2, Actual: 2 --- Next Price: 1.53
# Price: 1.53, Prediction: 2, Actual: 2 --- Next Price: 1.52
# Price: 1.52, Prediction: 2, Actual: 2 --- Next Price: 1.42
# Price: 1.42, Prediction: 1, Actual: 0 --- Next Price: 1.42
# Price: 1.42, Prediction: 1, Actual: 0 --- Next Price: 1.42
# Price: 1.42, Prediction: 1, Actual: 1 --- Next Price: 1.43
# Price: 1.43, Prediction: 1, Actual: 1 --- Next Price: 1.44
# Price: 1.44, Prediction: 1, Actual: 1 --- Next Price: 1.45
# Price: 1.45, Prediction: 1, Actual: 1 --- Next Price: 1.46
# Price: 1.46, Prediction: 1, Actual: 1 --- Next Price: 1.48
# Price: 1.48, Prediction: 1, Actual: 1 --- Next Price: 1.50
# Price: 1.50, Prediction: 1, Actual: 1 --- Next Price: 1.51
# Price: 1.51, Prediction: 1, Actual: 1 --- Next Price: 1.51
# Price: 1.51, Prediction: 0, Actual: 0 --- Next Price: 1.51
# Price: 1.51, Prediction: 1, Actual: 1 --- Next Price: 1.53
# Price: 1.53, Prediction: 1, Actual: 1 --- Next Price: 1.54
# Price: 1.54, Prediction: 1, Actual: 1 --- Next Price: 1.64
# Price: 1.64, Prediction: 2, Actual: 2 --- Next Price: 1.64
# Price: 1.64, Prediction: 2, Actual: 2 --- Next Price: 1.63
# Price: 1.63, Prediction: 2, Actual: 2 --- Next Price: 1.62
# Price: 1.62, Prediction: 2, Actual: 2 --- Next Price: 1.61
# Price: 1.61, Prediction: 2, Actual: 2 --- Next Price: 1.59
# Price: 1.59, Prediction: 2, Actual: 2 --- Next Price: 1.57
# Price: 1.57, Prediction: 2, Actual: 2 --- Next Price: 1.56
# Price: 1.56, Prediction: 2, Actual: 2 --- Next Price: 1.55
# Price: 1.55, Prediction: 2, Actual: 2 --- Next Price: 1.53
# Price: 1.53, Prediction: 2, Actual: 2 --- Next Price: 1.51
# Price: 1.51, Prediction: 2, Actual: 2 --- Next Price: 1.49
# Price: 1.49, Prediction: 2, Actual: 2 --- Next Price: 1.48
# Price: 1.48, Prediction: 0, Actual: 2 --- Next Price: 1.47
# Price: 1.47, Prediction: 2, Actual: 2 --- Next Price: 1.45
# Price: 1.45, Prediction: 2, Actual: 2 --- Next Price: 1.43
# Price: 1.43, Prediction: 2, Actual: 2 --- Next Price: 1.42
# Price: 1.42, Prediction: 2, Actual: 2 --- Next Price: 1.40
# Price: 1.40, Prediction: 2, Actual: 2 --- Next Price: 1.38
# Price: 1.38, Prediction: 2, Actual: 2 --- Next Price: 1.36
# Price: 1.36, Prediction: 2, Actual: 2 --- Next Price: 1.34
# Price: 1.34, Prediction: 2, Actual: 2 --- Next Price: 1.17
# Price: 1.17, Prediction: 1, Actual: 1 --- Next Price: 1.17
# Price: 1.17, Prediction: 1, Actual: 1 --- Next Price: 1.18
# Price: 1.18, Prediction: 1, Actual: 1 --- Next Price: 1.19
# Price: 1.19, Prediction: 1, Actual: 1 --- Next Price: 1.19
# Price: 1.19, Prediction: 1, Actual: 1 --- Next Price: 1.20
# Price: 1.20, Prediction: 1, Actual: 1 --- Next Price: 1.34
# Price: 1.34, Prediction: 2, Actual: 2 --- Next Price: 1.34
# Price: 1.34, Prediction: 2, Actual: 2 --- Next Price: 1.33
# Price: 1.33, Prediction: 0, Actual: 2 --- Next Price: 1.31
# Price: 1.31, Prediction: 2, Actual: 2 --- Next Price: 1.29
# Price: 1.29, Prediction: 2, Actual: 2 --- Next Price: 1.27
# Price: 1.27, Prediction: 2, Actual: 2 --- Next Price: 1.26
# Price: 1.26, Prediction: 2, Actual: 2 --- Next Price: 1.24
# Price: 1.24, Prediction: 2, Actual: 2 --- Next Price: 1.23
# Price: 1.23, Prediction: 2, Actual: 2 --- Next Price: 1.22
# Price: 1.22, Prediction: 2, Actual: 2 --- Next Price: 1.06
# Price: 1.06, Prediction: 1, Actual: 1 --- Next Price: 1.06
# Price: 1.06, Prediction: 1, Actual: 1 --- Next Price: 1.07
# Price: 1.07, Prediction: 1, Actual: 1 --- Next Price: 1.08
# Price: 1.08, Prediction: 1, Actual: 1 --- Next Price: 1.09
# Price: 1.09, Prediction: 1, Actual: 1 --- Next Price: 1.10
# Price: 1.10, Prediction: 1, Actual: 1 --- Next Price: 1.11
# Price: 1.11, Prediction: 1, Actual: 1 --- Next Price: 1.12
# Price: 1.12, Prediction: 1, Actual: 1 --- Next Price: 1.13
# Price: 1.13, Prediction: 1, Actual: 1 --- Next Price: 1.29
# Price: 1.29, Prediction: 2, Actual: 2 --- Next Price: 1.29
# Price: 1.29, Prediction: 2, Actual: 2 --- Next Price: 1.28
# Price: 1.28, Prediction: 2, Actual: 2 --- Next Price: 1.28
# Price: 1.28, Prediction: 2, Actual: 2 --- Next Price: 1.27
# Price: 1.27, Prediction: 2, Actual: 2 --- Next Price: 1.27
# Price: 1.27, Prediction: 2, Actual: 2 --- Next Price: 1.25
# Price: 1.25, Prediction: 2, Actual: 2 --- Next Price: 1.24
# Price: 1.24, Prediction: 2, Actual: 2 --- Next Price: 1.21
# Price: 1.21, Prediction: 2, Actual: 2 --- Next Price: 1.18
# Price: 1.18, Prediction: 2, Actual: 2 --- Next Price: 1.14
# Price: 1.14, Prediction: 2, Actual: 2 --- Next Price: 1.10
# Price: 1.10, Prediction: 2, Actual: 2 --- Next Price: 1.06
# Price: 1.06, Prediction: 2, Actual: 2 --- Next Price: 1.01
# Price: 1.01, Prediction: 2, Actual: 2 --- Next Price: 0.97
# Price: 0.97, Prediction: 2, Actual: 2 --- Next Price: 0.94
# Price: 0.94, Prediction: 2, Actual: 2 --- Next Price: 0.92
# Price: 0.92, Prediction: 0, Actual: 2 --- Next Price: 0.82
# Price: 0.82, Prediction: 1, Actual: 1 --- Next Price: 0.82
# Price: 0.82, Prediction: 1, Actual: 1 --- Next Price: 0.83
# Price: 0.83, Prediction: 1, Actual: 1 --- Next Price: 0.84
# Price: 0.84, Prediction: 0, Actual: 1 --- Next Price: 0.84
# Price: 0.84, Prediction: 1, Actual: 1 --- Next Price: 0.85
# Price: 0.85, Prediction: 1, Actual: 1 --- Next Price: 0.86
# Price: 0.86, Prediction: 1, Actual: 1 --- Next Price: 0.87
# Price: 0.87, Prediction: 1, Actual: 1 --- Next Price: 0.88
# Price: 0.88, Prediction: 1, Actual: 1 --- Next Price: 0.89
# Price: 0.89, Prediction: 1, Actual: 1 --- Next Price: 0.90
# Price: 0.90, Prediction: 1, Actual: 1 --- Next Price: 0.91
# Price: 0.91, Prediction: 1, Actual: 1 --- Next Price: 0.92
# Price: 0.92, Prediction: 1, Actual: 1 --- Next Price: 0.92
# Price: 0.92, Prediction: 1, Actual: 1 --- Next Price: 0.94
# Price: 0.94, Prediction: 1, Actual: 1 --- Next Price: 0.95
# Price: 0.95, Prediction: 1, Actual: 1 --- Next Price: 0.97
# Price: 0.97, Prediction: 1, Actual: 1 --- Next Price: 1.10
# Price: 1.10, Prediction: 1, Actual: 2 --- Next Price: 1.10
# Price: 1.10, Prediction: 2, Actual: 2 --- Next Price: 1.10
# Price: 1.10, Prediction: 2, Actual: 2 --- Next Price: 1.09
# Price: 1.09, Prediction: 2, Actual: 2 --- Next Price: 0.98
# Price: 0.98, Prediction: 1, Actual: 1 --- Next Price: 0.98
# Price: 0.98, Prediction: 1, Actual: 1 --- Next Price: 0.98
# Price: 0.98, Prediction: 1, Actual: 1 --- Next Price: 0.99
# Price: 0.99, Prediction: 1, Actual: 1 --- Next Price: 0.99
# Price: 0.99, Prediction: 1, Actual: 1 --- Next Price: 1.00
# Price: 1.00, Prediction: 1, Actual: 1 --- Next Price: 1.00
# Price: 1.00, Prediction: 1, Actual: 1 --- Next Price: 1.01
# Price: 1.01, Prediction: 1, Actual: 1 --- Next Price: 1.01
# Price: 1.01, Prediction: 1, Actual: 1 --- Next Price: 1.02
# Price: 1.02, Prediction: 1, Actual: 1 --- Next Price: 1.02
# Price: 1.02, Prediction: 1, Actual: 1 --- Next Price: 1.03
# Price: 1.03, Prediction: 1, Actual: 1 --- Next Price: 1.03
# Price: 1.03, Prediction: 1, Actual: 1 --- Next Price: 1.12
# Price: 1.12, Prediction: 2, Actual: 2 --- Next Price: 1.12
# Price: 1.12, Prediction: 2, Actual: 2 --- Next Price: 1.12
# Price: 1.12, Prediction: 2, Actual: 2 --- Next Price: 1.11
# Price: 1.11, Prediction: 2, Actual: 2 --- Next Price: 1.11
# Price: 1.11, Prediction: 2, Actual: 2 --- Next Price: 1.11
# Price: 1.11, Prediction: 2, Actual: 2 --- Next Price: 1.10
# Price: 1.10, Prediction: 2, Actual: 2 --- Next Price: 1.09
# Price: 1.09, Prediction: 2, Actual: 2 --- Next Price: 1.09
# Price: 1.09, Prediction: 2, Actual: 2 --- Next Price: 1.08
# Price: 1.08, Prediction: 2, Actual: 2 --- Next Price: 1.07
# Price: 1.07, Prediction: 2, Actual: 2 --- Next Price: 1.05
# ['trading_bot.joblib']

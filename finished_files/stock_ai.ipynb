# %%
# Import Modules

import numpy as np
import pandas as pd
import os
import random
import copy
import matplotlib.pyplot as plt
import pandas
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score, TimeSeriesSplit 
from sklearn.metrics import accuracy_score, confusion_matrix
import joblib
from sklearn import tree

os.chdir('./input/Data/Stocks')
list = os.listdir()
number_files = len(list)

#filenames = [x for x in os.listdir("./Stocks/") if x.endswith('.txt') and os.path.getsize(x) > 0]
filenames = random.sample([x for x in os.listdir() if x.endswith('.txt') 
                           and os.path.getsize(os.path.join('',x)) > 0], 8)

data = []
for filename in filenames:
    df = pd.read_csv(os.path.join('',filename), sep=',')
    label, _, _ = filename.split(sep='.')
    df['Label'] = label
    df['Date'] = pd.to_datetime(df['Date'])

    data.append(df)

TechIndicator = copy.deepcopy(data)


# Relative Strength Index
# Avg(PriceUp)/(Avg(PriceUP)+Avg(PriceDown)*100
# Where: PriceUp(t)=1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)>0};
#        PriceDown(t)=-1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)<0};

def rsi(values):
    up = values[values>0].mean()
    down = -1*values[values<0].mean()
    return 100 * up / (up + down)

# Add Momentum_1D column for all 15 stocks.
# Momentum_1D = P(t) - P(t-1)
for stock in range(len(TechIndicator)):
    TechIndicator[stock]['Momentum_1D'] = (TechIndicator[stock]['Close']-TechIndicator[stock]['Close'].shift(1)).fillna(0)
    TechIndicator[stock]['RSI_14D'] = TechIndicator[stock]['Momentum_1D'].rolling(center=False, window=14).apply(rsi).fillna(0)

### Calculation of Volume (Plain)m
for stock in range(len(TechIndicator)):
    TechIndicator[stock]['Volume_plain'] = TechIndicator[stock]['Volume'].fillna(0)
TechIndicator[0].tail()

def bbands(price, length=30, numsd=2):
    """ returns average, upper band, and lower band"""
    #ave = pd.stats.moments.rolling_mean(price,length)
    ave = price.rolling(window = length, center = False).mean()
    #sd = pd.stats.moments.rolling_std(price,length)
    sd = price.rolling(window = length, center = False).std()
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['BB_Middle_Band'], TechIndicator[stock]['BB_Upper_Band'], TechIndicator[stock]['BB_Lower_Band'] = bbands(TechIndicator[stock]['Close'], length=20, numsd=1)
    TechIndicator[stock]['BB_Middle_Band'] = TechIndicator[stock]['BB_Middle_Band'].fillna(0)
    TechIndicator[stock]['BB_Upper_Band'] = TechIndicator[stock]['BB_Upper_Band'].fillna(0)
    TechIndicator[stock]['BB_Lower_Band'] = TechIndicator[stock]['BB_Lower_Band'].fillna(0)

def aroon(df, tf=25):
    aroonup = []
    aroondown = []
    x = tf
    while x< len(df['Date']):
        aroon_up = ((df['High'][x-tf:x].tolist().index(max(df['High'][x-tf:x])))/float(tf))*100
        aroon_down = ((df['Low'][x-tf:x].tolist().index(min(df['Low'][x-tf:x])))/float(tf))*100
        aroonup.append(aroon_up)
        aroondown.append(aroon_down)
        x+=1
    return aroonup, aroondown

for stock in range(len(TechIndicator)):
    listofzeros = [0] * 25
    up, down = aroon(TechIndicator[stock])
    aroon_list = [x - y for x, y in zip(up,down)]
    if len(aroon_list)==0:
        aroon_list = [0] * TechIndicator[stock].shape[0]
        TechIndicator[stock]['Aroon_Oscillator'] = aroon_list
    else:
        TechIndicator[stock]['Aroon_Oscillator'] = listofzeros+aroon_list

for stock in range(len(TechIndicator)):
    TechIndicator[stock]["PVT"] = (TechIndicator[stock]['Momentum_1D']/ TechIndicator[stock]['Close'].shift(1))*TechIndicator[stock]['Volume']
    TechIndicator[stock]["PVT"] = TechIndicator[stock]["PVT"]-TechIndicator[stock]["PVT"].shift(1)
    TechIndicator[stock]["PVT"] = TechIndicator[stock]["PVT"].fillna(0)

def abands(df):
    #df['AB_Middle_Band'] = pd.rolling_mean(df['Close'], 20)
    df['AB_Middle_Band'] = df['Close'].rolling(window = 20, center=False).mean()
    # High * ( 1 + 4 * (High - Low) / (High + Low))
    df['aupband'] = df['High'] * (1 + 4 * (df['High']-df['Low'])/(df['High']+df['Low']))
    df['AB_Upper_Band'] = df['aupband'].rolling(window=20, center=False).mean()
    # Low *(1 - 4 * (High - Low)/ (High + Low))
    df['adownband'] = df['Low'] * (1 - 4 * (df['High']-df['Low'])/(df['High']+df['Low']))
    df['AB_Lower_Band'] = df['adownband'].rolling(window=20, center=False).mean()

for stock in range(len(TechIndicator)):
    abands(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)
TechIndicator[0].tail()

columns2Drop = ['Momentum_1D', 'aupband', 'adownband']
for stock in range(len(TechIndicator)):
    TechIndicator[stock] = TechIndicator[stock].drop(labels = columns2Drop, axis=1)
TechIndicator[0].head()

def STOK(df, n):
    df['STOK'] = ((df['Close'] - df['Low'].rolling(window=n, center=False).mean()) / (df['High'].rolling(window=n, center=False).max() - df['Low'].rolling(window=n, center=False).min())) * 100
    df['STOD'] = df['STOK'].rolling(window = 3, center=False).mean()

for stock in range(len(TechIndicator)):
    STOK(TechIndicator[stock], 4)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def CMFlow(df, tf):
    CHMF = []
    MFMs = []
    MFVs = []
    x = tf
    
    while x < len(df['Date']):
        PeriodVolume = 0
        volRange = df['Volume'][x-tf:x]
        for eachVol in volRange:
            PeriodVolume += eachVol
        
        MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
        MFV = MFM*PeriodVolume
        
        MFMs.append(MFM)
        MFVs.append(MFV)
        x+=1
    
    y = tf
    while y < len(MFVs):
        PeriodVolume = 0
        volRange = df['Volume'][x-tf:x]
        for eachVol in volRange:
            PeriodVolume += eachVol
        consider = MFVs[y-tf:y]
        tfsMFV = 0
        
        for eachMFV in consider:
            tfsMFV += eachMFV
        
        tfsCMF = tfsMFV/PeriodVolume
        CHMF.append(tfsCMF)
        y+=1
    return CHMF

for stock in range(len(TechIndicator)):
    listofzeros = [0] * 40
    CHMF = CMFlow(TechIndicator[stock], 20)
    if len(CHMF)==0:
        CHMF = [0] * TechIndicator[stock].shape[0]
        TechIndicator[stock]['Chaikin_MF'] = CHMF
    else:
        TechIndicator[stock]['Chaikin_MF'] = listofzeros+CHMF

def psar(df, iaf = 0.02, maxaf = 0.2):
    length = len(df)
    dates = (df['Date'])
    high = (df['High'])
    low = (df['Low'])
    close = (df['Close'])
    psar = df['Close'][0:len(df['Close'])]
    psarbull = [None] * length
    psarbear = [None] * length
    bull = True
    af = iaf
    ep = df['Low'][0]
    hp = df['High'][0]
    lp = df['Low'][0]
    for i in range(2,length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if df['Low'][i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = df['Low'][i]
                af = iaf
        else:
            if df['High'][i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = df['High'][i]
                af = iaf
        if not reverse:
            if bull:
                if df['High'][i] > hp:
                    hp = df['High'][i]
                    af = min(af + iaf, maxaf)
                if df['Low'][i - 1] < psar[i]:
                    psar[i] = df['Low'][i - 1]
                if df['Low'][i - 2] < psar[i]:
                    psar[i] = df['Low'][i - 2]
            else:
                if df['Low'][i] < lp:
                    lp = df['Low'][i]
                    af = min(af + iaf, maxaf)
                if df['High'][i - 1] > psar[i]:
                    psar[i] = df['High'][i - 1]
                if df['High'][i - 2] > psar[i]:
                    psar[i] = df['High'][i - 2]
        if bull:
            psarbull[i] = psar[i]
        else:
            psarbear[i] = psar[i]
    #return {"dates":dates, "high":high, "low":low, "close":close, "psar":psar, "psarbear":psarbear, "psarbull":psarbull}
    #return psar, psarbear, psarbull
    df['psar'] = psar
    #df['psarbear'] = psarbear
    #df['psarbull'] = psarbull

for stock in range(len(TechIndicator)):
    psar(TechIndicator[stock])

# ROC = [(Close - Close n periods ago) / (Close n periods ago)] * 100
for stock in range(len(TechIndicator)):
    TechIndicator[stock]['ROC'] = ((TechIndicator[stock]['Close'] - TechIndicator[stock]['Close'].shift(12))/(TechIndicator[stock]['Close'].shift(12)))*100
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['VWAP'] = np.cumsum(TechIndicator[stock]['Volume'] * (TechIndicator[stock]['High'] + TechIndicator[stock]['Low'])/2) / np.cumsum(TechIndicator[stock]['Volume'])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['Momentum'] = TechIndicator[stock]['Close'] - TechIndicator[stock]['Close'].shift(4)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def CCI(df, n, constant):
    TP = (df['High'] + df['Low'] + df['Close']) / 3
    CCI = pd.Series((TP - TP.rolling(window=n, center=False).mean()) / (constant * TP.rolling(window=n, center=False).std())) #, name = 'CCI_' + str(n))
    return CCI

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['CCI'] = CCI(TechIndicator[stock], 20, 0.015)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    new = (TechIndicator[stock]['Volume'] * (~TechIndicator[stock]['Close'].diff().le(0) * 2 -1)).cumsum()
    TechIndicator[stock]['OBV'] = new

#Keltner Channel  
def KELCH(df, n):  
    KelChM = pd.Series(((df['High'] + df['Low'] + df['Close']) / 3).rolling(window =n, center=False).mean(), name = 'KelChM_' + str(n))  
    KelChU = pd.Series(((4 * df['High'] - 2 * df['Low'] + df['Close']) / 3).rolling(window =n, center=False).mean(), name = 'KelChU_' + str(n))  
    KelChD = pd.Series(((-2 * df['High'] + 4 * df['Low'] + df['Close']) / 3).rolling(window =n, center=False).mean(), name = 'KelChD_' + str(n))    
    return KelChM, KelChD, KelChU

for stock in range(len(TechIndicator)):
    KelchM, KelchD, KelchU = KELCH(TechIndicator[stock], 14)
    TechIndicator[stock]['Kelch_Upper'] = KelchU
    TechIndicator[stock]['Kelch_Middle'] = KelchM
    TechIndicator[stock]['Kelch_Down'] = KelchD
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['EMA'] = TechIndicator[stock]['Close'].ewm(span=3,min_periods=0,adjust=True,ignore_na=False).mean()
    
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['TEMA'] = (3 * TechIndicator[stock]['EMA'] - 3 * TechIndicator[stock]['EMA'] * TechIndicator[stock]['EMA']) + (TechIndicator[stock]['EMA']*TechIndicator[stock]['EMA']*TechIndicator[stock]['EMA'])

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['HL'] = TechIndicator[stock]['High'] - TechIndicator[stock]['Low']
    TechIndicator[stock]['absHC'] = abs(TechIndicator[stock]['High'] - TechIndicator[stock]['Close'].shift(1))
    TechIndicator[stock]['absLC'] = abs(TechIndicator[stock]['Low'] - TechIndicator[stock]['Close'].shift(1))
    TechIndicator[stock]['TR'] = TechIndicator[stock][['HL','absHC','absLC']].max(axis=1)
    TechIndicator[stock]['ATR'] = TechIndicator[stock]['TR'].rolling(window=14).mean()
    TechIndicator[stock]['NATR'] = (TechIndicator[stock]['ATR'] / TechIndicator[stock]['Close']) *100
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def DMI(df, period):
    df['UpMove'] = df['High'] - df['High'].shift(1)
    df['DownMove'] = df['Low'].shift(1) - df['Low']
    df['Zero'] = 0

    df['PlusDM'] = np.where((df['UpMove'] > df['DownMove']) & (df['UpMove'] > df['Zero']), df['UpMove'], 0)
    df['MinusDM'] = np.where((df['UpMove'] < df['DownMove']) & (df['DownMove'] > df['Zero']), df['DownMove'], 0)

    df['plusDI'] = 100 * (df['PlusDM']/df['ATR']).ewm(span=period,min_periods=0,adjust=True,ignore_na=False).mean()
    df['minusDI'] = 100 * (df['MinusDM']/df['ATR']).ewm(span=period,min_periods=0,adjust=True,ignore_na=False).mean()

    df['ADX'] = 100 * (abs((df['plusDI'] - df['minusDI'])/(df['plusDI'] + df['minusDI']))).ewm(span=period,min_periods=0,adjust=True,ignore_na=False).mean()

for stock in range(len(TechIndicator)):
    DMI(TechIndicator[stock], 14)
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

columns2Drop = ['UpMove', 'DownMove', 'ATR', 'PlusDM', 'MinusDM', 'Zero', 'EMA', 'HL', 'absHC', 'absLC', 'TR']
for stock in range(len(TechIndicator)):
    TechIndicator[stock] = TechIndicator[stock].drop(labels = columns2Drop, axis=1)

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['26_ema'] = TechIndicator[stock]['Close'].ewm(span=26,min_periods=0,adjust=True,ignore_na=False).mean()
    TechIndicator[stock]['12_ema'] = TechIndicator[stock]['Close'].ewm(span=12,min_periods=0,adjust=True,ignore_na=False).mean()
    TechIndicator[stock]['MACD'] = TechIndicator[stock]['12_ema'] - TechIndicator[stock]['26_ema']
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def MFI(df):
    # typical price
    df['tp'] = (df['High']+df['Low']+df['Close'])/3
    #raw money flow
    df['rmf'] = df['tp'] * df['Volume']
    
    # positive and negative money flow
    df['pmf'] = np.where(df['tp'] > df['tp'].shift(1), df['tp'], 0)
    df['nmf'] = np.where(df['tp'] < df['tp'].shift(1), df['tp'], 0)

    # money flow ratio
    df['mfr'] = df['pmf'].rolling(window=14,center=False).sum()/df['nmf'].rolling(window=14,center=False).sum()
    df['Money_Flow_Index'] = 100 - 100 / (1 + df['mfr'])

for stock in range(len(TechIndicator)):
    MFI(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def ichimoku(df):
    # Turning Line
    period9_high = df['High'].rolling(window=9,center=False).max()
    period9_low = df['Low'].rolling(window=9,center=False).min()
    df['turning_line'] = (period9_high + period9_low) / 2
    
    # Standard Line
    period26_high = df['High'].rolling(window=26,center=False).max()
    period26_low = df['Low'].rolling(window=26,center=False).min()
    df['standard_line'] = (period26_high + period26_low) / 2
    
    # Leading Span 1
    df['ichimoku_span1'] = ((df['turning_line'] + df['standard_line']) / 2).shift(26)
    
    # Leading Span 2
    period52_high = df['High'].rolling(window=52,center=False).max()
    period52_low = df['Low'].rolling(window=52,center=False).min()
    df['ichimoku_span2'] = ((period52_high + period52_low) / 2).shift(26)
    
    # The most current closing price plotted 22 time periods behind (optional)
    df['chikou_span'] = df['Close'].shift(-22) # 22 according to investopedia

for stock in range(len(TechIndicator)):
    ichimoku(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def WillR(df):
    highest_high = df['High'].rolling(window=14,center=False).max()
    lowest_low = df['Low'].rolling(window=14,center=False).min()
    df['WillR'] = (-100) * ((highest_high - df['Close']) / (highest_high - lowest_low))

for stock in range(len(TechIndicator)):
    WillR(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def MINMAX(df):
    df['MIN_Volume'] = df['Volume'].rolling(window=14,center=False).min()
    df['MAX_Volume'] = df['Volume'].rolling(window=14,center=False).max()

for stock in range(len(TechIndicator)):
    MINMAX(TechIndicator[stock])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

def KAMA(price, n=10, pow1=2, pow2=30):
    ''' kama indicator '''    
    ''' accepts pandas dataframe of prices '''

    absDiffx = abs(price - price.shift(1) )  

    ER_num = abs( price - price.shift(n) )
    ER_den = absDiffx.rolling(window=n,center=False).sum()
    ER = ER_num / ER_den

    sc = ( ER*(2.0/(pow1+1)-2.0/(pow2+1.0))+2/(pow2+1.0) ) ** 2.0


    answer = np.zeros(sc.size)
    N = len(answer)
    first_value = True

    for i in range(N):
        if sc[i] != sc[i]:
            answer[i] = np.nan
        else:
            if first_value:
                answer[i] = price[i]
                first_value = False
            else:
                answer[i] = answer[i-1] + sc[i] * (price[i] - answer[i-1])
    return answer

for stock in range(len(TechIndicator)):
    TechIndicator[stock]['KAMA'] = KAMA(TechIndicator[stock]['Close'])
    TechIndicator[stock] = TechIndicator[stock].fillna(0)

columns2Drop = ['26_ema', '12_ema','tp','rmf','pmf','nmf','mfr']
for stock in range(len(TechIndicator)):
    TechIndicator[stock] = TechIndicator[stock].drop(labels = columns2Drop, axis=1)

def get_data(stock):
    y = []
    stock['ANSWER'] = pd.Series(index=stock.index)
    extra_columns = ['KAMA', 'OpenInt', 'RSI_14D', 'Volume_plain', 'BB_Middle_Band', 'BB_Upper_Band', 'BB_Lower_Band', 'Aroon_Oscillator', 'PVT', 'AB_Middle_Band', 'AB_Upper_Band', 'AB_Lower_Band', 'STOK', 'STOD', 'Chaikin_MF', 'psar', 'ROC', 'VWAP', 'Momentum', 'CCI', 'OBV', 'Kelch_Upper', 'Kelch_Middle', 'Kelch_Down', 'TEMA', 'NATR', 'plusDI', 'minusDI', 'ADX', 'MACD', 'Money_Flow_Index', 'turning_line', 'standard_line', 'ichimoku_span1', 'ichimoku_span2', 'chikou_span', 'WillR', 'MIN_Volume', 'MAX_Volume']
    x = stock.drop(columns=['Date', 'Label', 'ANSWER']).iloc[:-10]
    # x = stock['Close'].iloc[:-10]
    for row in range(len(stock) - 10):
        condition = 0
        if stock['Close'][row] < stock['Close'][row + 1]:
            condition = 1
            stock.at[row, 'ANSWER'] = 1
        elif stock['Close'][row] > stock['Close'][row + 1]:
            condition = 2
            stock.at[row, 'ANSWER'] = 2

        y.append(condition)
    y = pd.Series(y, name='Label')
    return x, y

def train_ai(lst):
    all_x = []
    all_y = []
    for stock in range(len(lst)):
        x, y = get_data(lst[stock])
        all_x.append(x)
        all_y.append(y)
        lst[stock] = lst[stock].fillna(0, inplace=True)

    
    all_x = pd.concat(all_x, ignore_index=True)
    all_y = pd.concat(all_y, ignore_index=True)
    columns = [column for column in all_x.columns]
    
    

    tscv = TimeSeriesSplit(n_splits=5)
    model = DecisionTreeClassifier()

    # Use cross-validation to check for overfitting
    cv_scores = cross_val_score(model, all_x, all_y, cv=tscv)
    print(f"Cross-validation scores: {cv_scores}")
    print(f"Mean CV score: {cv_scores.mean()}")

    for train_index, test_index in tscv.split(all_x):
        # print('test', train_index, test_index)
        x_train, x_test = all_x.iloc[train_index], all_x.iloc[test_index]
        y_train, y_test = all_y.iloc[train_index], all_y.iloc[test_index]
        model.fit(x_train, y_train)
        predictions = model.predict(x_test)
        score = accuracy_score(y_test, predictions)
        cm = confusion_matrix(y_test, predictions)
        print(f"Test accuracy score: {score}")
        print(f"Confusion Matrix:\n{cm}")
    
        for i in range(len(x_test) - 1):
            pred = model.predict(x_test.iloc[i:i+1])
            actual = y_test.iloc[i]
            # if pred != actual:
            print(f'Price: {x_test["Close"].iloc[i]:.2f}, Prediction: {pred[0]}, Actual: {actual} --- Next Price: {x_test["Close"].iloc[i+1]:.2f}')

    return model
    

# trading_bot= train_ai(TechIndicator)
# joblib.dump(trading_bot, 'trading_bot.joblib')



trading_bot = joblib.load('trading_bot.joblib')
# Out:
# C:\Users\trygv\AppData\Local\Temp\ipykernel_18000\2837769499.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_18000\2837769499.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_18000\2837769499.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_18000\2837769499.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_18000\2837769499.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# C:\Users\trygv\AppData\Local\Temp\ipykernel_18000\2837769499.py:140: RuntimeWarning: invalid value encountered in scalar divide
#   MFM = ((df['Close'][x] - df['Low'][x]) - (df['High'][x] - df['Close'][x])) / (df['High'][x] - df['Low'][x])
# Cross-validation scores: [0.90171756 0.82156489 0.88008906 0.90998728 0.84891858]
# Mean CV score: 0.8724554707379134
# Test accuracy score: 0.8823155216284987
# Confusion Matrix:
# [[  11   30   23]
#  [ 129 1436   42]
#  [ 111   35 1327]]
# Price: 23.11, Prediction: 2, Actual: 2 --- Next Price: 22.85
# Price: 22.85, Prediction: 2, Actual: 2 --- Next Price: 22.50
# Price: 22.50, Prediction: 2, Actual: 2 --- Next Price: 21.99
# Price: 21.99, Prediction: 2, Actual: 2 --- Next Price: 21.41
# Price: 21.41, Prediction: 2, Actual: 2 --- Next Price: 20.89
# Price: 20.89, Prediction: 2, Actual: 2 --- Next Price: 20.43
# Price: 20.43, Prediction: 2, Actual: 2 --- Next Price: 20.18
# Price: 20.18, Prediction: 1, Actual: 2 --- Next Price: 19.81
# Price: 19.81, Prediction: 1, Actual: 2 --- Next Price: 17.10
# Price: 17.10, Prediction: 1, Actual: 1 --- Next Price: 17.17
# Price: 17.17, Prediction: 1, Actual: 1 --- Next Price: 17.23
# Price: 17.23, Prediction: 1, Actual: 1 --- Next Price: 17.29
# Price: 17.29, Prediction: 1, Actual: 1 --- Next Price: 20.36
# Price: 20.36, Prediction: 2, Actual: 2 --- Next Price: 20.29
# Price: 20.29, Prediction: 2, Actual: 2 --- Next Price: 20.22
# Price: 20.22, Prediction: 2, Actual: 2 --- Next Price: 20.08
# Price: 20.08, Prediction: 2, Actual: 2 --- Next Price: 19.94
# Price: 19.94, Prediction: 2, Actual: 2 --- Next Price: 16.68
# Price: 16.68, Prediction: 0, Actual: 1 --- Next Price: 16.77
# Price: 16.77, Prediction: 1, Actual: 1 --- Next Price: 16.86
# Price: 16.86, Prediction: 1, Actual: 1 --- Next Price: 17.04
# Price: 17.04, Prediction: 1, Actual: 1 --- Next Price: 17.33
# Price: 17.33, Prediction: 1, Actual: 1 --- Next Price: 17.79
# Price: 17.79, Prediction: 0, Actual: 1 --- Next Price: 18.21
# Price: 18.21, Prediction: 0, Actual: 1 --- Next Price: 18.60
# Price: 18.60, Prediction: 0, Actual: 1 --- Next Price: 18.96
# Price: 18.96, Prediction: 1, Actual: 1 --- Next Price: 19.29
# Price: 19.29, Prediction: 0, Actual: 1 --- Next Price: 19.75
# Price: 19.75, Prediction: 1, Actual: 1 --- Next Price: 20.16
# Price: 20.16, Prediction: 1, Actual: 1 --- Next Price: 20.66
# Price: 20.66, Prediction: 1, Actual: 1 --- Next Price: 21.19
# Price: 21.19, Prediction: 1, Actual: 1 --- Next Price: 21.78
# Price: 21.78, Prediction: 1, Actual: 1 --- Next Price: 22.59
# Price: 22.59, Prediction: 1, Actual: 1 --- Next Price: 23.27
# Price: 23.27, Prediction: 2, Actual: 1 --- Next Price: 23.82
# Price: 23.82, Prediction: 2, Actual: 1 --- Next Price: 26.32
# Price: 26.32, Prediction: 2, Actual: 2 --- Next Price: 26.27
# Price: 26.27, Prediction: 2, Actual: 2 --- Next Price: 26.14
# Price: 26.14, Prediction: 2, Actual: 2 --- Next Price: 26.02
# Price: 26.02, Prediction: 2, Actual: 2 --- Next Price: 25.83
# Price: 25.83, Prediction: 2, Actual: 2 --- Next Price: 25.65
# Price: 25.65, Prediction: 2, Actual: 2 --- Next Price: 22.80
# Price: 22.80, Prediction: 1, Actual: 1 --- Next Price: 22.86
# Price: 22.86, Prediction: 1, Actual: 1 --- Next Price: 22.92
# Price: 22.92, Prediction: 1, Actual: 1 --- Next Price: 23.06
# Price: 23.06, Prediction: 1, Actual: 1 --- Next Price: 23.38
# Price: 23.38, Prediction: 1, Actual: 1 --- Next Price: 23.81
# Price: 23.81, Prediction: 1, Actual: 1 --- Next Price: 24.38
# Price: 24.38, Prediction: 1, Actual: 1 --- Next Price: 24.90
# Price: 24.90, Prediction: 1, Actual: 1 --- Next Price: 25.57
# Price: 25.57, Prediction: 1, Actual: 1 --- Next Price: 26.27
# Price: 26.27, Prediction: 1, Actual: 1 --- Next Price: 26.88
# Price: 26.88, Prediction: 1, Actual: 1 --- Next Price: 30.61
# Price: 30.61, Prediction: 2, Actual: 2 --- Next Price: 30.52
# Price: 30.52, Prediction: 2, Actual: 2 --- Next Price: 30.32
# Price: 30.32, Prediction: 2, Actual: 2 --- Next Price: 30.03
# Price: 30.03, Prediction: 2, Actual: 2 --- Next Price: 29.60
# Price: 29.60, Prediction: 2, Actual: 2 --- Next Price: 29.20
# Price: 29.20, Prediction: 2, Actual: 2 --- Next Price: 28.84
# Price: 28.84, Prediction: 2, Actual: 2 --- Next Price: 28.51
# Price: 28.51, Prediction: 2, Actual: 2 --- Next Price: 28.10
# Price: 28.10, Prediction: 2, Actual: 2 --- Next Price: 27.65
# Price: 27.65, Prediction: 2, Actual: 2 --- Next Price: 27.25
# Price: 27.25, Prediction: 2, Actual: 2 --- Next Price: 26.75
# Price: 26.75, Prediction: 2, Actual: 2 --- Next Price: 26.22
# Price: 26.22, Prediction: 2, Actual: 2 --- Next Price: 25.78
# Price: 25.78, Prediction: 2, Actual: 2 --- Next Price: 25.41
# Price: 25.41, Prediction: 2, Actual: 2 --- Next Price: 23.47
# Price: 23.47, Prediction: 1, Actual: 1 --- Next Price: 23.51
# Price: 23.51, Prediction: 1, Actual: 1 --- Next Price: 25.32
# Price: 25.32, Prediction: 2, Actual: 2 --- Next Price: 25.28
# Price: 25.28, Prediction: 2, Actual: 2 --- Next Price: 25.20
# Price: 25.20, Prediction: 2, Actual: 2 --- Next Price: 23.30
# Price: 23.30, Prediction: 1, Actual: 1 --- Next Price: 23.35
# Price: 23.35, Prediction: 1, Actual: 1 --- Next Price: 23.52
# Price: 23.52, Prediction: 1, Actual: 1 --- Next Price: 23.76
# Price: 23.76, Prediction: 1, Actual: 1 --- Next Price: 24.00
# Price: 24.00, Prediction: 1, Actual: 1 --- Next Price: 24.22
# Price: 24.22, Prediction: 1, Actual: 1 --- Next Price: 24.50
# Price: 24.50, Prediction: 1, Actual: 1 --- Next Price: 24.87
# Price: 24.87, Prediction: 1, Actual: 1 --- Next Price: 28.27
# Price: 28.27, Prediction: 2, Actual: 2 --- Next Price: 28.20
# Price: 28.20, Prediction: 2, Actual: 2 --- Next Price: 28.07
# Price: 28.07, Prediction: 2, Actual: 2 --- Next Price: 27.81
# Price: 27.81, Prediction: 2, Actual: 2 --- Next Price: 27.47
# Price: 27.47, Prediction: 2, Actual: 2 --- Next Price: 27.17
# Price: 27.17, Prediction: 2, Actual: 2 --- Next Price: 26.89
# Price: 26.89, Prediction: 2, Actual: 2 --- Next Price: 26.47
# Price: 26.47, Prediction: 2, Actual: 2 --- Next Price: 26.00
# Price: 26.00, Prediction: 2, Actual: 2 --- Next Price: 25.52
# Price: 25.52, Prediction: 2, Actual: 2 --- Next Price: 25.11
# Price: 25.11, Prediction: 0, Actual: 2 --- Next Price: 24.67
# Price: 24.67, Prediction: 2, Actual: 2 --- Next Price: 23.95
# Price: 23.95, Prediction: 2, Actual: 2 --- Next Price: 23.36
# Price: 23.36, Prediction: 2, Actual: 2 --- Next Price: 22.88
# Price: 22.88, Prediction: 1, Actual: 2 --- Next Price: 22.49
# Price: 22.49, Prediction: 1, Actual: 2 --- Next Price: 22.44
# Price: 22.44, Prediction: 1, Actual: 2 --- Next Price: 22.13
# Price: 22.13, Prediction: 2, Actual: 2 --- Next Price: 21.87
# Price: 21.87, Prediction: 2, Actual: 2 --- Next Price: 20.69
# Price: 20.69, Prediction: 1, Actual: 1 --- Next Price: 20.71
# Price: 20.71, Prediction: 1, Actual: 1 --- Next Price: 20.73
# Price: 20.73, Prediction: 1, Actual: 1 --- Next Price: 20.81
# Price: 20.81, Prediction: 1, Actual: 1 --- Next Price: 20.96
# Price: 20.96, Prediction: 1, Actual: 1 --- Next Price: 21.11
# Price: 21.11, Prediction: 1, Actual: 1 --- Next Price: 21.31
# Price: 21.31, Prediction: 1, Actual: 1 --- Next Price: 21.55
# Price: 21.55, Prediction: 1, Actual: 1 --- Next Price: 21.82
# Price: 21.82, Prediction: 1, Actual: 1 --- Next Price: 22.06
# Price: 22.06, Prediction: 1, Actual: 1 --- Next Price: 22.27
# Price: 22.27, Prediction: 1, Actual: 1 --- Next Price: 22.44
# Price: 22.44, Prediction: 2, Actual: 1 --- Next Price: 22.48
# Price: 22.48, Prediction: 2, Actual: 1 --- Next Price: 24.10
# Price: 24.10, Prediction: 2, Actual: 0 --- Next Price: 24.10
# Price: 24.10, Prediction: 2, Actual: 2 --- Next Price: 24.03
# Price: 24.03, Prediction: 2, Actual: 2 --- Next Price: 23.92
# Price: 23.92, Prediction: 2, Actual: 2 --- Next Price: 23.74
# Price: 23.74, Prediction: 2, Actual: 2 --- Next Price: 23.51
# Price: 23.51, Prediction: 2, Actual: 2 --- Next Price: 23.24
# Price: 23.24, Prediction: 2, Actual: 2 --- Next Price: 21.26
# Price: 21.26, Prediction: 1, Actual: 1 --- Next Price: 21.31
# Price: 21.31, Prediction: 1, Actual: 1 --- Next Price: 21.41
# Price: 21.41, Prediction: 1, Actual: 1 --- Next Price: 21.63
# Price: 21.63, Prediction: 1, Actual: 1 --- Next Price: 21.92
# Price: 21.92, Prediction: 1, Actual: 1 --- Next Price: 22.36
# Price: 22.36, Prediction: 1, Actual: 1 --- Next Price: 22.92
# Price: 22.92, Prediction: 1, Actual: 1 --- Next Price: 23.49
# Price: 23.49, Prediction: 1, Actual: 1 --- Next Price: 23.99
# Price: 23.99, Prediction: 1, Actual: 1 --- Next Price: 24.41
# Price: 24.41, Prediction: 2, Actual: 1 --- Next Price: 24.76
# Price: 24.76, Prediction: 2, Actual: 1 --- Next Price: 27.03
# Price: 27.03, Prediction: 2, Actual: 2 --- Next Price: 26.98
# Price: 26.98, Prediction: 2, Actual: 2 --- Next Price: 26.85
# Price: 26.85, Prediction: 2, Actual: 2 --- Next Price: 26.66
# Price: 26.66, Prediction: 2, Actual: 2 --- Next Price: 26.49
# Price: 26.49, Prediction: 2, Actual: 2 --- Next Price: 26.32
# Price: 26.32, Prediction: 2, Actual: 2 --- Next Price: 23.70
# Price: 23.70, Prediction: 1, Actual: 1 --- Next Price: 23.75
# Price: 23.75, Prediction: 1, Actual: 1 --- Next Price: 23.81
# Price: 23.81, Prediction: 1, Actual: 1 --- Next Price: 23.86
# Price: 23.86, Prediction: 1, Actual: 1 --- Next Price: 23.92
# Price: 23.92, Prediction: 1, Actual: 1 --- Next Price: 26.52
# Price: 26.52, Prediction: 2, Actual: 2 --- Next Price: 26.47
# Price: 26.47, Prediction: 2, Actual: 2 --- Next Price: 26.42
# Price: 26.42, Prediction: 2, Actual: 2 --- Next Price: 23.91
# Price: 23.91, Prediction: 1, Actual: 1 --- Next Price: 23.97
# Price: 23.97, Prediction: 1, Actual: 1 --- Next Price: 24.09
# Price: 24.09, Prediction: 1, Actual: 1 --- Next Price: 24.31
# Price: 24.31, Prediction: 1, Actual: 1 --- Next Price: 24.52
# Price: 24.52, Prediction: 1, Actual: 1 --- Next Price: 24.72
# Price: 24.72, Prediction: 1, Actual: 1 --- Next Price: 24.90
# Price: 24.90, Prediction: 1, Actual: 1 --- Next Price: 25.08
# Price: 25.08, Prediction: 1, Actual: 1 --- Next Price: 25.24
# Price: 25.24, Prediction: 1, Actual: 1 --- Next Price: 25.39
# Price: 25.39, Prediction: 1, Actual: 1 --- Next Price: 25.54
# Price: 25.54, Prediction: 1, Actual: 1 --- Next Price: 25.74
# Price: 25.74, Prediction: 1, Actual: 1 --- Next Price: 26.05
# Price: 26.05, Prediction: 1, Actual: 1 --- Next Price: 26.39
# Price: 26.39, Prediction: 1, Actual: 1 --- Next Price: 26.69
# Price: 26.69, Prediction: 1, Actual: 1 --- Next Price: 26.95
# Price: 26.95, Prediction: 1, Actual: 1 --- Next Price: 27.03
# Price: 27.03, Prediction: 1, Actual: 1 --- Next Price: 27.31
# Price: 27.31, Prediction: 2, Actual: 1 --- Next Price: 29.03
# Price: 29.03, Prediction: 2, Actual: 2 --- Next Price: 28.99
# Price: 28.99, Prediction: 2, Actual: 2 --- Next Price: 28.93
# Price: 28.93, Prediction: 2, Actual: 2 --- Next Price: 28.79
# Price: 28.79, Prediction: 2, Actual: 2 --- Next Price: 28.55
# Price: 28.55, Prediction: 2, Actual: 2 --- Next Price: 28.33
# Price: 28.33, Prediction: 2, Actual: 2 --- Next Price: 28.06
# Price: 28.06, Prediction: 2, Actual: 2 --- Next Price: 27.82
# Price: 27.82, Prediction: 2, Actual: 2 --- Next Price: 25.66
# Price: 25.66, Prediction: 1, Actual: 1 --- Next Price: 25.71
# Price: 25.71, Prediction: 1, Actual: 1 --- Next Price: 25.81
# Price: 25.81, Prediction: 1, Actual: 1 --- Next Price: 26.03
# Price: 26.03, Prediction: 1, Actual: 1 --- Next Price: 26.42
# Price: 26.42, Prediction: 1, Actual: 1 --- Next Price: 26.90
# Price: 26.90, Prediction: 1, Actual: 1 --- Next Price: 27.45
# Price: 27.45, Prediction: 1, Actual: 1 --- Next Price: 28.17
# Price: 28.17, Prediction: 1, Actual: 1 --- Next Price: 28.91
# Price: 28.91, Prediction: 1, Actual: 1 --- Next Price: 29.87
# Price: 29.87, Prediction: 1, Actual: 1 --- Next Price: 30.65
# Price: 30.65, Prediction: 0, Actual: 1 --- Next Price: 34.21
# Price: 34.21, Prediction: 2, Actual: 2 --- Next Price: 34.15
# Price: 34.15, Prediction: 2, Actual: 2 --- Next Price: 34.08
# Price: 34.08, Prediction: 2, Actual: 2 --- Next Price: 33.93
# Price: 33.93, Prediction: 2, Actual: 2 --- Next Price: 33.78
# Price: 33.78, Prediction: 2, Actual: 2 --- Next Price: 33.64
# Price: 33.64, Prediction: 2, Actual: 2 --- Next Price: 33.50
# Price: 33.50, Prediction: 2, Actual: 2 --- Next Price: 33.37
# Price: 33.37, Prediction: 2, Actual: 2 --- Next Price: 33.24
# Price: 33.24, Prediction: 2, Actual: 2 --- Next Price: 33.12
# Price: 33.12, Prediction: 2, Actual: 2 --- Next Price: 33.00
# Price: 33.00, Prediction: 2, Actual: 2 --- Next Price: 32.89
# Price: 32.89, Prediction: 2, Actual: 2 --- Next Price: 32.78
# Price: 32.78, Prediction: 2, Actual: 2 --- Next Price: 32.68
# Price: 32.68, Prediction: 2, Actual: 2 --- Next Price: 32.58
# Price: 32.58, Prediction: 2, Actual: 2 --- Next Price: 32.41
# Price: 32.41, Prediction: 2, Actual: 2 --- Next Price: 32.26
# Price: 32.26, Prediction: 2, Actual: 2 --- Next Price: 29.85
# Price: 29.85, Prediction: 1, Actual: 1 --- Next Price: 29.91
# Price: 29.91, Prediction: 1, Actual: 1 --- Next Price: 29.97
# Price: 29.97, Prediction: 1, Actual: 1 --- Next Price: 30.10
# Price: 30.10, Prediction: 1, Actual: 1 --- Next Price: 30.21
# Price: 30.21, Prediction: 1, Actual: 1 --- Next Price: 30.33
# Price: 30.33, Prediction: 1, Actual: 1 --- Next Price: 30.54
# Price: 30.54, Prediction: 1, Actual: 1 --- Next Price: 30.85
# Price: 30.85, Prediction: 1, Actual: 1 --- Next Price: 31.21
# Price: 31.21, Prediction: 1, Actual: 1 --- Next Price: 31.54
# Price: 31.54, Prediction: 1, Actual: 1 --- Next Price: 31.83
# Price: 31.83, Prediction: 1, Actual: 1 --- Next Price: 32.10
# Price: 32.10, Prediction: 1, Actual: 1 --- Next Price: 32.42
# Price: 32.42, Prediction: 1, Actual: 1 --- Next Price: 32.84
# Price: 32.84, Prediction: 1, Actual: 1 --- Next Price: 33.28
# Price: 33.28, Prediction: 1, Actual: 1 --- Next Price: 33.64
# Price: 33.64, Prediction: 2, Actual: 1 --- Next Price: 33.70
# Price: 33.70, Prediction: 2, Actual: 1 --- Next Price: 35.67
# Price: 35.67, Prediction: 2, Actual: 2 --- Next Price: 35.63
# Price: 35.63, Prediction: 2, Actual: 2 --- Next Price: 35.59
# Price: 35.59, Prediction: 2, Actual: 2 --- Next Price: 35.56
# Price: 35.56, Prediction: 2, Actual: 2 --- Next Price: 35.52
# Price: 35.52, Prediction: 2, Actual: 2 --- Next Price: 35.44
# Price: 35.44, Prediction: 2, Actual: 2 --- Next Price: 35.31
# Price: 35.31, Prediction: 2, Actual: 2 --- Next Price: 35.10
# Price: 35.10, Prediction: 2, Actual: 2 --- Next Price: 34.76
# Price: 34.76, Prediction: 2, Actual: 2 --- Next Price: 34.45
# Price: 34.45, Prediction: 0, Actual: 2 --- Next Price: 31.71
# Price: 31.71, Prediction: 1, Actual: 1 --- Next Price: 31.77
# Price: 31.77, Prediction: 1, Actual: 1 --- Next Price: 31.83
# Price: 31.83, Prediction: 1, Actual: 1 --- Next Price: 31.89
# Price: 31.89, Prediction: 1, Actual: 1 --- Next Price: 32.07
# Price: 32.07, Prediction: 1, Actual: 1 --- Next Price: 32.33
# Price: 32.33, Prediction: 1, Actual: 1 --- Next Price: 32.67
# Price: 32.67, Prediction: 1, Actual: 1 --- Next Price: 33.12
# Price: 33.12, Prediction: 1, Actual: 1 --- Next Price: 33.82
# Price: 33.82, Prediction: 1, Actual: 1 --- Next Price: 34.44
# Price: 34.44, Prediction: 1, Actual: 1 --- Next Price: 34.98
# Price: 34.98, Prediction: 1, Actual: 1 --- Next Price: 35.46
# Price: 35.46, Prediction: 0, Actual: 1 --- Next Price: 35.96
# Price: 35.96, Prediction: 0, Actual: 1 --- Next Price: 36.53
# Price: 36.53, Prediction: 0, Actual: 1 --- Next Price: 37.00
# Price: 37.00, Prediction: 0, Actual: 1 --- Next Price: 37.22
# Price: 37.22, Prediction: 0, Actual: 0 --- Next Price: 37.22
# Price: 37.22, Prediction: 0, Actual: 1 --- Next Price: 37.48
# Price: 37.48, Prediction: 1, Actual: 1 --- Next Price: 37.80
# Price: 37.80, Prediction: 0, Actual: 1 --- Next Price: 39.50
# Price: 39.50, Prediction: 0, Actual: 2 --- Next Price: 39.44
# Price: 39.44, Prediction: 2, Actual: 2 --- Next Price: 39.31
# Price: 39.31, Prediction: 2, Actual: 2 --- Next Price: 39.18
# Price: 39.18, Prediction: 0, Actual: 2 --- Next Price: 39.05
# Price: 39.05, Prediction: 0, Actual: 2 --- Next Price: 38.93
# Price: 38.93, Prediction: 0, Actual: 2 --- Next Price: 38.82
# Price: 38.82, Prediction: 2, Actual: 2 --- Next Price: 38.71
# Price: 38.71, Prediction: 2, Actual: 2 --- Next Price: 38.60
# Price: 38.60, Prediction: 2, Actual: 2 --- Next Price: 38.43
# Price: 38.43, Prediction: 2, Actual: 2 --- Next Price: 38.27
# Price: 38.27, Prediction: 2, Actual: 2 --- Next Price: 38.02
# Price: 38.02, Prediction: 2, Actual: 2 --- Next Price: 37.72
# Price: 37.72, Prediction: 2, Actual: 2 --- Next Price: 37.30
# Price: 37.30, Prediction: 2, Actual: 2 --- Next Price: 36.93
# Price: 36.93, Prediction: 2, Actual: 2 --- Next Price: 36.53
# Price: 36.53, Prediction: 2, Actual: 2 --- Next Price: 36.19
# Price: 36.19, Prediction: 1, Actual: 2 --- Next Price: 34.08
# Price: 34.08, Prediction: 0, Actual: 1 --- Next Price: 34.15
# Price: 34.15, Prediction: 1, Actual: 1 --- Next Price: 34.22
# Price: 34.22, Prediction: 0, Actual: 1 --- Next Price: 34.29
# Price: 34.29, Prediction: 1, Actual: 1 --- Next Price: 34.44
# Price: 34.44, Prediction: 1, Actual: 1 --- Next Price: 34.72
# Price: 34.72, Prediction: 1, Actual: 1 --- Next Price: 34.98
# Price: 34.98, Prediction: 1, Actual: 1 --- Next Price: 35.34
# Price: 35.34, Prediction: 1, Actual: 1 --- Next Price: 35.67
# Price: 35.67, Prediction: 1, Actual: 1 --- Next Price: 36.12
# Price: 36.12, Prediction: 1, Actual: 1 --- Next Price: 36.53
# Price: 36.53, Prediction: 1, Actual: 1 --- Next Price: 36.99
# Price: 36.99, Prediction: 1, Actual: 1 --- Next Price: 37.39
# Price: 37.39, Prediction: 1, Actual: 1 --- Next Price: 37.74
# Price: 37.74, Prediction: 1, Actual: 1 --- Next Price: 40.31
# Price: 40.31, Prediction: 2, Actual: 2 --- Next Price: 40.20
# Price: 40.20, Prediction: 2, Actual: 2 --- Next Price: 39.98
# Price: 39.98, Prediction: 2, Actual: 2 --- Next Price: 39.77
# Price: 39.77, Prediction: 2, Actual: 2 --- Next Price: 39.57
# Price: 39.57, Prediction: 2, Actual: 2 --- Next Price: 39.38
# Price: 39.38, Prediction: 2, Actual: 2 --- Next Price: 39.19
# Price: 39.19, Prediction: 2, Actual: 2 --- Next Price: 34.71
# Price: 34.71, Prediction: 1, Actual: 1 --- Next Price: 34.80
# Price: 34.80, Prediction: 1, Actual: 1 --- Next Price: 34.99
# Price: 34.99, Prediction: 1, Actual: 1 --- Next Price: 35.27
# Price: 35.27, Prediction: 1, Actual: 1 --- Next Price: 35.68
# Price: 35.68, Prediction: 1, Actual: 1 --- Next Price: 36.18
# Price: 36.18, Prediction: 1, Actual: 1 --- Next Price: 36.62
# Price: 36.62, Prediction: 1, Actual: 1 --- Next Price: 37.02
# Price: 37.02, Prediction: 1, Actual: 1 --- Next Price: 37.38
# Price: 37.38, Prediction: 1, Actual: 1 --- Next Price: 40.61
# Price: 40.61, Prediction: 2, Actual: 2 --- Next Price: 40.55
# Price: 40.55, Prediction: 2, Actual: 2 --- Next Price: 40.40
# Price: 40.40, Prediction: 2, Actual: 2 --- Next Price: 40.18
# Price: 40.18, Prediction: 2, Actual: 2 --- Next Price: 39.88
# Price: 39.88, Prediction: 2, Actual: 2 --- Next Price: 39.51
# Price: 39.51, Prediction: 2, Actual: 2 --- Next Price: 39.17
# Price: 39.17, Prediction: 2, Actual: 2 --- Next Price: 36.10
# Price: 36.10, Prediction: 1, Actual: 1 --- Next Price: 36.16
# Price: 36.16, Prediction: 1, Actual: 1 --- Next Price: 36.22
# Price: 36.22, Prediction: 1, Actual: 1 --- Next Price: 36.27
# Price: 36.27, Prediction: 1, Actual: 1 --- Next Price: 36.40
# Price: 36.40, Prediction: 1, Actual: 1 --- Next Price: 36.53
# Price: 36.53, Prediction: 1, Actual: 1 --- Next Price: 36.73
# Price: 36.73, Prediction: 1, Actual: 1 --- Next Price: 39.87
# Price: 39.87, Prediction: 2, Actual: 2 --- Next Price: 39.80
# Price: 39.80, Prediction: 2, Actual: 2 --- Next Price: 39.66
# Price: 39.66, Prediction: 2, Actual: 2 --- Next Price: 39.39
# Price: 39.39, Prediction: 2, Actual: 2 --- Next Price: 39.04
# Price: 39.04, Prediction: 2, Actual: 2 --- Next Price: 38.71
# Price: 38.71, Prediction: 2, Actual: 2 --- Next Price: 34.97
# Price: 34.97, Prediction: 0, Actual: 1 --- Next Price: 35.04
# Price: 35.04, Prediction: 1, Actual: 1 --- Next Price: 35.11
# Price: 35.11, Prediction: 1, Actual: 1 --- Next Price: 35.18
# Price: 35.18, Prediction: 1, Actual: 1 --- Next Price: 35.25
# Price: 35.25, Prediction: 1, Actual: 1 --- Next Price: 35.32
# Price: 35.32, Prediction: 1, Actual: 1 --- Next Price: 35.38
# Price: 35.38, Prediction: 1, Actual: 1 --- Next Price: 35.45
# Price: 35.45, Prediction: 1, Actual: 1 --- Next Price: 35.51
# Price: 35.51, Prediction: 1, Actual: 1 --- Next Price: 35.57
# Price: 35.57, Prediction: 1, Actual: 1 --- Next Price: 35.63
# Price: 35.63, Prediction: 1, Actual: 1 --- Next Price: 35.76
# Price: 35.76, Prediction: 1, Actual: 1 --- Next Price: 35.95
# Price: 35.95, Prediction: 1, Actual: 1 --- Next Price: 36.20
# Price: 36.20, Prediction: 1, Actual: 1 --- Next Price: 36.53
# Price: 36.53, Prediction: 1, Actual: 1 --- Next Price: 36.83
# Price: 36.83, Prediction: 1, Actual: 1 --- Next Price: 37.10
# Price: 37.10, Prediction: 1, Actual: 1 --- Next Price: 37.40
# Price: 37.40, Prediction: 1, Actual: 1 --- Next Price: 37.92
# Price: 37.92, Prediction: 1, Actual: 1 --- Next Price: 38.49
# Price: 38.49, Prediction: 1, Actual: 1 --- Next Price: 38.97
# Price: 38.97, Prediction: 1, Actual: 1 --- Next Price: 39.38
# Price: 39.38, Prediction: 2, Actual: 1 --- Next Price: 39.65
# Price: 39.65, Prediction: 1, Actual: 1 --- Next Price: 39.75
# Price: 39.75, Prediction: 1, Actual: 1 --- Next Price: 40.10
# Price: 40.10, Prediction: 2, Actual: 1 --- Next Price: 41.65
# Price: 41.65, Prediction: 2, Actual: 2 --- Next Price: 41.62
# Price: 41.62, Prediction: 2, Actual: 2 --- Next Price: 41.60
# Price: 41.60, Prediction: 2, Actual: 2 --- Next Price: 41.48
# Price: 41.48, Prediction: 2, Actual: 2 --- Next Price: 41.29
# Price: 41.29, Prediction: 2, Actual: 2 --- Next Price: 41.00
# Price: 41.00, Prediction: 2, Actual: 2 --- Next Price: 40.58
# Price: 40.58, Prediction: 2, Actual: 2 --- Next Price: 40.21
# Price: 40.21, Prediction: 0, Actual: 2 --- Next Price: 39.79
# Price: 39.79, Prediction: 2, Actual: 2 --- Next Price: 39.42
# Price: 39.42, Prediction: 2, Actual: 2 --- Next Price: 39.03
# Price: 39.03, Prediction: 2, Actual: 2 --- Next Price: 38.70
# Price: 38.70, Prediction: 2, Actual: 2 --- Next Price: 38.41
# Price: 38.41, Prediction: 1, Actual: 2 --- Next Price: 38.23
# Price: 38.23, Prediction: 1, Actual: 0 --- Next Price: 38.23
# Price: 38.23, Prediction: 1, Actual: 2 --- Next Price: 38.01
# Price: 38.01, Prediction: 2, Actual: 2 --- Next Price: 37.81
# Price: 37.81, Prediction: 2, Actual: 2 --- Next Price: 37.72
# Price: 37.72, Prediction: 2, Actual: 2 --- Next Price: 37.42
# Price: 37.42, Prediction: 2, Actual: 2 --- Next Price: 35.87
# Price: 35.87, Prediction: 1, Actual: 1 --- Next Price: 35.92
# Price: 35.92, Prediction: 1, Actual: 1 --- Next Price: 38.38
# Price: 38.38, Prediction: 2, Actual: 2 --- Next Price: 38.32
# Price: 38.32, Prediction: 2, Actual: 2 --- Next Price: 38.26
# Price: 38.26, Prediction: 2, Actual: 2 --- Next Price: 38.20
# Price: 38.20, Prediction: 2, Actual: 2 --- Next Price: 38.07
# Price: 38.07, Prediction: 2, Actual: 2 --- Next Price: 37.87
# Price: 37.87, Prediction: 2, Actual: 2 --- Next Price: 37.61
# Price: 37.61, Prediction: 2, Actual: 2 --- Next Price: 37.37
# Price: 37.37, Prediction: 0, Actual: 2 --- Next Price: 37.08
# Price: 37.08, Prediction: 2, Actual: 2 --- Next Price: 36.82
# Price: 36.82, Prediction: 2, Actual: 2 --- Next Price: 36.59
# Price: 36.59, Prediction: 2, Actual: 2 --- Next Price: 36.32
# Price: 36.32, Prediction: 2, Actual: 2 --- Next Price: 36.07
# Price: 36.07, Prediction: 2, Actual: 2 --- Next Price: 35.86
# Price: 35.86, Prediction: 2, Actual: 2 --- Next Price: 35.68
# Price: 35.68, Prediction: 2, Actual: 2 --- Next Price: 35.51
# Price: 35.51, Prediction: 2, Actual: 2 --- Next Price: 35.34
# Price: 35.34, Prediction: 2, Actual: 2 --- Next Price: 33.71
# Price: 33.71, Prediction: 1, Actual: 0 --- Next Price: 33.71
# Price: 33.71, Prediction: 1, Actual: 1 --- Next Price: 35.34
# Price: 35.34, Prediction: 0, Actual: 0 --- Next Price: 35.34
# Price: 35.34, Prediction: 2, Actual: 2 --- Next Price: 35.22
# Price: 35.22, Prediction: 2, Actual: 2 --- Next Price: 35.11
# Price: 35.11, Prediction: 2, Actual: 2 --- Next Price: 35.00
# Price: 35.00, Prediction: 2, Actual: 2 --- Next Price: 34.90
# Price: 34.90, Prediction: 2, Actual: 2 --- Next Price: 34.80
# Price: 34.80, Prediction: 2, Actual: 2 --- Next Price: 34.70
# Price: 34.70, Prediction: 2, Actual: 2 --- Next Price: 34.61
# Price: 34.61, Prediction: 2, Actual: 2 --- Next Price: 34.52
# Price: 34.52, Prediction: 2, Actual: 2 --- Next Price: 32.40
# Price: 32.40, Prediction: 1, Actual: 1 --- Next Price: 32.46
# Price: 32.46, Prediction: 1, Actual: 1 --- Next Price: 32.59
# Price: 32.59, Prediction: 1, Actual: 1 --- Next Price: 32.72
# Price: 32.72, Prediction: 1, Actual: 1 --- Next Price: 32.84
# Price: 32.84, Prediction: 1, Actual: 1 --- Next Price: 32.96
# Price: 32.96, Prediction: 1, Actual: 1 --- Next Price: 33.07
# Price: 33.07, Prediction: 1, Actual: 1 --- Next Price: 33.18
# Price: 33.18, Prediction: 1, Actual: 1 --- Next Price: 35.78
# Price: 35.78, Prediction: 2, Actual: 2 --- Next Price: 35.73
# Price: 35.73, Prediction: 2, Actual: 2 --- Next Price: 35.59
# Price: 35.59, Prediction: 2, Actual: 2 --- Next Price: 35.46
# Price: 35.46, Prediction: 2, Actual: 2 --- Next Price: 35.23
# Price: 35.23, Prediction: 2, Actual: 2 --- Next Price: 34.93
# Price: 34.93, Prediction: 2, Actual: 2 --- Next Price: 34.38
# Price: 34.38, Prediction: 2, Actual: 2 --- Next Price: 33.89
# Price: 33.89, Prediction: 0, Actual: 2 --- Next Price: 33.45
# Price: 33.45, Prediction: 2, Actual: 2 --- Next Price: 32.95
# Price: 32.95, Prediction: 2, Actual: 2 --- Next Price: 32.34
# Price: 32.34, Prediction: 2, Actual: 2 --- Next Price: 31.53
# Price: 31.53, Prediction: 2, Actual: 2 --- Next Price: 30.84
# Price: 30.84, Prediction: 2, Actual: 2 --- Next Price: 30.17
# Price: 30.17, Prediction: 2, Actual: 2 --- Next Price: 29.62
# Price: 29.62, Prediction: 2, Actual: 2 --- Next Price: 29.16
# Price: 29.16, Prediction: 2, Actual: 2 --- Next Price: 27.10
# Price: 27.10, Prediction: 1, Actual: 1 --- Next Price: 27.15
# Price: 27.15, Prediction: 1, Actual: 1 --- Next Price: 27.19
# Price: 27.19, Prediction: 1, Actual: 1 --- Next Price: 27.29
# Price: 27.29, Prediction: 1, Actual: 1 --- Next Price: 27.38
# Price: 27.38, Prediction: 1, Actual: 1 --- Next Price: 27.47
# Price: 27.47, Prediction: 1, Actual: 1 --- Next Price: 27.60
# Price: 27.60, Prediction: 1, Actual: 1 --- Next Price: 27.73
# Price: 27.73, Prediction: 1, Actual: 1 --- Next Price: 27.90
# Price: 27.90, Prediction: 1, Actual: 1 --- Next Price: 28.20
# Price: 28.20, Prediction: 1, Actual: 1 --- Next Price: 28.46
# Price: 28.46, Prediction: 1, Actual: 1 --- Next Price: 28.70
# Price: 28.70, Prediction: 1, Actual: 1 --- Next Price: 28.91
# Price: 28.91, Prediction: 1, Actual: 1 --- Next Price: 29.09
# Price: 29.09, Prediction: 1, Actual: 0 --- Next Price: 29.09
# Price: 29.09, Prediction: 1, Actual: 1 --- Next Price: 29.42
# Price: 29.42, Prediction: 1, Actual: 1 --- Next Price: 29.85
# Price: 29.85, Prediction: 1, Actual: 1 --- Next Price: 30.21
# Price: 30.21, Prediction: 1, Actual: 1 --- Next Price: 32.09
# Price: 32.09, Prediction: 2, Actual: 2 --- Next Price: 32.05
# Price: 32.05, Prediction: 2, Actual: 2 --- Next Price: 32.01
# Price: 32.01, Prediction: 2, Actual: 2 --- Next Price: 31.98
# Price: 31.98, Prediction: 2, Actual: 2 --- Next Price: 31.94
# Price: 31.94, Prediction: 2, Actual: 2 --- Next Price: 31.90
# Price: 31.90, Prediction: 2, Actual: 2 --- Next Price: 31.87
# Price: 31.87, Prediction: 2, Actual: 2 --- Next Price: 31.78
# Price: 31.78, Prediction: 2, Actual: 2 --- Next Price: 31.70
# Price: 31.70, Prediction: 2, Actual: 2 --- Next Price: 31.62
# Price: 31.62, Prediction: 2, Actual: 2 --- Next Price: 31.48
# Price: 31.48, Prediction: 2, Actual: 2 --- Next Price: 31.30
# Price: 31.30, Prediction: 2, Actual: 2 --- Next Price: 31.14
# Price: 31.14, Prediction: 2, Actual: 2 --- Next Price: 29.24
# Price: 29.24, Prediction: 1, Actual: 1 --- Next Price: 29.29
# Price: 29.29, Prediction: 1, Actual: 1 --- Next Price: 29.39
# Price: 29.39, Prediction: 1, Actual: 1 --- Next Price: 29.54
# Price: 29.54, Prediction: 1, Actual: 1 --- Next Price: 29.75
# Price: 29.75, Prediction: 1, Actual: 1 --- Next Price: 30.05
# Price: 30.05, Prediction: 1, Actual: 1 --- Next Price: 30.40
# Price: 30.40, Prediction: 1, Actual: 1 --- Next Price: 32.99
# Price: 32.99, Prediction: 2, Actual: 2 --- Next Price: 32.93
# Price: 32.93, Prediction: 2, Actual: 2 --- Next Price: 32.79
# Price: 32.79, Prediction: 2, Actual: 2 --- Next Price: 32.64
# Price: 32.64, Prediction: 2, Actual: 2 --- Next Price: 32.51
# Price: 32.51, Prediction: 2, Actual: 2 --- Next Price: 32.38
# Price: 32.38, Prediction: 2, Actual: 2 --- Next Price: 32.17
# Price: 32.17, Prediction: 2, Actual: 2 --- Next Price: 31.86
# Price: 31.86, Prediction: 2, Actual: 2 --- Next Price: 31.31
# Price: 31.31, Prediction: 2, Actual: 2 --- Next Price: 30.82
# Price: 30.82, Prediction: 2, Actual: 2 --- Next Price: 30.25
# Price: 30.25, Prediction: 2, Actual: 2 --- Next Price: 29.75
# Price: 29.75, Prediction: 2, Actual: 2 --- Next Price: 29.31
# Price: 29.31, Prediction: 2, Actual: 2 --- Next Price: 28.92
# Price: 28.92, Prediction: 2, Actual: 2 --- Next Price: 28.58
# Price: 28.58, Prediction: 2, Actual: 2 --- Next Price: 28.15
# Price: 28.15, Prediction: 2, Actual: 2 --- Next Price: 27.69
# Price: 27.69, Prediction: 2, Actual: 2 --- Next Price: 27.21
# Price: 27.21, Prediction: 2, Actual: 2 --- Next Price: 26.70
# Price: 26.70, Prediction: 1, Actual: 2 --- Next Price: 24.66
# Price: 24.66, Prediction: 1, Actual: 1 --- Next Price: 24.72
# Price: 24.72, Prediction: 1, Actual: 1 --- Next Price: 24.79
# Price: 24.79, Prediction: 1, Actual: 1 --- Next Price: 24.85
# Price: 24.85, Prediction: 1, Actual: 1 --- Next Price: 24.91
# Price: 24.91, Prediction: 1, Actual: 1 --- Next Price: 24.97
# Price: 24.97, Prediction: 1, Actual: 1 --- Next Price: 25.03
# Price: 25.03, Prediction: 1, Actual: 1 --- Next Price: 25.08
# Price: 25.08, Prediction: 1, Actual: 1 --- Next Price: 27.90
# Price: 27.90, Prediction: 2, Actual: 2 --- Next Price: 27.82
# Price: 27.82, Prediction: 2, Actual: 2 --- Next Price: 27.65
# Price: 27.65, Prediction: 2, Actual: 2 --- Next Price: 27.38
# Price: 27.38, Prediction: 2, Actual: 2 --- Next Price: 27.13
# Price: 27.13, Prediction: 2, Actual: 2 --- Next Price: 26.90
# Price: 26.90, Prediction: 2, Actual: 2 --- Next Price: 26.68
# Price: 26.68, Prediction: 2, Actual: 2 --- Next Price: 26.47
# Price: 26.47, Prediction: 2, Actual: 2 --- Next Price: 26.27
# Price: 26.27, Prediction: 2, Actual: 2 --- Next Price: 26.09
# Price: 26.09, Prediction: 0, Actual: 2 --- Next Price: 25.92
# Price: 25.92, Prediction: 2, Actual: 2 --- Next Price: 25.76
# Price: 25.76, Prediction: 2, Actual: 2 --- Next Price: 25.60
# Price: 25.60, Prediction: 2, Actual: 2 --- Next Price: 25.52
# Price: 25.52, Prediction: 2, Actual: 0 --- Next Price: 25.52
# Price: 25.52, Prediction: 2, Actual: 2 --- Next Price: 23.22
# Price: 23.22, Prediction: 1, Actual: 1 --- Next Price: 23.27
# Price: 23.27, Prediction: 1, Actual: 1 --- Next Price: 23.32
# Price: 23.32, Prediction: 1, Actual: 1 --- Next Price: 23.36
# Price: 23.36, Prediction: 1, Actual: 1 --- Next Price: 23.41
# Price: 23.41, Prediction: 1, Actual: 1 --- Next Price: 23.45
# Price: 23.45, Prediction: 1, Actual: 1 --- Next Price: 23.55
# Price: 23.55, Prediction: 1, Actual: 1 --- Next Price: 23.73
# Price: 23.73, Prediction: 1, Actual: 1 --- Next Price: 23.98
# Price: 23.98, Prediction: 1, Actual: 1 --- Next Price: 24.27
# Price: 24.27, Prediction: 1, Actual: 1 --- Next Price: 24.53
# Price: 24.53, Prediction: 1, Actual: 1 --- Next Price: 24.77
# Price: 24.77, Prediction: 1, Actual: 1 --- Next Price: 24.98
# Price: 24.98, Prediction: 1, Actual: 1 --- Next Price: 25.31
# Price: 25.31, Prediction: 1, Actual: 1 --- Next Price: 25.65
# Price: 25.65, Prediction: 1, Actual: 1 --- Next Price: 25.95
# Price: 25.95, Prediction: 2, Actual: 1 --- Next Price: 26.21
# Price: 26.21, Prediction: 0, Actual: 1 --- Next Price: 27.78
# Price: 27.78, Prediction: 2, Actual: 2 --- Next Price: 27.75
# Price: 27.75, Prediction: 0, Actual: 2 --- Next Price: 27.67
# Price: 27.67, Prediction: 0, Actual: 2 --- Next Price: 25.80
# Price: 25.80, Prediction: 1, Actual: 1 --- Next Price: 25.84
# Price: 25.84, Prediction: 1, Actual: 1 --- Next Price: 25.96
# Price: 25.96, Prediction: 1, Actual: 1 --- Next Price: 26.17
# Price: 26.17, Prediction: 1, Actual: 1 --- Next Price: 26.36
# Price: 26.36, Prediction: 1, Actual: 1 --- Next Price: 26.55
# Price: 26.55, Prediction: 1, Actual: 1 --- Next Price: 26.72
# Price: 26.72, Prediction: 1, Actual: 1 --- Next Price: 26.88
# Price: 26.88, Prediction: 1, Actual: 1 --- Next Price: 29.42
# Price: 29.42, Prediction: 2, Actual: 2 --- Next Price: 29.37
# Price: 29.37, Prediction: 2, Actual: 2 --- Next Price: 29.32
# Price: 29.32, Prediction: 2, Actual: 2 --- Next Price: 29.22
# Price: 29.22, Prediction: 2, Actual: 2 --- Next Price: 29.06
# Price: 29.06, Prediction: 2, Actual: 2 --- Next Price: 28.82
# Price: 28.82, Prediction: 2, Actual: 2 --- Next Price: 28.61
# Price: 28.61, Prediction: 2, Actual: 2 --- Next Price: 26.14
# Price: 26.14, Prediction: 1, Actual: 1 --- Next Price: 26.20
# Price: 26.20, Prediction: 1, Actual: 1 --- Next Price: 26.37
# Price: 26.37, Prediction: 1, Actual: 1 --- Next Price: 26.54
# Price: 26.54, Prediction: 1, Actual: 1 --- Next Price: 26.70
# Price: 26.70, Prediction: 1, Actual: 1 --- Next Price: 26.85
# Price: 26.85, Prediction: 1, Actual: 1 --- Next Price: 26.99
# Price: 26.99, Prediction: 1, Actual: 1 --- Next Price: 27.13
# Price: 27.13, Prediction: 1, Actual: 1 --- Next Price: 27.27
# Price: 27.27, Prediction: 1, Actual: 1 --- Next Price: 27.46
# Price: 27.46, Prediction: 1, Actual: 1 --- Next Price: 27.75
# Price: 27.75, Prediction: 1, Actual: 1 --- Next Price: 28.01
# Price: 28.01, Prediction: 1, Actual: 1 --- Next Price: 28.25
# Price: 28.25, Prediction: 1, Actual: 1 --- Next Price: 28.47
# Price: 28.47, Prediction: 1, Actual: 1 --- Next Price: 28.68
# Price: 28.68, Prediction: 1, Actual: 1 --- Next Price: 31.02
# Price: 31.02, Prediction: 2, Actual: 2 --- Next Price: 30.98
# Price: 30.98, Prediction: 2, Actual: 2 --- Next Price: 30.93
# Price: 30.93, Prediction: 2, Actual: 2 --- Next Price: 30.89
# Price: 30.89, Prediction: 2, Actual: 2 --- Next Price: 28.66
# Price: 28.66, Prediction: 1, Actual: 1 --- Next Price: 28.72
# Price: 28.72, Prediction: 1, Actual: 1 --- Next Price: 28.78
# Price: 28.78, Prediction: 1, Actual: 1 --- Next Price: 28.83
# Price: 28.83, Prediction: 1, Actual: 1 --- Next Price: 28.89
# Price: 28.89, Prediction: 1, Actual: 1 --- Next Price: 28.94
# Price: 28.94, Prediction: 1, Actual: 1 --- Next Price: 28.99
# Price: 28.99, Prediction: 1, Actual: 1 --- Next Price: 29.04
# Price: 29.04, Prediction: 2, Actual: 1 --- Next Price: 29.09
# Price: 29.09, Prediction: 2, Actual: 1 --- Next Price: 29.14
# Price: 29.14, Prediction: 1, Actual: 1 --- Next Price: 29.24
# Price: 29.24, Prediction: 1, Actual: 1 --- Next Price: 29.40
# Price: 29.40, Prediction: 1, Actual: 1 --- Next Price: 29.69
# Price: 29.69, Prediction: 1, Actual: 1 --- Next Price: 29.96
# Price: 29.96, Prediction: 1, Actual: 1 --- Next Price: 30.21
# Price: 30.21, Prediction: 1, Actual: 1 --- Next Price: 33.06
# Price: 33.06, Prediction: 2, Actual: 2 --- Next Price: 33.00
# Price: 33.00, Prediction: 2, Actual: 2 --- Next Price: 32.94
# Price: 32.94, Prediction: 2, Actual: 2 --- Next Price: 32.88
# Price: 32.88, Prediction: 2, Actual: 2 --- Next Price: 32.83
# Price: 32.83, Prediction: 2, Actual: 2 --- Next Price: 32.78
# Price: 32.78, Prediction: 2, Actual: 2 --- Next Price: 32.72
# Price: 32.72, Prediction: 2, Actual: 2 --- Next Price: 32.67
# Price: 32.67, Prediction: 2, Actual: 2 --- Next Price: 32.57
# Price: 32.57, Prediction: 2, Actual: 2 --- Next Price: 32.46
# Price: 32.46, Prediction: 2, Actual: 2 --- Next Price: 32.37
# Price: 32.37, Prediction: 2, Actual: 2 --- Next Price: 32.27
# Price: 32.27, Prediction: 2, Actual: 2 --- Next Price: 32.13
# Price: 32.13, Prediction: 2, Actual: 2 --- Next Price: 31.93
# Price: 31.93, Prediction: 2, Actual: 2 --- Next Price: 31.75
# Price: 31.75, Prediction: 2, Actual: 2 --- Next Price: 31.58
# Price: 31.58, Prediction: 2, Actual: 2 --- Next Price: 31.43
# Price: 31.43, Prediction: 2, Actual: 2 --- Next Price: 31.29
# Price: 31.29, Prediction: 2, Actual: 2 --- Next Price: 31.16
# Price: 31.16, Prediction: 2, Actual: 2 --- Next Price: 30.85
# Price: 30.85, Prediction: 2, Actual: 2 --- Next Price: 30.46
# Price: 30.46, Prediction: 2, Actual: 2 --- Next Price: 30.12
# Price: 30.12, Prediction: 2, Actual: 2 --- Next Price: 29.79
# Price: 29.79, Prediction: 2, Actual: 2 --- Next Price: 27.65
# Price: 27.65, Prediction: 1, Actual: 0 --- Next Price: 27.65
# Price: 27.65, Prediction: 1, Actual: 1 --- Next Price: 27.69
# Price: 27.69, Prediction: 1, Actual: 1 --- Next Price: 27.77
# Price: 27.77, Prediction: 1, Actual: 1 --- Next Price: 27.91
# Price: 27.91, Prediction: 1, Actual: 1 --- Next Price: 28.03
# Price: 28.03, Prediction: 1, Actual: 1 --- Next Price: 28.15
# Price: 28.15, Prediction: 1, Actual: 1 --- Next Price: 28.26
# Price: 28.26, Prediction: 1, Actual: 1 --- Next Price: 28.36
# Price: 28.36, Prediction: 1, Actual: 1 --- Next Price: 28.46
# Price: 28.46, Prediction: 1, Actual: 1 --- Next Price: 28.63
# Price: 28.63, Prediction: 1, Actual: 1 --- Next Price: 28.86
# Price: 28.86, Prediction: 1, Actual: 1 --- Next Price: 29.12
# Price: 29.12, Prediction: 1, Actual: 1 --- Next Price: 29.35
# Price: 29.35, Prediction: 1, Actual: 1 --- Next Price: 29.63
# Price: 29.63, Prediction: 1, Actual: 1 --- Next Price: 29.86
# Price: 29.86, Prediction: 1, Actual: 1 --- Next Price: 30.06
# Price: 30.06, Prediction: 1, Actual: 1 --- Next Price: 30.39
# Price: 30.39, Prediction: 1, Actual: 1 --- Next Price: 30.67
# Price: 30.67, Prediction: 1, Actual: 1 --- Next Price: 31.13
# Price: 31.13, Prediction: 0, Actual: 1 --- Next Price: 31.49
# Price: 31.49, Prediction: 0, Actual: 1 --- Next Price: 32.95
# Price: 32.95, Prediction: 2, Actual: 2 --- Next Price: 31.77
# Price: 31.77, Prediction: 1, Actual: 0 --- Next Price: 31.77
# Price: 31.77, Prediction: 1, Actual: 1 --- Next Price: 31.85
# Price: 31.85, Prediction: 1, Actual: 1 --- Next Price: 31.93
# Price: 31.93, Prediction: 1, Actual: 1 --- Next Price: 32.00
# Price: 32.00, Prediction: 1, Actual: 1 --- Next Price: 33.82
# Price: 33.82, Prediction: 2, Actual: 2 --- Next Price: 33.78
# Price: 33.78, Prediction: 2, Actual: 2 --- Next Price: 33.69
# Price: 33.69, Prediction: 2, Actual: 2 --- Next Price: 31.37
# Price: 31.37, Prediction: 1, Actual: 1 --- Next Price: 31.42
# Price: 31.42, Prediction: 1, Actual: 1 --- Next Price: 31.53
# Price: 31.53, Prediction: 1, Actual: 1 --- Next Price: 31.63
# Price: 31.63, Prediction: 1, Actual: 1 --- Next Price: 34.19
# Price: 34.19, Prediction: 2, Actual: 2 --- Next Price: 34.13
# Price: 34.13, Prediction: 2, Actual: 2 --- Next Price: 34.02
# Price: 34.02, Prediction: 2, Actual: 2 --- Next Price: 33.91
# Price: 33.91, Prediction: 2, Actual: 2 --- Next Price: 33.81
# Price: 33.81, Prediction: 2, Actual: 2 --- Next Price: 33.71
# Price: 33.71, Prediction: 2, Actual: 2 --- Next Price: 33.62
# Price: 33.62, Prediction: 2, Actual: 2 --- Next Price: 33.45
# Price: 33.45, Prediction: 2, Actual: 2 --- Next Price: 33.23
# Price: 33.23, Prediction: 2, Actual: 2 --- Next Price: 32.96
# Price: 32.96, Prediction: 2, Actual: 2 --- Next Price: 32.61
# Price: 32.61, Prediction: 2, Actual: 2 --- Next Price: 32.24
# Price: 32.24, Prediction: 2, Actual: 2 --- Next Price: 31.83
# Price: 31.83, Prediction: 2, Actual: 2 --- Next Price: 31.42
# Price: 31.42, Prediction: 2, Actual: 2 --- Next Price: 31.08
# Price: 31.08, Prediction: 2, Actual: 2 --- Next Price: 29.53
# Price: 29.53, Prediction: 1, Actual: 0 --- Next Price: 29.53
# Price: 29.53, Prediction: 1, Actual: 1 --- Next Price: 29.58
# Price: 29.58, Prediction: 1, Actual: 1 --- Next Price: 29.64
# Price: 29.64, Prediction: 1, Actual: 1 --- Next Price: 29.69
# Price: 29.69, Prediction: 1, Actual: 1 --- Next Price: 29.74
# Price: 29.74, Prediction: 1, Actual: 1 --- Next Price: 31.05
# Price: 31.05, Prediction: 2, Actual: 0 --- Next Price: 31.05
# Price: 31.05, Prediction: 2, Actual: 2 --- Next Price: 30.98
# Price: 30.98, Prediction: 2, Actual: 2 --- Next Price: 30.91
# Price: 30.91, Prediction: 2, Actual: 2 --- Next Price: 30.85
# Price: 30.85, Prediction: 2, Actual: 2 --- Next Price: 30.79
# Price: 30.79, Prediction: 2, Actual: 2 --- Next Price: 30.73
# Price: 30.73, Prediction: 2, Actual: 2 --- Next Price: 30.67
# Price: 30.67, Prediction: 2, Actual: 2 --- Next Price: 30.51
# Price: 30.51, Prediction: 2, Actual: 2 --- Next Price: 30.27
# Price: 30.27, Prediction: 2, Actual: 2 --- Next Price: 29.90
# Price: 29.90, Prediction: 2, Actual: 2 --- Next Price: 29.56
# Price: 29.56, Prediction: 2, Actual: 2 --- Next Price: 29.26
# Price: 29.26, Prediction: 2, Actual: 2 --- Next Price: 29.00
# Price: 29.00, Prediction: 2, Actual: 2 --- Next Price: 28.75
# Price: 28.75, Prediction: 2, Actual: 2 --- Next Price: 28.54
# Price: 28.54, Prediction: 2, Actual: 2 --- Next Price: 28.34
# Price: 28.34, Prediction: 2, Actual: 2 --- Next Price: 28.16
# Price: 28.16, Prediction: 1, Actual: 2 --- Next Price: 28.06
# Price: 28.06, Prediction: 1, Actual: 2 --- Next Price: 27.87
# Price: 27.87, Prediction: 2, Actual: 2 --- Next Price: 27.44
# Price: 27.44, Prediction: 2, Actual: 2 --- Next Price: 27.07
# Price: 27.07, Prediction: 2, Actual: 2 --- Next Price: 26.75
# Price: 26.75, Prediction: 2, Actual: 2 --- Next Price: 26.48
# Price: 26.48, Prediction: 2, Actual: 2 --- Next Price: 26.42
# Price: 26.42, Prediction: 2, Actual: 2 --- Next Price: 24.79
# Price: 24.79, Prediction: 1, Actual: 1 --- Next Price: 24.82
# Price: 24.82, Prediction: 1, Actual: 1 --- Next Price: 24.89
# Price: 24.89, Prediction: 1, Actual: 1 --- Next Price: 25.00
# Price: 25.00, Prediction: 1, Actual: 1 --- Next Price: 25.16
# Price: 25.16, Prediction: 1, Actual: 1 --- Next Price: 25.42
# Price: 25.42, Prediction: 1, Actual: 1 --- Next Price: 25.71
# Price: 25.71, Prediction: 1, Actual: 1 --- Next Price: 26.05
# Price: 26.05, Prediction: 1, Actual: 1 --- Next Price: 26.42
# Price: 26.42, Prediction: 1, Actual: 1 --- Next Price: 26.85
# Price: 26.85, Prediction: 1, Actual: 1 --- Next Price: 27.28
# Price: 27.28, Prediction: 1, Actual: 1 --- Next Price: 27.64
# Price: 27.64, Prediction: 1, Actual: 1 --- Next Price: 28.09
# Price: 28.09, Prediction: 0, Actual: 1 --- Next Price: 28.45
# Price: 28.45, Prediction: 0, Actual: 1 --- Next Price: 28.86
# Price: 28.86, Prediction: 0, Actual: 1 --- Next Price: 29.18
# Price: 29.18, Prediction: 0, Actual: 1 --- Next Price: 29.47
# Price: 29.47, Prediction: 0, Actual: 1 --- Next Price: 29.70
# Price: 29.70, Prediction: 0, Actual: 1 --- Next Price: 29.87
# Price: 29.87, Prediction: 0, Actual: 1 --- Next Price: 31.14
# Price: 31.14, Prediction: 2, Actual: 2 --- Next Price: 31.11
# Price: 31.11, Prediction: 2, Actual: 2 --- Next Price: 31.09
# Price: 31.09, Prediction: 2, Actual: 2 --- Next Price: 31.06
# Price: 31.06, Prediction: 2, Actual: 2 --- Next Price: 31.04
# Price: 31.04, Prediction: 2, Actual: 2 --- Next Price: 31.01
# Price: 31.01, Prediction: 0, Actual: 2 --- Next Price: 30.99
# Price: 30.99, Prediction: 2, Actual: 2 --- Next Price: 30.96
# Price: 30.96, Prediction: 2, Actual: 2 --- Next Price: 29.35
# Price: 29.35, Prediction: 1, Actual: 0 --- Next Price: 29.35
# Price: 29.35, Prediction: 1, Actual: 1 --- Next Price: 29.42
# Price: 29.42, Prediction: 1, Actual: 1 --- Next Price: 29.48
# Price: 29.48, Prediction: 1, Actual: 1 --- Next Price: 29.59
# Price: 29.59, Prediction: 1, Actual: 1 --- Next Price: 29.69
# Price: 29.69, Prediction: 1, Actual: 1 --- Next Price: 29.84
# Price: 29.84, Prediction: 1, Actual: 1 --- Next Price: 31.57
# Price: 31.57, Prediction: 2, Actual: 2 --- Next Price: 31.53
# Price: 31.53, Prediction: 2, Actual: 2 --- Next Price: 31.49
# Price: 31.49, Prediction: 2, Actual: 2 --- Next Price: 31.39
# Price: 31.39, Prediction: 2, Actual: 2 --- Next Price: 31.24
# Price: 31.24, Prediction: 2, Actual: 2 --- Next Price: 31.05
# Price: 31.05, Prediction: 2, Actual: 2 --- Next Price: 30.82
# Price: 30.82, Prediction: 2, Actual: 2 --- Next Price: 30.62
# Price: 30.62, Prediction: 2, Actual: 2 --- Next Price: 28.78
# Price: 28.78, Prediction: 1, Actual: 1 --- Next Price: 28.81
# Price: 28.81, Prediction: 1, Actual: 1 --- Next Price: 28.92
# Price: 28.92, Prediction: 1, Actual: 1 --- Next Price: 29.11
# Price: 29.11, Prediction: 1, Actual: 1 --- Next Price: 29.28
# Price: 29.28, Prediction: 1, Actual: 1 --- Next Price: 29.54
# Price: 29.54, Prediction: 1, Actual: 1 --- Next Price: 29.78
# Price: 29.78, Prediction: 1, Actual: 1 --- Next Price: 30.00
# Price: 30.00, Prediction: 1, Actual: 1 --- Next Price: 30.21
# Price: 30.21, Prediction: 1, Actual: 1 --- Next Price: 30.57
# Price: 30.57, Prediction: 1, Actual: 1 --- Next Price: 30.98
# Price: 30.98, Prediction: 1, Actual: 1 --- Next Price: 31.34
# Price: 31.34, Prediction: 1, Actual: 1 --- Next Price: 31.66
# Price: 31.66, Prediction: 1, Actual: 1 --- Next Price: 31.94
# Price: 31.94, Prediction: 2, Actual: 1 --- Next Price: 32.18
# Price: 32.18, Prediction: 1, Actual: 1 --- Next Price: 32.33
# Price: 32.33, Prediction: 1, Actual: 1 --- Next Price: 32.51
# Price: 32.51, Prediction: 1, Actual: 1 --- Next Price: 32.79
# Price: 32.79, Prediction: 1, Actual: 1 --- Next Price: 33.04
# Price: 33.04, Prediction: 2, Actual: 1 --- Next Price: 34.53
# Price: 34.53, Prediction: 2, Actual: 2 --- Next Price: 34.51
# Price: 34.51, Prediction: 2, Actual: 2 --- Next Price: 34.44
# Price: 34.44, Prediction: 2, Actual: 2 --- Next Price: 34.32
# Price: 34.32, Prediction: 2, Actual: 2 --- Next Price: 34.18
# Price: 34.18, Prediction: 2, Actual: 2 --- Next Price: 33.95
# Price: 33.95, Prediction: 2, Actual: 2 --- Next Price: 33.69
# Price: 33.69, Prediction: 2, Actual: 2 --- Next Price: 33.41
# Price: 33.41, Prediction: 2, Actual: 2 --- Next Price: 33.17
# Price: 33.17, Prediction: 2, Actual: 2 --- Next Price: 32.91
# Price: 32.91, Prediction: 2, Actual: 2 --- Next Price: 31.54
# Price: 31.54, Prediction: 2, Actual: 1 --- Next Price: 31.57
# Price: 31.57, Prediction: 1, Actual: 1 --- Next Price: 31.62
# Price: 31.62, Prediction: 1, Actual: 1 --- Next Price: 31.71
# Price: 31.71, Prediction: 1, Actual: 1 --- Next Price: 31.80
# Price: 31.80, Prediction: 1, Actual: 1 --- Next Price: 31.87
# Price: 31.87, Prediction: 1, Actual: 1 --- Next Price: 31.95
# Price: 31.95, Prediction: 1, Actual: 1 --- Next Price: 32.01
# Price: 32.01, Prediction: 1, Actual: 1 --- Next Price: 32.09
# Price: 32.09, Prediction: 1, Actual: 1 --- Next Price: 32.18
# Price: 32.18, Prediction: 1, Actual: 1 --- Next Price: 32.33
# Price: 32.33, Prediction: 1, Actual: 1 --- Next Price: 32.46
# Price: 32.46, Prediction: 1, Actual: 1 --- Next Price: 32.55
# Price: 32.55, Prediction: 1, Actual: 1 --- Next Price: 33.66
# Price: 33.66, Prediction: 2, Actual: 2 --- Next Price: 33.63
# Price: 33.63, Prediction: 2, Actual: 2 --- Next Price: 32.55
# Price: 32.55, Prediction: 1, Actual: 1 --- Next Price: 32.58
# Price: 32.58, Prediction: 1, Actual: 1 --- Next Price: 32.60
# Price: 32.60, Prediction: 1, Actual: 1 --- Next Price: 32.65
# Price: 32.65, Prediction: 1, Actual: 1 --- Next Price: 32.69
# Price: 32.69, Prediction: 1, Actual: 1 --- Next Price: 32.74
# Price: 32.74, Prediction: 1, Actual: 1 --- Next Price: 33.81
# Price: 33.81, Prediction: 2, Actual: 2 --- Next Price: 33.78
# Price: 33.78, Prediction: 2, Actual: 2 --- Next Price: 33.71
# Price: 33.71, Prediction: 2, Actual: 2 --- Next Price: 33.58
# Price: 33.58, Prediction: 2, Actual: 2 --- Next Price: 33.41
# ...
# Price: 23.04, Prediction: 2, Actual: 2 --- Next Price: 23.02
# Price: 23.02, Prediction: 2, Actual: 2 --- Next Price: 22.98
# Price: 22.98, Prediction: 2, Actual: 2 --- Next Price: 22.94
# Price: 22.94, Prediction: 2, Actual: 2 --- Next Price: 22.88
# Price: 22.88, Prediction: 2, Actual: 2 --- Next Price: 22.81
# Price: 22.81, Prediction: 2, Actual: 2 --- Next Price: 22.75
# Price: 22.75, Prediction: 2, Actual: 2 --- Next Price: 22.69
# Price: 22.69, Prediction: 2, Actual: 2 --- Next Price: 22.64
# Price: 22.64, Prediction: 2, Actual: 2 --- Next Price: 22.60
# Price: 22.60, Prediction: 2, Actual: 2 --- Next Price: 22.54
# Price: 22.54, Prediction: 2, Actual: 2 --- Next Price: 22.49
# Price: 22.49, Prediction: 2, Actual: 2 --- Next Price: 22.44
# Price: 22.44, Prediction: 2, Actual: 2 --- Next Price: 22.40
# Price: 22.40, Prediction: 2, Actual: 2 --- Next Price: 22.38
# Price: 22.38, Prediction: 2, Actual: 2 --- Next Price: 22.30
# Price: 22.30, Prediction: 2, Actual: 2 --- Next Price: 21.89
# Price: 21.89, Prediction: 1, Actual: 1 --- Next Price: 21.90
# Price: 21.90, Prediction: 1, Actual: 1 --- Next Price: 22.28
# Price: 22.28, Prediction: 2, Actual: 2 --- Next Price: 21.74
# Price: 21.74, Prediction: 1, Actual: 0 --- Next Price: 21.74
# Price: 21.74, Prediction: 1, Actual: 1 --- Next Price: 21.81
# Price: 21.81, Prediction: 1, Actual: 1 --- Next Price: 21.96
# Price: 21.96, Prediction: 1, Actual: 1 --- Next Price: 22.09
# Price: 22.09, Prediction: 1, Actual: 1 --- Next Price: 22.26
# Price: 22.26, Prediction: 1, Actual: 1 --- Next Price: 22.47
# Price: 22.47, Prediction: 1, Actual: 1 --- Next Price: 22.69
# Price: 22.69, Prediction: 1, Actual: 1 --- Next Price: 22.89
# Price: 22.89, Prediction: 1, Actual: 1 --- Next Price: 23.14
# Price: 23.14, Prediction: 1, Actual: 1 --- Next Price: 23.35
# Price: 23.35, Prediction: 1, Actual: 1 --- Next Price: 23.57
# Price: 23.57, Prediction: 1, Actual: 1 --- Next Price: 23.75
# Price: 23.75, Prediction: 1, Actual: 1 --- Next Price: 23.90
# Price: 23.90, Prediction: 1, Actual: 1 --- Next Price: 24.03
# Price: 24.03, Prediction: 1, Actual: 1 --- Next Price: 24.14
# Price: 24.14, Prediction: 1, Actual: 1 --- Next Price: 24.23
# Price: 24.23, Prediction: 1, Actual: 1 --- Next Price: 24.32
# Price: 24.32, Prediction: 1, Actual: 1 --- Next Price: 24.44
# Price: 24.44, Prediction: 1, Actual: 1 --- Next Price: 24.63
# Price: 24.63, Prediction: 1, Actual: 1 --- Next Price: 24.82
# Price: 24.82, Prediction: 1, Actual: 1 --- Next Price: 25.01
# Price: 25.01, Prediction: 1, Actual: 1 --- Next Price: 25.16
# Price: 25.16, Prediction: 1, Actual: 1 --- Next Price: 25.28
# Price: 25.28, Prediction: 2, Actual: 1 --- Next Price: 25.76
# Price: 25.76, Prediction: 1, Actual: 2 --- Next Price: 25.75
# Price: 25.75, Prediction: 2, Actual: 2 --- Next Price: 25.73
# Price: 25.73, Prediction: 2, Actual: 2 --- Next Price: 25.71
# Price: 25.71, Prediction: 2, Actual: 2 --- Next Price: 25.68
# Price: 25.68, Prediction: 2, Actual: 2 --- Next Price: 25.66
# Price: 25.66, Prediction: 2, Actual: 2 --- Next Price: 25.61
# Price: 25.61, Prediction: 2, Actual: 2 --- Next Price: 25.55
# Price: 25.55, Prediction: 2, Actual: 2 --- Next Price: 25.48
# Price: 25.48, Prediction: 2, Actual: 2 --- Next Price: 25.40
# Price: 25.40, Prediction: 2, Actual: 2 --- Next Price: 25.32
# Price: 25.32, Prediction: 2, Actual: 2 --- Next Price: 25.22
# Price: 25.22, Prediction: 2, Actual: 2 --- Next Price: 24.54
# Price: 24.54, Prediction: 1, Actual: 1 --- Next Price: 24.55
# Price: 24.55, Prediction: 1, Actual: 1 --- Next Price: 24.57
# Price: 24.57, Prediction: 1, Actual: 1 --- Next Price: 25.22
# Price: 25.22, Prediction: 2, Actual: 2 --- Next Price: 25.21
# Price: 25.21, Prediction: 2, Actual: 2 --- Next Price: 25.20
# Price: 25.20, Prediction: 2, Actual: 2 --- Next Price: 25.18
# Price: 25.18, Prediction: 2, Actual: 2 --- Next Price: 25.17
# Price: 25.17, Prediction: 2, Actual: 2 --- Next Price: 25.16
# Price: 25.16, Prediction: 2, Actual: 2 --- Next Price: 25.15
# Price: 25.15, Prediction: 2, Actual: 2 --- Next Price: 25.13
# Price: 25.13, Prediction: 2, Actual: 2 --- Next Price: 25.12
# Price: 25.12, Prediction: 2, Actual: 2 --- Next Price: 25.11
# Price: 25.11, Prediction: 2, Actual: 2 --- Next Price: 25.08
# Price: 25.08, Prediction: 2, Actual: 2 --- Next Price: 25.04
# Price: 25.04, Prediction: 2, Actual: 2 --- Next Price: 25.01
# Price: 25.01, Prediction: 2, Actual: 2 --- Next Price: 25.00
# Price: 25.00, Prediction: 0, Actual: 0 --- Next Price: 25.00
# Price: 25.00, Prediction: 2, Actual: 2 --- Next Price: 24.96
# Price: 24.96, Prediction: 2, Actual: 2 --- Next Price: 24.93
# Price: 24.93, Prediction: 2, Actual: 2 --- Next Price: 24.90
# Price: 24.90, Prediction: 2, Actual: 2 --- Next Price: 24.88
# Price: 24.88, Prediction: 2, Actual: 2 --- Next Price: 24.85
# Price: 24.85, Prediction: 2, Actual: 2 --- Next Price: 24.82
# Price: 24.82, Prediction: 2, Actual: 2 --- Next Price: 24.80
# Price: 24.80, Prediction: 2, Actual: 2 --- Next Price: 24.20
# Price: 24.20, Prediction: 1, Actual: 1 --- Next Price: 24.21
# Price: 24.21, Prediction: 1, Actual: 1 --- Next Price: 24.24
# Price: 24.24, Prediction: 1, Actual: 1 --- Next Price: 24.30
# Price: 24.30, Prediction: 1, Actual: 1 --- Next Price: 24.37
# Price: 24.37, Prediction: 1, Actual: 1 --- Next Price: 24.47
# Price: 24.47, Prediction: 1, Actual: 1 --- Next Price: 24.55
# Price: 24.55, Prediction: 1, Actual: 1 --- Next Price: 24.65
# Price: 24.65, Prediction: 1, Actual: 1 --- Next Price: 24.76
# Price: 24.76, Prediction: 1, Actual: 1 --- Next Price: 24.85
# Price: 24.85, Prediction: 1, Actual: 1 --- Next Price: 24.93
# Price: 24.93, Prediction: 1, Actual: 1 --- Next Price: 25.00
# Price: 25.00, Prediction: 1, Actual: 1 --- Next Price: 25.50
# Price: 25.50, Prediction: 0, Actual: 0 --- Next Price: 25.50
# Price: 25.50, Prediction: 2, Actual: 2 --- Next Price: 25.49
# Price: 25.49, Prediction: 2, Actual: 2 --- Next Price: 25.48
# Price: 25.48, Prediction: 2, Actual: 2 --- Next Price: 25.47
# Price: 25.47, Prediction: 2, Actual: 2 --- Next Price: 25.45
# Price: 25.45, Prediction: 2, Actual: 2 --- Next Price: 25.41
# Price: 25.41, Prediction: 2, Actual: 2 --- Next Price: 25.37
# Price: 25.37, Prediction: 2, Actual: 2 --- Next Price: 25.34
# Price: 25.34, Prediction: 2, Actual: 2 --- Next Price: 25.31
# Price: 25.31, Prediction: 2, Actual: 2 --- Next Price: 25.27
# Price: 25.27, Prediction: 2, Actual: 2 --- Next Price: 25.25
# Price: 25.25, Prediction: 2, Actual: 2 --- Next Price: 24.80
# Price: 24.80, Prediction: 0, Actual: 1 --- Next Price: 24.81
# Price: 24.81, Prediction: 1, Actual: 1 --- Next Price: 24.81
# Price: 24.81, Prediction: 1, Actual: 1 --- Next Price: 25.23
# Price: 25.23, Prediction: 2, Actual: 2 --- Next Price: 25.22
# Price: 25.22, Prediction: 2, Actual: 2 --- Next Price: 25.19
# Price: 25.19, Prediction: 2, Actual: 2 --- Next Price: 25.17
# Price: 25.17, Prediction: 2, Actual: 2 --- Next Price: 25.14
# Price: 25.14, Prediction: 2, Actual: 2 --- Next Price: 25.12
# Price: 25.12, Prediction: 2, Actual: 2 --- Next Price: 24.53
# Price: 24.53, Prediction: 1, Actual: 1 --- Next Price: 24.54
# Price: 24.54, Prediction: 1, Actual: 1 --- Next Price: 24.57
# Price: 24.57, Prediction: 1, Actual: 1 --- Next Price: 24.61
# Price: 24.61, Prediction: 1, Actual: 1 --- Next Price: 24.65
# Price: 24.65, Prediction: 1, Actual: 1 --- Next Price: 24.69
# Price: 24.69, Prediction: 1, Actual: 1 --- Next Price: 24.70
# Price: 24.70, Prediction: 1, Actual: 1 --- Next Price: 24.73
# Price: 24.73, Prediction: 2, Actual: 1 --- Next Price: 24.76
# Price: 24.76, Prediction: 1, Actual: 1 --- Next Price: 24.78
# Price: 24.78, Prediction: 1, Actual: 1 --- Next Price: 24.80
# Price: 24.80, Prediction: 1, Actual: 1 --- Next Price: 25.27
# Price: 25.27, Prediction: 2, Actual: 2 --- Next Price: 25.26
# Price: 25.26, Prediction: 2, Actual: 2 --- Next Price: 25.25
# Price: 25.25, Prediction: 2, Actual: 2 --- Next Price: 25.23
# Price: 25.23, Prediction: 2, Actual: 2 --- Next Price: 24.75
# Price: 24.75, Prediction: 1, Actual: 1 --- Next Price: 24.77
# Price: 24.77, Prediction: 1, Actual: 1 --- Next Price: 24.78
# Price: 24.78, Prediction: 1, Actual: 1 --- Next Price: 24.81
# Price: 24.81, Prediction: 1, Actual: 1 --- Next Price: 24.87
# Price: 24.87, Prediction: 1, Actual: 1 --- Next Price: 24.95
# Price: 24.95, Prediction: 1, Actual: 1 --- Next Price: 25.02
# Price: 25.02, Prediction: 1, Actual: 1 --- Next Price: 25.09
# Price: 25.09, Prediction: 1, Actual: 1 --- Next Price: 25.15
# Price: 25.15, Prediction: 1, Actual: 1 --- Next Price: 25.20
# Price: 25.20, Prediction: 1, Actual: 1 --- Next Price: 25.26
# Price: 25.26, Prediction: 1, Actual: 1 --- Next Price: 25.30
# Price: 25.30, Prediction: 1, Actual: 1 --- Next Price: 25.35
# Price: 25.35, Prediction: 1, Actual: 1 --- Next Price: 25.39
# Price: 25.39, Prediction: 1, Actual: 1 --- Next Price: 25.42
# Price: 25.42, Prediction: 1, Actual: 1 --- Next Price: 25.85
# Price: 25.85, Prediction: 2, Actual: 2 --- Next Price: 25.84
# Price: 25.84, Prediction: 1, Actual: 2 --- Next Price: 25.83
# Price: 25.83, Prediction: 2, Actual: 2 --- Next Price: 25.81
# Price: 25.81, Prediction: 2, Actual: 2 --- Next Price: 25.76
# Price: 25.76, Prediction: 2, Actual: 2 --- Next Price: 25.67
# Price: 25.67, Prediction: 2, Actual: 2 --- Next Price: 25.54
# Price: 25.54, Prediction: 2, Actual: 2 --- Next Price: 25.42
# Price: 25.42, Prediction: 2, Actual: 2 --- Next Price: 25.32
# Price: 25.32, Prediction: 2, Actual: 2 --- Next Price: 25.23
# Price: 25.23, Prediction: 2, Actual: 2 --- Next Price: 25.14
# Price: 25.14, Prediction: 2, Actual: 2 --- Next Price: 25.07
# Price: 25.07, Prediction: 2, Actual: 2 --- Next Price: 25.00
# Price: 25.00, Prediction: 0, Actual: 2 --- Next Price: 24.95
# Price: 24.95, Prediction: 2, Actual: 2 --- Next Price: 24.39
# Price: 24.39, Prediction: 1, Actual: 1 --- Next Price: 24.41
# Price: 24.41, Prediction: 1, Actual: 1 --- Next Price: 24.44
# Price: 24.44, Prediction: 1, Actual: 1 --- Next Price: 24.50
# Price: 24.50, Prediction: 1, Actual: 1 --- Next Price: 24.55
# Price: 24.55, Prediction: 1, Actual: 1 --- Next Price: 24.60
# Price: 24.60, Prediction: 1, Actual: 1 --- Next Price: 24.64
# Price: 24.64, Prediction: 1, Actual: 1 --- Next Price: 24.68
# Price: 24.68, Prediction: 1, Actual: 1 --- Next Price: 24.75
# Price: 24.75, Prediction: 1, Actual: 1 --- Next Price: 24.84
# Price: 24.84, Prediction: 1, Actual: 1 --- Next Price: 24.91
# Price: 24.91, Prediction: 1, Actual: 1 --- Next Price: 25.58
# Price: 25.58, Prediction: 2, Actual: 2 --- Next Price: 25.56
# Price: 25.56, Prediction: 2, Actual: 2 --- Next Price: 25.55
# Price: 25.55, Prediction: 2, Actual: 2 --- Next Price: 25.54
# Price: 25.54, Prediction: 2, Actual: 2 --- Next Price: 25.53
# Price: 25.53, Prediction: 2, Actual: 2 --- Next Price: 25.51
# Price: 25.51, Prediction: 2, Actual: 2 --- Next Price: 25.50
# Price: 25.50, Prediction: 2, Actual: 2 --- Next Price: 25.49
# Price: 25.49, Prediction: 2, Actual: 2 --- Next Price: 24.92
# Price: 24.92, Prediction: 1, Actual: 1 --- Next Price: 24.93
# Price: 24.93, Prediction: 1, Actual: 1 --- Next Price: 24.94
# Price: 24.94, Prediction: 1, Actual: 1 --- Next Price: 24.95
# Price: 24.95, Prediction: 1, Actual: 1 --- Next Price: 24.98
# Price: 24.98, Prediction: 1, Actual: 1 --- Next Price: 25.76
# Price: 25.76, Prediction: 2, Actual: 2 --- Next Price: 25.74
# Price: 25.74, Prediction: 2, Actual: 2 --- Next Price: 25.73
# Price: 25.73, Prediction: 2, Actual: 2 --- Next Price: 25.69
# Price: 25.69, Prediction: 2, Actual: 2 --- Next Price: 25.63
# Price: 25.63, Prediction: 2, Actual: 2 --- Next Price: 25.57
# Price: 25.57, Prediction: 2, Actual: 2 --- Next Price: 25.52
# Price: 25.52, Prediction: 2, Actual: 2 --- Next Price: 25.47
# Price: 25.47, Prediction: 2, Actual: 2 --- Next Price: 25.46
# Price: 25.46, Prediction: 2, Actual: 2 --- Next Price: 24.67
# Price: 24.67, Prediction: 1, Actual: 1 --- Next Price: 24.69
# Price: 24.69, Prediction: 1, Actual: 1 --- Next Price: 24.72
# Price: 24.72, Prediction: 1, Actual: 1 --- Next Price: 24.76
# Price: 24.76, Prediction: 1, Actual: 1 --- Next Price: 24.79
# Price: 24.79, Prediction: 1, Actual: 1 --- Next Price: 24.82
# Price: 24.82, Prediction: 1, Actual: 1 --- Next Price: 24.86
# Price: 24.86, Prediction: 1, Actual: 1 --- Next Price: 24.91
# Price: 24.91, Prediction: 1, Actual: 1 --- Next Price: 24.96
# Price: 24.96, Prediction: 1, Actual: 1 --- Next Price: 25.01
# Price: 25.01, Prediction: 1, Actual: 1 --- Next Price: 25.06
# Price: 25.06, Prediction: 1, Actual: 1 --- Next Price: 25.10
# Price: 25.10, Prediction: 1, Actual: 1 --- Next Price: 25.15
# Price: 25.15, Prediction: 1, Actual: 1 --- Next Price: 25.18
# Price: 25.18, Prediction: 1, Actual: 1 --- Next Price: 25.25
# Price: 25.25, Prediction: 1, Actual: 1 --- Next Price: 25.34
# Price: 25.34, Prediction: 1, Actual: 1 --- Next Price: 26.19
# Price: 26.19, Prediction: 2, Actual: 2 --- Next Price: 26.17
# Price: 26.17, Prediction: 2, Actual: 2 --- Next Price: 26.14
# Price: 26.14, Prediction: 2, Actual: 2 --- Next Price: 26.11
# Price: 26.11, Prediction: 2, Actual: 2 --- Next Price: 26.08
# Price: 26.08, Prediction: 2, Actual: 2 --- Next Price: 26.05
# Price: 26.05, Prediction: 2, Actual: 2 --- Next Price: 26.02
# Price: 26.02, Prediction: 2, Actual: 2 --- Next Price: 25.96
# Price: 25.96, Prediction: 2, Actual: 2 --- Next Price: 25.88
# Price: 25.88, Prediction: 2, Actual: 2 --- Next Price: 25.80
# Price: 25.80, Prediction: 2, Actual: 2 --- Next Price: 25.73
# Price: 25.73, Prediction: 2, Actual: 2 --- Next Price: 25.67
# Price: 25.67, Prediction: 2, Actual: 2 --- Next Price: 25.61
# Price: 25.61, Prediction: 2, Actual: 2 --- Next Price: 25.56
# Price: 25.56, Prediction: 2, Actual: 2 --- Next Price: 25.51
# Price: 25.51, Prediction: 2, Actual: 2 --- Next Price: 24.94
# Price: 24.94, Prediction: 1, Actual: 1 --- Next Price: 24.95
# Price: 24.95, Prediction: 1, Actual: 1 --- Next Price: 24.99
# Price: 24.99, Prediction: 1, Actual: 1 --- Next Price: 25.03
# Price: 25.03, Prediction: 1, Actual: 1 --- Next Price: 25.07
# Price: 25.07, Prediction: 1, Actual: 1 --- Next Price: 25.13
# Price: 25.13, Prediction: 1, Actual: 1 --- Next Price: 25.18
# Price: 25.18, Prediction: 1, Actual: 1 --- Next Price: 25.24
# Price: 25.24, Prediction: 1, Actual: 1 --- Next Price: 25.33
# Price: 25.33, Prediction: 1, Actual: 1 --- Next Price: 25.45
# Price: 25.45, Prediction: 1, Actual: 1 --- Next Price: 25.60
# Price: 25.60, Prediction: 1, Actual: 1 --- Next Price: 25.74
# Price: 25.74, Prediction: 1, Actual: 1 --- Next Price: 25.86
# Price: 25.86, Prediction: 1, Actual: 1 --- Next Price: 25.97
# Price: 25.97, Prediction: 1, Actual: 1 --- Next Price: 26.06
# Price: 26.06, Prediction: 1, Actual: 1 --- Next Price: 26.14
# Price: 26.14, Prediction: 1, Actual: 1 --- Next Price: 26.21
# Price: 26.21, Prediction: 1, Actual: 1 --- Next Price: 26.27
# Price: 26.27, Prediction: 1, Actual: 1 --- Next Price: 26.35
# Price: 26.35, Prediction: 1, Actual: 1 --- Next Price: 26.48
# Price: 26.48, Prediction: 1, Actual: 1 --- Next Price: 26.58
# Price: 26.58, Prediction: 1, Actual: 1 --- Next Price: 26.69
# Price: 26.69, Prediction: 1, Actual: 1 --- Next Price: 26.82
# Price: 26.82, Prediction: 1, Actual: 1 --- Next Price: 26.94
# Price: 26.94, Prediction: 1, Actual: 1 --- Next Price: 27.04
# Price: 27.04, Prediction: 1, Actual: 1 --- Next Price: 27.12
# Price: 27.12, Prediction: 1, Actual: 1 --- Next Price: 27.48
# Price: 27.48, Prediction: 2, Actual: 0 --- Next Price: 27.48
# Price: 27.48, Prediction: 2, Actual: 2 --- Next Price: 27.46
# Price: 27.46, Prediction: 1, Actual: 2 --- Next Price: 27.44
# Price: 27.44, Prediction: 2, Actual: 2 --- Next Price: 27.39
# Price: 27.39, Prediction: 2, Actual: 2 --- Next Price: 27.34
# Price: 27.34, Prediction: 2, Actual: 2 --- Next Price: 27.28
# Price: 27.28, Prediction: 2, Actual: 2 --- Next Price: 26.77
# Price: 26.77, Prediction: 1, Actual: 1 --- Next Price: 26.78
# Price: 26.78, Prediction: 1, Actual: 1 --- Next Price: 26.80
# Price: 26.80, Prediction: 1, Actual: 1 --- Next Price: 26.82
# Price: 26.82, Prediction: 1, Actual: 1 --- Next Price: 26.86
# Price: 26.86, Prediction: 1, Actual: 1 --- Next Price: 26.90
# Price: 26.90, Prediction: 1, Actual: 1 --- Next Price: 26.94
# Price: 26.94, Prediction: 1, Actual: 1 --- Next Price: 26.98
# ['trading_bot.joblib']
